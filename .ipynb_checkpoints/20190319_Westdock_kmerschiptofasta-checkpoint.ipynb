# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import os
os.chdir('/home/bojk/Data/') #this is when opened in '/home/bojk/Data/notebooks' on linux Quakelab
#os.chdir('/Users/bojk/Google Drive/QuakeLab/Data/')
import sys
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
sys.path.append('/Users/bojk/Google Drive/QuakeLab/minimeta_pyfiles/')
import imp
import HTSeq
from scipy.stats import powerlaw
import minimetagenome_analysis as minimeta

import mock_metagenome_creation as mock
imp.reload(mock)
#import reassembly as rea
#import subcluster_bins as sub
#import checkm_out_plot as cop
#import checkm_out as co

import matplotlib as mpl
mpl.rcParams['axes.labelsize'] = 15
mpl.rcParams['xtick.labelsize'] = 15
mpl.rcParams['ytick.labelsize'] = 15
mpl.rcParams['axes.titlesize'] = 15
mpl.rcParams['figure.titlesize'] = 18
mpl.rcParams['legend.fontsize'] = 14

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
#metagenome_fasta = '/home/datastorage/ASSEMBLY_DATA/PermafrostFranklinBluffs/Combined_Analysis/super_contigs.PermafrostWestD.fasta'
metagenome_fasta = 'Permafrost/WestDock/super_contigs.PermafrostWestDock.fasta'
save_dir = 'Permafrost/WestDock/pickles/'

# %%
maindf = pd.read_pickle('Permafrost/WestDock/20180904hdbfinal')
contigdf = maindf[['Sequence Length','GC Content','Read Depth']].copy()
contig2 = pd.read_csv('Permafrost/SIMR/WestDock_metadata.table').set_index('Unnamed: 0')[['Sequence Length','GC Content','Read Depth']]
contigdf.rename(index=str,columns={'Sequence Length':'Sequence length','GC Content':'GC'},inplace=True)
#contig2.rename(index=str,columns={'Sequence Length':'Sequence length','GC Content':'GC'},inplace=True)

# %%
chip = pd.read_csv('Permafrost/WestDock/super_contigs.PermafrostWestDock.alignment_report.txt','\t').set_index('Unnamed: 0')
chip.drop('WestDock5_Bulk',axis=1, inplace=True)

# %%
chip_mini = chip[~chip.index.str.contains('Bulk')]

# %%
chip_mini.shape
chip_mini[chip_mini.isna()].sum().sum()
# Out:
# 0.0

# %%
maindf.head()
# Out:
#                                                                               Scaffold ID  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  3300022818 assembled Ga0255658_100002
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...  3300022818 assembled Ga0255658_100017
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...  3300022818 assembled Ga0255658_100035
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...  3300022818 assembled Ga0255658_100037
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...  3300022818 assembled Ga0255658_100043
#
#                                                     Scaffold Name   Genome ID  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...         100002  3300022818
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...         100017  3300022818
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...         100035  3300022818
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...         100037  3300022818
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...         100043  3300022818
#
#                                                                                                Genome  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  Permafrost soil microbial communities from Wes...
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...  Permafrost soil microbial communities from Wes...
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...  Permafrost soil microbial communities from Wes...
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...  Permafrost soil microbial communities from Wes...
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...  Permafrost soil microbial communities from Wes...
#
#                                                     Gene Count  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...           7
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...           9
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...           9
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...           5
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...           7
#
#                                                     Sequence Length  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...             5216
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...             5363
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...             5555
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...             5745
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...             5169
#
#                                                     GC Content  Read Depth  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...        0.65           1
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...        0.71           1
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...        0.57           1
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...        0.66           1
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...        0.49           1
#
#                                                    Lineage Domain  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...       Bacteria
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...       Bacteria
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...       Bacteria
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...       Bacteria
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...       Bacteria
#
#                                                     Lineage Phylum  ...  \
# Unnamed: 0                                                          ...
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  Actinobacteria  ...
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...      Firmicutes  ...
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...  Proteobacteria  ...
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...      Unassigned  ...
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...      Unassigned  ...
#
#                                                        y_70_n     y_80_a  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52... -20.794870  25.229956
# SuperContig_k91_818_flag=1_multi=10.4127_len=53... -12.769647  25.557776
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5... -33.369970  15.494744
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57... -18.576481  24.871854
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51... -14.056690  -3.432112
#
#                                                        y_80_n DBclusternum  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  -5.094186            3
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...   2.185190            3
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5... -27.721259           13
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...  -2.703166            3
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51... -15.999414           10
#
#                                                    finclu  Bin bulk_cov  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...      0  000    536.0
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...      0  000   1052.0
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...      1  001    504.0
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...      0  000    370.0
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...      2  002    412.0
#
#                                                     norm_cov         FPK  \
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  0.102761  102.760736
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...  0.196159  196.158866
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...  0.090729   90.729073
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...  0.064404   64.403829
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...  0.079706   79.705939
#
#                                                      FPK_log
# Unnamed: 0
# SuperContig_k91_123_flag=0_multi=12.4853_len=52...  2.011827
# SuperContig_k91_818_flag=1_multi=10.4127_len=53...  2.292608
# SuperContig_k91_2173_flag=0_multi=17.1559_len=5...  1.957746
# SuperContig_k91_2472_flag=1_multi=8.5646_len=57...  1.808912
# SuperContig_k91_2863_flag=0_multi=9.2367_len=51...  1.901491
#
# [5 rows x 49 columns]

# %%
idx_incl = chip_mini.index
#chip_mini.divide(contig2.loc[idx_incl,'Sequence length'].astype(float),axis=0)
#contig2

# %%
num_dims = len(chip_mini.T)
pcs_to_reduce = [int(round(f)) for f in np.logspace(0,3,20)[4:]]
[f for f in pcs_to_reduce if f<num_dims]
# Out:
# [4, 6, 9, 13, 18, 26, 38, 55, 78, 113]

# %%
import minimetagenome_dimensionality as miniD
imp.reload(miniD)
maindir = 'Permafrost/WestDock/kmerPCA/'
thres3kb = chip_mini[chip_mini>3000].dropna(how='all').fillna(0)
thres5kb = chip_mini[chip_mini>5000].dropna(how='all').fillna(0)
thres7kb = chip_mini[chip_mini>7000].dropna(how='all').fillna(0)
thres10kb = chip_mini[chip_mini>10000].dropna(how='all').fillna(0)
#contig2.loc[idx,'Sequence length'].sum()
tsnedf3kb = miniD.perform_complete_analysis_Coverage(thres3kb,6,contig2,maindir,'WDminichipCov3kbthres')
# Out:
# building tSNE of all 160 dimensions
# finished building main tSNE, this took 547.23 seconds
# performing cluster sweep of tSNE of all 160 dimensions
# Performing PCA...
# building tSNE of 4 PCs
# finished building tSNE of 4 PCs, this took 488.98 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 6 PCs
# finished building tSNE of 6 PCs, this took 422.07 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 9 PCs
# finished building tSNE of 9 PCs, this took 429.06 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 13 PCs
# finished building tSNE of 13 PCs, this took 428.49 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 18 PCs
# finished building tSNE of 18 PCs, this took 429.71 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 26 PCs
# finished building tSNE of 26 PCs, this took 454.92 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 38 PCs
# finished building tSNE of 38 PCs, this took 476.54 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 55 PCs
# finished building tSNE of 55 PCs, this took 465.43 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 78 PCs
# finished building tSNE of 78 PCs, this took 470.87 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 113 PCs
# finished building tSNE of 113 PCs, this took 492.01 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# Finished everything.
# Total elapsed time is 85.10 minutes

# %%
tsnedf5kb = miniD.perform_complete_analysis_Coverage(thres5kb,6,contig2,maindir,'WDminichipCov5kbthres')
# Out:
# building tSNE of all 160 dimensions
# finished building main tSNE, this took 466.58 seconds
# performing cluster sweep of tSNE of all 160 dimensions
# Performing PCA...
# building tSNE of 4 PCs
# finished building tSNE of 4 PCs, this took 1728.42 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 6 PCs
# finished building tSNE of 6 PCs, this took 372.15 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 9 PCs
# finished building tSNE of 9 PCs, this took 372.84 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 13 PCs
# finished building tSNE of 13 PCs, this took 401.27 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 18 PCs
# finished building tSNE of 18 PCs, this took 409.09 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 26 PCs
# finished building tSNE of 26 PCs, this took 411.19 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 38 PCs
# finished building tSNE of 38 PCs, this took 412.96 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 55 PCs
# finished building tSNE of 55 PCs, this took 423.91 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 78 PCs
# finished building tSNE of 78 PCs, this took 461.56 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 113 PCs
# finished building tSNE of 113 PCs, this took 457.05 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# Finished everything.
# Total elapsed time is 98.62 minutes

# %%
tsnedf7kb = miniD.perform_complete_analysis_Coverage(thres7kb,6,contig2,maindir,'WDminichipCov7kbthres')
# Out:
# building tSNE of all 160 dimensions
# finished building main tSNE, this took 245.52 seconds
# performing cluster sweep of tSNE of all 160 dimensions
# Performing PCA...
# building tSNE of 4 PCs
# finished building tSNE of 4 PCs, this took 224.28 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 6 PCs
# finished building tSNE of 6 PCs, this took 218.94 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 9 PCs
# finished building tSNE of 9 PCs, this took 212.90 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 13 PCs
# finished building tSNE of 13 PCs, this took 222.91 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 18 PCs
# finished building tSNE of 18 PCs, this took 229.96 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 26 PCs
# finished building tSNE of 26 PCs, this took 229.48 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 38 PCs
# finished building tSNE of 38 PCs, this took 215.11 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 55 PCs
# finished building tSNE of 55 PCs, this took 222.26 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 78 PCs
# finished building tSNE of 78 PCs, this took 229.91 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 113 PCs
# finished building tSNE of 113 PCs, this took 241.10 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# Finished everything.
# Total elapsed time is 41.54 minutes

# %%
tsnedf10kb = miniD.perform_complete_analysis_Coverage(thres10kb,6,contig2,maindir,'WDminichipCov10kbthres')
# Out:
# building tSNE of all 160 dimensions
# finished building main tSNE, this took 109.63 seconds
# performing cluster sweep of tSNE of all 160 dimensions
# Performing PCA...
# building tSNE of 4 PCs
# finished building tSNE of 4 PCs, this took 96.06 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 6 PCs
# finished building tSNE of 6 PCs, this took 95.48 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 9 PCs
# finished building tSNE of 9 PCs, this took 95.43 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 13 PCs
# finished building tSNE of 13 PCs, this took 98.67 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 18 PCs
# finished building tSNE of 18 PCs, this took 98.63 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 26 PCs
# finished building tSNE of 26 PCs, this took 99.14 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 38 PCs
# finished building tSNE of 38 PCs, this took 98.97 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 55 PCs
# finished building tSNE of 55 PCs, this took 100.42 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 78 PCs
# finished building tSNE of 78 PCs, this took 122.19 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# building tSNE of 113 PCs
# finished building tSNE of 113 PCs, this took 115.34 seconds
# Index([0, 1, 'Sequence length', 'GC'], dtype='object')
# Finished everything.
# Total elapsed time is 18.83 minutes

# %%
#imp.reload(miniD)
#main = pd.read_csv('Permafrost/SIMR/WestDock_metadata.table').set_index('Unnamed: 0')
#tsnedf_WDminiCov = pd.read_pickle(maindir+'WDminiCovOnly6mers_all_tSNEs')
#miniD.plotPCs(tsnedf_WDminiCov,main,maindir,'WDminiChipAbsCov')

# %%
#maindir = 'Permafrost/WestDock/kmerPCA/'
#tsnedf_WDminiCov = pd.read_pickle(maindir+'WDminiCovOnly6mers_all_tSNEs')
idx = tsnedf3kb.index
WDmaindf_mini3 = contig2.loc[idx].copy()
WDmaindf_mini3 = WDmaindf_mini3.join(tsnedf3kb)#[['x_PC13','y_PC13']])
WDmaindf_mini3.head()

idx = tsnedf5kb.index
WDmaindf_mini5 = contig2.loc[idx].copy()
WDmaindf_mini5 = WDmaindf_mini5.join(tsnedf5kb)#[['x_PC13','y_PC13']])
WDmaindf_mini5.head()

idx = tsnedf7kb.index
WDmaindf_mini7 = contig2.loc[idx].copy()
WDmaindf_mini7 = WDmaindf_mini7.join(tsnedf7kb)#[['x_PC13','y_PC13']])
WDmaindf_mini7.head()

idx = tsnedf10kb.index
WDmaindf_mini10 = contig2.loc[idx].copy()
WDmaindf_mini10 = WDmaindf_mini10.join(tsnedf10kb)#[['x_PC13','y_PC13']])
WDmaindf_mini10.head()
# Out:
#                                                  Sequence Length  GC Content  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179             18628        0.33
# SuperContig_NODE_2002_length_15947_cov_0.98025             15947        0.47
# SuperContig_NODE_1248_length_19278_cov_2.04802             19278        0.49
# SuperContig_NODE_3562_length_12278_cov_0.503079            12278        0.43
# SuperContig_NODE_2462_length_14531_cov_2.80592             14531        0.37
#
#                                                  Read Depth  x_160mers  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179            1  25.839336
# SuperContig_NODE_2002_length_15947_cov_0.98025            1 -13.298770
# SuperContig_NODE_1248_length_19278_cov_2.04802            1  53.795483
# SuperContig_NODE_3562_length_12278_cov_0.503079           1  22.288321
# SuperContig_NODE_2462_length_14531_cov_2.80592            1  22.542706
#
#                                                  y_160mers  Sequence length  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   -9.900165            18628
# SuperContig_NODE_2002_length_15947_cov_0.98025  -57.164463            15947
# SuperContig_NODE_1248_length_19278_cov_2.04802  -36.111485            19278
# SuperContig_NODE_3562_length_12278_cov_0.503079  -3.810481            12278
# SuperContig_NODE_2462_length_14531_cov_2.80592  -40.340584            14531
#
#                                                    GC      x_PC4      y_PC4  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   0.33 -27.498554  13.316640
# SuperContig_NODE_2002_length_15947_cov_0.98025   0.47  11.542347 -18.182737
# SuperContig_NODE_1248_length_19278_cov_2.04802   0.49  39.493816  49.944073
# SuperContig_NODE_3562_length_12278_cov_0.503079  0.43 -24.563833   3.675609
# SuperContig_NODE_2462_length_14531_cov_2.80592   0.37  18.961937 -23.277065
#
#                                                      x_PC6  ...     x_PC26  \
# Unnamed: 0                                                  ...
# SuperContig_NODE_1352_length_18628_cov_1.96179    8.791280  ... -11.141665
# SuperContig_NODE_2002_length_15947_cov_0.98025  -21.662539  ...  30.532898
# SuperContig_NODE_1248_length_19278_cov_2.04802   30.314314  ...  -8.677154
# SuperContig_NODE_3562_length_12278_cov_0.503079   5.576499  ... -14.481489
# SuperContig_NODE_2462_length_14531_cov_2.80592   41.053146  ...  36.403973
#
#                                                     y_PC26     x_PC38  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179  -35.748268 -10.823096
# SuperContig_NODE_2002_length_15947_cov_0.98025  -11.906808  69.029854
# SuperContig_NODE_1248_length_19278_cov_2.04802  -66.608162 -35.583637
# SuperContig_NODE_3562_length_12278_cov_0.503079 -34.710888  -6.477506
# SuperContig_NODE_2462_length_14531_cov_2.80592   32.244823  41.061443
#
#                                                     y_PC38     x_PC55  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   -0.175075  41.640961
# SuperContig_NODE_2002_length_15947_cov_0.98025  -13.746682  19.783625
# SuperContig_NODE_1248_length_19278_cov_2.04802  -37.058411 -65.427742
# SuperContig_NODE_3562_length_12278_cov_0.503079  -1.390689  37.722759
# SuperContig_NODE_2462_length_14531_cov_2.80592   28.993969  23.163773
#
#                                                     y_PC55     x_PC78  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179  -35.592979  20.450151
# SuperContig_NODE_2002_length_15947_cov_0.98025   15.841828  12.555349
# SuperContig_NODE_1248_length_19278_cov_2.04802  -18.290924 -44.667183
# SuperContig_NODE_3562_length_12278_cov_0.503079 -34.512691  22.795389
# SuperContig_NODE_2462_length_14531_cov_2.80592   37.086449  12.009456
#
#                                                     y_PC78    x_PC113  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179  -10.392942  13.219214
# SuperContig_NODE_2002_length_15947_cov_0.98025  -20.258966   9.483404
# SuperContig_NODE_1248_length_19278_cov_2.04802   18.984222 -52.878380
# SuperContig_NODE_3562_length_12278_cov_0.503079 -15.269758  19.851082
# SuperContig_NODE_2462_length_14531_cov_2.80592   16.536842  44.526695
#
#                                                    y_PC113
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179  -14.143561
# SuperContig_NODE_2002_length_15947_cov_0.98025  -42.488495
# SuperContig_NODE_1248_length_19278_cov_2.04802  -29.631920
# SuperContig_NODE_3562_length_12278_cov_0.503079 -12.044785
# SuperContig_NODE_2462_length_14531_cov_2.80592  -14.477378
#
# [5 rows x 27 columns]

# %%
#get tsne cols in the right format (write function to do this, then pass on to 
#                                  standard minimeta pipeline)
imp.reload(minimeta)
"""
minCS ['min_cluster_size']
minS ['min_samples']
CSM ['cluster_selection_method']
ASC ['allow_single_cluster']
perp ['perplexity_na'] # this is a string of the form '40_a' or '60_n' (so perplexity and absolute or normalized tsne)
expt_name ['expt_name']
write_fasta ['write_fasta'] # save the fasta Y/n (as in: do dry run clustering first, as fasta writing takes time)
writedf ['write_df']
series ['is_this_a_series']
"""
minCS = 90
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster'
             ,'perplexity_na','expt_name','write_fasta','write_df','is_this_a_series','outdir']
values = [minCS,1,'leaf',False,'PC13','WestDock_miniPC13','YES','YES','NO','Permafrost/WestDock/']
kwargs = dict(zip(keys,values))
for pcs in [9,13,18,26,38,55,78,113]:
    pc = str(pcs)
    kwargs['perplexity_na'] = 'PC'+pc
    kwargs['expt_name'] = 'WestDock_miniPC'+pc+'_3kbthres_minCS'+str(minCS)
    maindf_mini = minimeta.cluster_main_tsne(WDmaindf_mini3,**kwargs) # cluster whatever pcs you want here.

minCS = 70
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster'
             ,'perplexity_na','expt_name','write_fasta','write_df','is_this_a_series','outdir']
values = [minCS,1,'leaf',False,'PC13','WestDock_miniPC13','YES','YES','NO','Permafrost/WestDock/']
kwargs = dict(zip(keys,values))
for pcs in [9,13,18,26,38,55,78,113]:
    pc = str(pcs)
    kwargs['perplexity_na'] = 'PC'+pc
    kwargs['expt_name'] = 'WestDock_miniPC'+pc+'_5kbthres_minCS'+str(minCS)
    maindf_mini = minimeta.cluster_main_tsne(WDmaindf_mini5,**kwargs) # cluster whatever pcs you want here.

minCS = 50
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster'
             ,'perplexity_na','expt_name','write_fasta','write_df','is_this_a_series','outdir']
values = [minCS,1,'leaf',False,'PC13','WestDock_miniPC13','YES','YES','NO','Permafrost/WestDock/']
kwargs = dict(zip(keys,values))
for pcs in [9,13,18,26,38,55,78,113]:
    pc = str(pcs)
    kwargs['perplexity_na'] = 'PC'+pc
    kwargs['expt_name'] = 'WestDock_miniPC'+pc+'_7kbthres_minCS'+str(minCS)
    maindf_mini = minimeta.cluster_main_tsne(WDmaindf_mini7,**kwargs) # cluster whatever pcs you want here.

minCS = 25
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster'
             ,'perplexity_na','expt_name','write_fasta','write_df','is_this_a_series','outdir']
values = [minCS,1,'leaf',False,'PC13','WestDock_miniPC13','YES','YES','NO','Permafrost/WestDock/']
kwargs = dict(zip(keys,values))
for pcs in [9,13,18,26,38,55,78,113]:
    pc = str(pcs)
    kwargs['perplexity_na'] = 'PC'+pc
    kwargs['expt_name'] = 'WestDock_miniPC'+pc+'_10kbthres_minCS'+str(minCS)
    maindf_mini = minimeta.cluster_main_tsne(WDmaindf_mini10,**kwargs) # cluster whatever pcs you want here.

# %%
WDmaindf_mini10
# Out:
#                                                   Sequence Length  GC Content  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179              18628        0.33
# SuperContig_NODE_2002_length_15947_cov_0.98025              15947        0.47
# SuperContig_NODE_1248_length_19278_cov_2.04802              19278        0.49
# SuperContig_NODE_3562_length_12278_cov_0.503079             12278        0.43
# SuperContig_NODE_2462_length_14531_cov_2.80592              14531        0.37
# SuperContig_NODE_324_length_29524_cov_1.29003               29524        0.32
# SuperContig_NODE_2872_length_13506_cov_0.220631             13506        0.50
# SuperContig_NODE_691_length_23859_cov_3.17386               23859        0.38
# SuperContig_NODE_2172_length_15382_cov_0.531048             15382        0.39
# SuperContig_NODE_2102_length_15618_cov_0.338359             15618        0.52
# SuperContig_NODE_5241_length_10240_cov_0.308155             10240        0.39
# SuperContig_NODE_4882_length_10600_cov_0.369489             10600        0.36
# SuperContig_NODE_2775_length_13736_cov_1.32595              13736        0.40
# SuperContig_NODE_2529_length_14344_cov_1.51716              14344        0.42
# SuperContig_NODE_2408_length_14660_cov_0.0852963            14660        0.45
# SuperContig_NODE_1498_length_17972_cov_2.74436              17972        0.37
# SuperContig_NODE_2034_length_15828_cov_0.182974             15828        0.49
# SuperContig_NODE_1414_length_18339_cov_2.79282              18339        0.49
# SuperContig_NODE_3098_length_13073_cov_0.346077             13073        0.40
# SuperContig_NODE_3697_length_12059_cov_4.6592               12059        0.35
# SuperContig_NODE_1578_length_17539_cov_0.177867             17539        0.50
# SuperContig_NODE_4145_length_11432_cov_1.61114              11432        0.50
# SuperContig_NODE_2526_length_14349_cov_0.861754             14349        0.43
# SuperContig_NODE_1654_length_17231_cov_1.83849              17231        0.44
# SuperContig_NODE_4059_length_11557_cov_1.20099              11557        0.44
# SuperContig_NODE_2404_length_14669_cov_0.105422             14669        0.45
# SuperContig_NODE_991_length_21052_cov_1.10385               21052        0.38
# SuperContig_NODE_628_length_24559_cov_0.203352              24559        0.54
# SuperContig_NODE_5084_length_10402_cov_2.19383              10402        0.39
# SuperContig_NODE_418_length_27712_cov_0.61366               27712        0.36
# ...                                                           ...         ...
# SuperContig_NODE_5129_length_10351_cov_0.377                10351        0.38
# SuperContig_NODE_102_length_40046_cov_0.322202              40046        0.49
# SuperContig_NODE_3406_length_12532_cov_1.32928              12532        0.38
# SuperContig_NODE_3627_length_12179_cov_0.183113             12179        0.38
# SuperContig_NODE_4486_length_11032_cov_0.242751             11032        0.31
# SuperContig_NODE_2044_length_15774_cov_0.391005             15774        0.49
# SuperContig_NODE_1966_length_16062_cov_0.638226             16062        0.39
# SuperContig_NODE_436_length_27245_cov_4.30067               27245        0.40
# SuperContig_NODE_4703_length_10795_cov_0.636593             10795        0.43
# SuperContig_NODE_3515_length_12354_cov_0.451326             12354        0.44
# SuperContig_NODE_4938_length_10545_cov_0.650584             10545        0.37
# SuperContig_NODE_1041_length_20745_cov_0.88235              20745        0.46
# SuperContig_NODE_510_length_26197_cov_0.734884              26197        0.33
# SuperContig_NODE_1438_length_18200_cov_0.36893              18200        0.40
# SuperContig_NODE_4757_length_10739_cov_0.465414             10739        0.34
# SuperContig_NODE_1765_length_16743_cov_4.69911              16743        0.39
# SuperContig_NODE_4552_length_10973_cov_1.08295              10973        0.38
# SuperContig_NODE_423_length_27530_cov_0.657103              27530        0.48
# SuperContig_NODE_2879_length_13488_cov_0.570244             13488        0.37
# SuperContig_NODE_4804_length_10687_cov_0.404892             10687        0.39
# SuperContig_NODE_1970_length_16048_cov_2.07963              16048        0.40
# SuperContig_NODE_4584_length_10928_cov_2.18626              10928        0.38
# SuperContig_NODE_4438_length_11080_cov_0.635917             11080        0.44
# SuperContig_NODE_4599_length_10911_cov_6.43331              10911        0.40
# SuperContig_NODE_2454_length_14543_cov_0.914428             14543        0.45
# SuperContig_NODE_2392_length_14699_cov_0.388973             14699        0.46
# SuperContig_NODE_2413_length_14648_cov_0.518592             14648        0.43
# SuperContig_NODE_849_length_22142_cov_0.260445              22142        0.45
# SuperContig_NODE_2310_length_14983_cov_0.353332             14983        0.47
# SuperContig_NODE_601_length_25061_cov_4.23356               25061        0.35
#
#                                                   x_160mers  y_160mers  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179    25.839336  -9.900165
# SuperContig_NODE_2002_length_15947_cov_0.98025   -13.298770 -57.164463
# SuperContig_NODE_1248_length_19278_cov_2.04802    53.795483 -36.111485
# SuperContig_NODE_3562_length_12278_cov_0.503079   22.288321  -3.810481
# SuperContig_NODE_2462_length_14531_cov_2.80592    22.542706 -40.340584
# SuperContig_NODE_324_length_29524_cov_1.29003     26.737270  43.443512
# SuperContig_NODE_2872_length_13506_cov_0.220631   51.863358 -36.220165
# SuperContig_NODE_691_length_23859_cov_3.17386     -6.234107 -42.026470
# SuperContig_NODE_2172_length_15382_cov_0.531048   35.262432 -37.727299
# SuperContig_NODE_2102_length_15618_cov_0.338359   24.866575  71.589676
# SuperContig_NODE_5241_length_10240_cov_0.308155  -11.587639  -7.226314
# SuperContig_NODE_4882_length_10600_cov_0.369489  -14.528710 -72.534256
# SuperContig_NODE_2775_length_13736_cov_1.32595    23.210419 -54.451458
# SuperContig_NODE_2529_length_14344_cov_1.51716   -22.582512  56.644791
# SuperContig_NODE_2408_length_14660_cov_0.0852963 -69.580452 -20.044666
# SuperContig_NODE_1498_length_17972_cov_2.74436   -12.244300 -32.553493
# SuperContig_NODE_2034_length_15828_cov_0.182974  -22.505079 -20.010687
# SuperContig_NODE_1414_length_18339_cov_2.79282   -39.773285  42.976414
# SuperContig_NODE_3098_length_13073_cov_0.346077   14.117457  -0.230742
# SuperContig_NODE_3697_length_12059_cov_4.6592      9.661149  11.296400
# SuperContig_NODE_1578_length_17539_cov_0.177867   -4.845521  38.985184
# SuperContig_NODE_4145_length_11432_cov_1.61114    -1.103517 -54.643642
# SuperContig_NODE_2526_length_14349_cov_0.861754  -30.487734  21.156803
# SuperContig_NODE_1654_length_17231_cov_1.83849    52.736385   4.180037
# SuperContig_NODE_4059_length_11557_cov_1.20099     0.481696 -29.742079
# SuperContig_NODE_2404_length_14669_cov_0.105422   38.484623   1.706174
# SuperContig_NODE_991_length_21052_cov_1.10385     54.141735 -14.678339
# SuperContig_NODE_628_length_24559_cov_0.203352    49.028664  42.210754
# SuperContig_NODE_5084_length_10402_cov_2.19383    -6.234107 -42.026470
# SuperContig_NODE_418_length_27712_cov_0.61366     42.998611  16.040194
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377     -64.559738  34.889729
# SuperContig_NODE_102_length_40046_cov_0.322202     6.358358  37.723831
# SuperContig_NODE_3406_length_12532_cov_1.32928    -9.331827 -17.251509
# SuperContig_NODE_3627_length_12179_cov_0.183113   -2.360882  55.068668
# SuperContig_NODE_4486_length_11032_cov_0.242751   74.804649  -7.463127
# SuperContig_NODE_2044_length_15774_cov_0.391005   56.851776 -18.914282
# SuperContig_NODE_1966_length_16062_cov_0.638226   22.261105  -4.327021
# SuperContig_NODE_436_length_27245_cov_4.30067     21.144318  26.902210
# SuperContig_NODE_4703_length_10795_cov_0.636593  -21.299368   3.178469
# SuperContig_NODE_3515_length_12354_cov_0.451326    8.510885 -34.935596
# SuperContig_NODE_4938_length_10545_cov_0.650584  -26.227589 -54.552338
# SuperContig_NODE_1041_length_20745_cov_0.88235     1.211511  -6.368283
# SuperContig_NODE_510_length_26197_cov_0.734884    68.712616  -3.619088
# SuperContig_NODE_1438_length_18200_cov_0.36893    49.089684  43.775932
# SuperContig_NODE_4757_length_10739_cov_0.465414  -21.459148  -6.866808
# SuperContig_NODE_1765_length_16743_cov_4.69911   -15.506747 -30.052372
# SuperContig_NODE_4552_length_10973_cov_1.08295    22.609314 -40.362637
# SuperContig_NODE_423_length_27530_cov_0.657103   -48.901344 -39.946701
# SuperContig_NODE_2879_length_13488_cov_0.570244   -0.645583  26.691940
# SuperContig_NODE_4804_length_10687_cov_0.404892  -15.764927  27.802975
# SuperContig_NODE_1970_length_16048_cov_2.07963    -9.350405 -16.287067
# SuperContig_NODE_4584_length_10928_cov_2.18626    -5.246261   1.079066
# SuperContig_NODE_4438_length_11080_cov_0.635917    1.968027   3.514574
# SuperContig_NODE_4599_length_10911_cov_6.43331    26.229288  23.767355
# SuperContig_NODE_2454_length_14543_cov_0.914428  -31.842213  -1.919906
# SuperContig_NODE_2392_length_14699_cov_0.388973    9.464921 -44.821846
# SuperContig_NODE_2413_length_14648_cov_0.518592   19.595831  13.815910
# SuperContig_NODE_849_length_22142_cov_0.260445    23.969406 -55.484238
# SuperContig_NODE_2310_length_14983_cov_0.353332   27.519711 -10.920869
# SuperContig_NODE_601_length_25061_cov_4.23356    -24.000000  57.402809
#
#                                                   Sequence length    GC  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179              18628  0.33
# SuperContig_NODE_2002_length_15947_cov_0.98025              15947  0.47
# SuperContig_NODE_1248_length_19278_cov_2.04802              19278  0.49
# SuperContig_NODE_3562_length_12278_cov_0.503079             12278  0.43
# SuperContig_NODE_2462_length_14531_cov_2.80592              14531  0.37
# SuperContig_NODE_324_length_29524_cov_1.29003               29524  0.32
# SuperContig_NODE_2872_length_13506_cov_0.220631             13506  0.50
# SuperContig_NODE_691_length_23859_cov_3.17386               23859  0.38
# SuperContig_NODE_2172_length_15382_cov_0.531048             15382  0.39
# SuperContig_NODE_2102_length_15618_cov_0.338359             15618  0.52
# SuperContig_NODE_5241_length_10240_cov_0.308155             10240  0.39
# SuperContig_NODE_4882_length_10600_cov_0.369489             10600  0.36
# SuperContig_NODE_2775_length_13736_cov_1.32595              13736  0.40
# SuperContig_NODE_2529_length_14344_cov_1.51716              14344  0.42
# SuperContig_NODE_2408_length_14660_cov_0.0852963            14660  0.45
# SuperContig_NODE_1498_length_17972_cov_2.74436              17972  0.37
# SuperContig_NODE_2034_length_15828_cov_0.182974             15828  0.49
# SuperContig_NODE_1414_length_18339_cov_2.79282              18339  0.49
# SuperContig_NODE_3098_length_13073_cov_0.346077             13073  0.40
# SuperContig_NODE_3697_length_12059_cov_4.6592               12059  0.35
# SuperContig_NODE_1578_length_17539_cov_0.177867             17539  0.50
# SuperContig_NODE_4145_length_11432_cov_1.61114              11432  0.50
# SuperContig_NODE_2526_length_14349_cov_0.861754             14349  0.43
# SuperContig_NODE_1654_length_17231_cov_1.83849              17231  0.44
# SuperContig_NODE_4059_length_11557_cov_1.20099              11557  0.44
# SuperContig_NODE_2404_length_14669_cov_0.105422             14669  0.45
# SuperContig_NODE_991_length_21052_cov_1.10385               21052  0.38
# SuperContig_NODE_628_length_24559_cov_0.203352              24559  0.54
# SuperContig_NODE_5084_length_10402_cov_2.19383              10402  0.39
# SuperContig_NODE_418_length_27712_cov_0.61366               27712  0.36
# ...                                                           ...   ...
# SuperContig_NODE_5129_length_10351_cov_0.377                10351  0.38
# SuperContig_NODE_102_length_40046_cov_0.322202              40046  0.49
# SuperContig_NODE_3406_length_12532_cov_1.32928              12532  0.38
# SuperContig_NODE_3627_length_12179_cov_0.183113             12179  0.38
# SuperContig_NODE_4486_length_11032_cov_0.242751             11032  0.31
# SuperContig_NODE_2044_length_15774_cov_0.391005             15774  0.49
# SuperContig_NODE_1966_length_16062_cov_0.638226             16062  0.39
# SuperContig_NODE_436_length_27245_cov_4.30067               27245  0.40
# SuperContig_NODE_4703_length_10795_cov_0.636593             10795  0.43
# SuperContig_NODE_3515_length_12354_cov_0.451326             12354  0.44
# SuperContig_NODE_4938_length_10545_cov_0.650584             10545  0.37
# SuperContig_NODE_1041_length_20745_cov_0.88235              20745  0.46
# SuperContig_NODE_510_length_26197_cov_0.734884              26197  0.33
# SuperContig_NODE_1438_length_18200_cov_0.36893              18200  0.40
# SuperContig_NODE_4757_length_10739_cov_0.465414             10739  0.34
# SuperContig_NODE_1765_length_16743_cov_4.69911              16743  0.39
# SuperContig_NODE_4552_length_10973_cov_1.08295              10973  0.38
# SuperContig_NODE_423_length_27530_cov_0.657103              27530  0.48
# SuperContig_NODE_2879_length_13488_cov_0.570244             13488  0.37
# SuperContig_NODE_4804_length_10687_cov_0.404892             10687  0.39
# SuperContig_NODE_1970_length_16048_cov_2.07963              16048  0.40
# SuperContig_NODE_4584_length_10928_cov_2.18626              10928  0.38
# SuperContig_NODE_4438_length_11080_cov_0.635917             11080  0.44
# SuperContig_NODE_4599_length_10911_cov_6.43331              10911  0.40
# SuperContig_NODE_2454_length_14543_cov_0.914428             14543  0.45
# SuperContig_NODE_2392_length_14699_cov_0.388973             14699  0.46
# SuperContig_NODE_2413_length_14648_cov_0.518592             14648  0.43
# SuperContig_NODE_849_length_22142_cov_0.260445              22142  0.45
# SuperContig_NODE_2310_length_14983_cov_0.353332             14983  0.47
# SuperContig_NODE_601_length_25061_cov_4.23356               25061  0.35
#
#                                                       x_PC4      y_PC4  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   -27.498554  13.316640
# SuperContig_NODE_2002_length_15947_cov_0.98025    11.542347 -18.182737
# SuperContig_NODE_1248_length_19278_cov_2.04802    39.493816  49.944073
# SuperContig_NODE_3562_length_12278_cov_0.503079  -24.563833   3.675609
# SuperContig_NODE_2462_length_14531_cov_2.80592    18.961937 -23.277065
# SuperContig_NODE_324_length_29524_cov_1.29003    -29.516808 -59.751915
# SuperContig_NODE_2872_length_13506_cov_0.220631  -18.929611 -60.880127
# SuperContig_NODE_691_length_23859_cov_3.17386     76.924675 -12.998532
# SuperContig_NODE_2172_length_15382_cov_0.531048  -23.941254  14.613124
# SuperContig_NODE_2102_length_15618_cov_0.338359   47.469517 -48.826248
# SuperContig_NODE_5241_length_10240_cov_0.308155    0.062032 -50.362228
# SuperContig_NODE_4882_length_10600_cov_0.369489   15.980724  -4.682843
# SuperContig_NODE_2775_length_13736_cov_1.32595    33.585426  29.498018
# SuperContig_NODE_2529_length_14344_cov_1.51716    37.665237  -3.900252
# SuperContig_NODE_2408_length_14660_cov_0.0852963   4.978602 -80.687416
# SuperContig_NODE_1498_length_17972_cov_2.74436    -6.962293  40.485737
# SuperContig_NODE_2034_length_15828_cov_0.182974    3.561576 -36.925999
# SuperContig_NODE_1414_length_18339_cov_2.79282   -38.456310  38.274796
# SuperContig_NODE_3098_length_13073_cov_0.346077   -7.846604 -18.174314
# SuperContig_NODE_3697_length_12059_cov_4.6592     24.892122 -31.938610
# SuperContig_NODE_1578_length_17539_cov_0.177867  -31.749403  57.259689
# SuperContig_NODE_4145_length_11432_cov_1.61114    24.991737 -39.280190
# SuperContig_NODE_2526_length_14349_cov_0.861754   33.715267  50.148071
# SuperContig_NODE_1654_length_17231_cov_1.83849   -56.327648 -28.507111
# SuperContig_NODE_4059_length_11557_cov_1.20099    20.020367  39.419769
# SuperContig_NODE_2404_length_14669_cov_0.105422   48.918259  43.929890
# SuperContig_NODE_991_length_21052_cov_1.10385    -73.627106   0.822869
# SuperContig_NODE_628_length_24559_cov_0.203352     2.261303   0.664840
# SuperContig_NODE_5084_length_10402_cov_2.19383    76.924660 -12.998533
# SuperContig_NODE_418_length_27712_cov_0.61366     -4.940939  70.420479
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377      54.664833   9.134246
# SuperContig_NODE_102_length_40046_cov_0.322202   -11.387670  63.144341
# SuperContig_NODE_3406_length_12532_cov_1.32928   -43.985786 -10.098648
# SuperContig_NODE_3627_length_12179_cov_0.183113  -42.835945  35.222790
# SuperContig_NODE_4486_length_11032_cov_0.242751   20.223896  29.738012
# SuperContig_NODE_2044_length_15774_cov_0.391005  -73.920296   6.330209
# SuperContig_NODE_1966_length_16062_cov_0.638226  -23.735765   3.454780
# SuperContig_NODE_436_length_27245_cov_4.30067    -15.058252  46.580349
# SuperContig_NODE_4703_length_10795_cov_0.636593  -11.722182 -38.170410
# SuperContig_NODE_3515_length_12354_cov_0.451326  -14.418710  26.464180
# SuperContig_NODE_4938_length_10545_cov_0.650584   61.751671 -16.010223
# SuperContig_NODE_1041_length_20745_cov_0.88235    -3.556328  -8.515900
# SuperContig_NODE_510_length_26197_cov_0.734884    15.499444  30.008623
# SuperContig_NODE_1438_length_18200_cov_0.36893     1.499724   2.087197
# SuperContig_NODE_4757_length_10739_cov_0.465414   -7.239525 -43.701820
# SuperContig_NODE_1765_length_16743_cov_4.69911    -2.212682  19.131134
# SuperContig_NODE_4552_length_10973_cov_1.08295    19.059753 -23.324572
# SuperContig_NODE_423_length_27530_cov_0.657103    48.793968  20.317638
# SuperContig_NODE_2879_length_13488_cov_0.570244  -41.100029  18.587416
# SuperContig_NODE_4804_length_10687_cov_0.404892  -34.964966   3.999764
# SuperContig_NODE_1970_length_16048_cov_2.07963   -43.733006 -11.067005
# SuperContig_NODE_4584_length_10928_cov_2.18626   -18.921217 -27.894213
# SuperContig_NODE_4438_length_11080_cov_0.635917  -18.312218 -36.838234
# SuperContig_NODE_4599_length_10911_cov_6.43331    -6.225768  40.907051
# SuperContig_NODE_2454_length_14543_cov_0.914428   25.911331  10.274753
# SuperContig_NODE_2392_length_14699_cov_0.388973   11.212026  16.056931
# SuperContig_NODE_2413_length_14648_cov_0.518592   62.155811  25.544447
# SuperContig_NODE_849_length_22142_cov_0.260445    33.097569  51.119644
# SuperContig_NODE_2310_length_14983_cov_0.353332    0.642591 -23.076071
# SuperContig_NODE_601_length_25061_cov_4.23356     -8.619676  22.741892
#
#                                                       x_PC6      y_PC6  ...  \
# Unnamed: 0                                                              ...
# SuperContig_NODE_1352_length_18628_cov_1.96179     8.791280  47.525299  ...
# SuperContig_NODE_2002_length_15947_cov_0.98025   -21.662539 -24.400541  ...
# SuperContig_NODE_1248_length_19278_cov_2.04802    30.314314  22.890263  ...
# SuperContig_NODE_3562_length_12278_cov_0.503079    5.576499  36.037735  ...
# SuperContig_NODE_2462_length_14531_cov_2.80592    41.053146 -34.526596  ...
# SuperContig_NODE_324_length_29524_cov_1.29003      6.194829 -79.794891  ...
# SuperContig_NODE_2872_length_13506_cov_0.220631   20.327145 -27.007231  ...
# SuperContig_NODE_691_length_23859_cov_3.17386     34.721226 -55.022076  ...
# SuperContig_NODE_2172_length_15382_cov_0.531048   13.288284  50.078377  ...
# SuperContig_NODE_2102_length_15618_cov_0.338359   40.984528   4.343416  ...
# SuperContig_NODE_5241_length_10240_cov_0.308155  -13.184160 -44.158295  ...
# SuperContig_NODE_4882_length_10600_cov_0.369489   32.832626 -18.628929  ...
# SuperContig_NODE_2775_length_13736_cov_1.32595    83.187080 -22.940628  ...
# SuperContig_NODE_2529_length_14344_cov_1.51716     4.804648 -16.073099  ...
# SuperContig_NODE_2408_length_14660_cov_0.0852963  16.651705 -62.701572  ...
# SuperContig_NODE_1498_length_17972_cov_2.74436    -0.704354  12.484280  ...
# SuperContig_NODE_2034_length_15828_cov_0.182974   -6.385477 -33.042774  ...
# SuperContig_NODE_1414_length_18339_cov_2.79282   -21.142427  58.739635  ...
# SuperContig_NODE_3098_length_13073_cov_0.346077  -13.859869  -6.704372  ...
# SuperContig_NODE_3697_length_12059_cov_4.6592     44.827087 -39.882954  ...
# SuperContig_NODE_1578_length_17539_cov_0.177867  -29.499485  46.544247  ...
# SuperContig_NODE_4145_length_11432_cov_1.61114   -13.164127 -76.249756  ...
# SuperContig_NODE_2526_length_14349_cov_0.861754   11.715505  17.954014  ...
# SuperContig_NODE_1654_length_17231_cov_1.83849    10.457454  16.598171  ...
# SuperContig_NODE_4059_length_11557_cov_1.20099    42.683872 -14.067379  ...
# SuperContig_NODE_2404_length_14669_cov_0.105422   28.932278  30.373133  ...
# SuperContig_NODE_991_length_21052_cov_1.10385    -74.609184  11.593818  ...
# SuperContig_NODE_628_length_24559_cov_0.203352   -22.514723   6.658347  ...
# SuperContig_NODE_5084_length_10402_cov_2.19383    34.718231 -55.021637  ...
# SuperContig_NODE_418_length_27712_cov_0.61366    -42.736885  26.530407  ...
# ...                                                     ...        ...  ...
# SuperContig_NODE_5129_length_10351_cov_0.377      33.087368  69.219490  ...
# SuperContig_NODE_102_length_40046_cov_0.322202   -35.462498  31.780399  ...
# SuperContig_NODE_3406_length_12532_cov_1.32928     5.102598 -29.589603  ...
# SuperContig_NODE_3627_length_12179_cov_0.183113  -19.007744  63.098690  ...
# SuperContig_NODE_4486_length_11032_cov_0.242751   49.310482  35.715458  ...
# SuperContig_NODE_2044_length_15774_cov_0.391005  -77.104736  16.620375  ...
# SuperContig_NODE_1966_length_16062_cov_0.638226    6.164162  35.435951  ...
# SuperContig_NODE_436_length_27245_cov_4.30067      0.335010  12.480154  ...
# SuperContig_NODE_4703_length_10795_cov_0.636593  -29.378412 -45.464066  ...
# SuperContig_NODE_3515_length_12354_cov_0.451326  -19.903666  21.888981  ...
# SuperContig_NODE_4938_length_10545_cov_0.650584   60.549984   8.512686  ...
# SuperContig_NODE_1041_length_20745_cov_0.88235   -26.551201 -18.473846  ...
# SuperContig_NODE_510_length_26197_cov_0.734884    51.841408  34.387161  ...
# SuperContig_NODE_1438_length_18200_cov_0.36893   -20.921162   6.910145  ...
# SuperContig_NODE_4757_length_10739_cov_0.465414  -22.011637 -40.612221  ...
# SuperContig_NODE_1765_length_16743_cov_4.69911    28.593929   8.056997  ...
# SuperContig_NODE_4552_length_10973_cov_1.08295    41.119492 -34.559479  ...
# SuperContig_NODE_423_length_27530_cov_0.657103    15.937497 -45.661793  ...
# SuperContig_NODE_2879_length_13488_cov_0.570244   -6.489715  51.990639  ...
# SuperContig_NODE_4804_length_10687_cov_0.404892   -4.688703  37.560631  ...
# SuperContig_NODE_1970_length_16048_cov_2.07963     5.609717 -30.455454  ...
# SuperContig_NODE_4584_length_10928_cov_2.18626   -36.151707 -30.932367  ...
# SuperContig_NODE_4438_length_11080_cov_0.635917  -31.152538 -38.997402  ...
# SuperContig_NODE_4599_length_10911_cov_6.43331    -0.124441  14.201849  ...
# SuperContig_NODE_2454_length_14543_cov_0.914428  -40.439732   6.461967  ...
# SuperContig_NODE_2392_length_14699_cov_0.388973   16.030489 -15.815887  ...
# SuperContig_NODE_2413_length_14648_cov_0.518592   32.146324  55.742390  ...
# SuperContig_NODE_849_length_22142_cov_0.260445    11.180062  16.164139  ...
# SuperContig_NODE_2310_length_14983_cov_0.353332   -9.104767 -13.820000  ...
# SuperContig_NODE_601_length_25061_cov_4.23356    -20.374552  12.688374  ...
#
#                                                      x_PC26     y_PC26  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   -11.141665 -35.748268
# SuperContig_NODE_2002_length_15947_cov_0.98025    30.532898 -11.906808
# SuperContig_NODE_1248_length_19278_cov_2.04802    -8.677154 -66.608162
# SuperContig_NODE_3562_length_12278_cov_0.503079  -14.481489 -34.710888
# SuperContig_NODE_2462_length_14531_cov_2.80592    36.403973  32.244823
# SuperContig_NODE_324_length_29524_cov_1.29003      6.970627  12.049862
# SuperContig_NODE_2872_length_13506_cov_0.220631  -11.192154 -65.052383
# SuperContig_NODE_691_length_23859_cov_3.17386     79.199379 -12.608263
# SuperContig_NODE_2172_length_15382_cov_0.531048   40.521294 -27.513239
# SuperContig_NODE_2102_length_15618_cov_0.338359   63.490742 -34.388882
# SuperContig_NODE_5241_length_10240_cov_0.308155    1.415316 -10.326043
# SuperContig_NODE_4882_length_10600_cov_0.369489   28.391346 -36.150097
# SuperContig_NODE_2775_length_13736_cov_1.32595     1.916566 -27.017708
# SuperContig_NODE_2529_length_14344_cov_1.51716   -45.351177 -45.439487
# SuperContig_NODE_2408_length_14660_cov_0.0852963   3.834306 -79.022507
# SuperContig_NODE_1498_length_17972_cov_2.74436   -29.550827  45.611820
# SuperContig_NODE_2034_length_15828_cov_0.182974  -11.211812  -8.472906
# SuperContig_NODE_1414_length_18339_cov_2.79282   -48.573421  19.460695
# SuperContig_NODE_3098_length_13073_cov_0.346077   20.129782 -49.128819
# SuperContig_NODE_3697_length_12059_cov_4.6592     38.246136  13.125199
# SuperContig_NODE_1578_length_17539_cov_0.177867  -13.318270  54.120293
# SuperContig_NODE_4145_length_11432_cov_1.61114    28.151896 -20.813509
# SuperContig_NODE_2526_length_14349_cov_0.861754  -38.091530   5.321836
# SuperContig_NODE_1654_length_17231_cov_1.83849   -54.091976  -9.472796
# SuperContig_NODE_4059_length_11557_cov_1.20099    27.520857  54.271515
# SuperContig_NODE_2404_length_14669_cov_0.105422   13.613295 -18.596672
# SuperContig_NODE_991_length_21052_cov_1.10385    -25.084736 -43.059151
# SuperContig_NODE_628_length_24559_cov_0.203352    -0.745329  65.330856
# SuperContig_NODE_5084_length_10402_cov_2.19383    79.422974 -12.712187
# SuperContig_NODE_418_length_27712_cov_0.61366      3.252612  26.333485
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377      27.561384  39.895336
# SuperContig_NODE_102_length_40046_cov_0.322202   -19.737429  64.770302
# SuperContig_NODE_3406_length_12532_cov_1.32928    43.670776 -11.217095
# SuperContig_NODE_3627_length_12179_cov_0.183113  -44.860332  18.887501
# SuperContig_NODE_4486_length_11032_cov_0.242751   38.447037  69.412857
# SuperContig_NODE_2044_length_15774_cov_0.391005  -28.237286 -39.444412
# SuperContig_NODE_1966_length_16062_cov_0.638226  -14.806050 -35.248158
# SuperContig_NODE_436_length_27245_cov_4.30067    -28.681555  -5.153921
# SuperContig_NODE_4703_length_10795_cov_0.636593   -5.897340 -49.367908
# SuperContig_NODE_3515_length_12354_cov_0.451326    4.272273  47.672825
# SuperContig_NODE_4938_length_10545_cov_0.650584   37.628101  45.331257
# SuperContig_NODE_1041_length_20745_cov_0.88235    31.466547  -2.041254
# SuperContig_NODE_510_length_26197_cov_0.734884    38.504116  72.318985
# SuperContig_NODE_1438_length_18200_cov_0.36893     0.794509  65.684380
# SuperContig_NODE_4757_length_10739_cov_0.465414   -0.368871 -41.639263
# SuperContig_NODE_1765_length_16743_cov_4.69911   -25.771938  44.905235
# SuperContig_NODE_4552_length_10973_cov_1.08295    36.409672  32.210224
# SuperContig_NODE_423_length_27530_cov_0.657103   -68.099663 -16.064735
# SuperContig_NODE_2879_length_13488_cov_0.570244  -13.076933  39.171490
# SuperContig_NODE_4804_length_10687_cov_0.404892  -20.753759  16.482965
# SuperContig_NODE_1970_length_16048_cov_2.07963    43.342377 -12.135536
# SuperContig_NODE_4584_length_10928_cov_2.18626    25.657574   8.747516
# SuperContig_NODE_4438_length_11080_cov_0.635917   21.231281   9.743405
# SuperContig_NODE_4599_length_10911_cov_6.43331   -23.617954   0.504476
# SuperContig_NODE_2454_length_14543_cov_0.914428  -43.726532  50.818047
# SuperContig_NODE_2392_length_14699_cov_0.388973   17.746853  47.813095
# SuperContig_NODE_2413_length_14648_cov_0.518592   71.891861  11.542462
# SuperContig_NODE_849_length_22142_cov_0.260445     3.474795 -26.602848
# SuperContig_NODE_2310_length_14983_cov_0.353332    9.582925 -56.571339
# SuperContig_NODE_601_length_25061_cov_4.23356    -28.316847  41.613194
#
#                                                      x_PC38     y_PC38  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179   -10.823096  -0.175075
# SuperContig_NODE_2002_length_15947_cov_0.98025    69.029854 -13.746682
# SuperContig_NODE_1248_length_19278_cov_2.04802   -35.583637 -37.058411
# SuperContig_NODE_3562_length_12278_cov_0.503079   -6.477506  -1.390689
# SuperContig_NODE_2462_length_14531_cov_2.80592    41.061443  28.993969
# SuperContig_NODE_324_length_29524_cov_1.29003      6.318612 -46.598148
# SuperContig_NODE_2872_length_13506_cov_0.220631  -32.740902 -36.688709
# SuperContig_NODE_691_length_23859_cov_3.17386     85.224442  -8.769586
# SuperContig_NODE_2172_length_15382_cov_0.531048  -19.837942   3.403845
# SuperContig_NODE_2102_length_15618_cov_0.338359   58.943821 -26.566866
# SuperContig_NODE_5241_length_10240_cov_0.308155   14.377986 -13.129454
# SuperContig_NODE_4882_length_10600_cov_0.369489   32.058479 -33.529858
# SuperContig_NODE_2775_length_13736_cov_1.32595    -5.293673 -36.020245
# SuperContig_NODE_2529_length_14344_cov_1.51716    -5.480274 -54.183052
# SuperContig_NODE_2408_length_14660_cov_0.0852963 -38.133560 -67.272751
# SuperContig_NODE_1498_length_17972_cov_2.74436   -16.426968  44.044216
# SuperContig_NODE_2034_length_15828_cov_0.182974    3.653775 -22.604012
# SuperContig_NODE_1414_length_18339_cov_2.79282   -45.506298  15.508882
# SuperContig_NODE_3098_length_13073_cov_0.346077   34.240021 -65.708206
# SuperContig_NODE_3697_length_12059_cov_4.6592     42.587566  19.690529
# SuperContig_NODE_1578_length_17539_cov_0.177867   -4.628794  58.610214
# SuperContig_NODE_4145_length_11432_cov_1.61114    57.503597 -13.915454
# SuperContig_NODE_2526_length_14349_cov_0.861754  -25.200897 -22.510912
# SuperContig_NODE_1654_length_17231_cov_1.83849    39.990265 -14.527845
# SuperContig_NODE_4059_length_11557_cov_1.20099     9.818937  32.900867
# SuperContig_NODE_2404_length_14669_cov_0.105422   10.712554  45.563675
# SuperContig_NODE_991_length_21052_cov_1.10385    -48.450287 -35.920105
# SuperContig_NODE_628_length_24559_cov_0.203352   -53.401131   7.027493
# SuperContig_NODE_5084_length_10402_cov_2.19383    85.224442  -8.769586
# SuperContig_NODE_418_length_27712_cov_0.61366     31.277184  -7.078140
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377      34.255997  37.662663
# SuperContig_NODE_102_length_40046_cov_0.322202   -36.564846  38.004143
# SuperContig_NODE_3406_length_12532_cov_1.32928    -7.439106 -16.963558
# SuperContig_NODE_3627_length_12179_cov_0.183113  -44.293392  17.932547
# SuperContig_NODE_4486_length_11032_cov_0.242751   18.033131  55.946056
# SuperContig_NODE_2044_length_15774_cov_0.391005  -52.265194 -33.922226
# SuperContig_NODE_1966_length_16062_cov_0.638226   -7.058107  -1.654748
# SuperContig_NODE_436_length_27245_cov_4.30067    -27.391886  13.181721
# SuperContig_NODE_4703_length_10795_cov_0.636593   15.020791 -63.564838
# SuperContig_NODE_3515_length_12354_cov_0.451326   -3.495770  14.138509
# SuperContig_NODE_4938_length_10545_cov_0.650584   49.556755  48.524818
# SuperContig_NODE_1041_length_20745_cov_0.88235    67.083809  -3.430303
# SuperContig_NODE_510_length_26197_cov_0.734884    20.894840  57.252884
# SuperContig_NODE_1438_length_18200_cov_0.36893   -54.958656   6.933325
# SuperContig_NODE_4757_length_10739_cov_0.465414   24.871292 -21.681833
# SuperContig_NODE_1765_length_16743_cov_4.69911   -13.266659  42.033524
# SuperContig_NODE_4552_length_10973_cov_1.08295    41.067596  28.981253
# SuperContig_NODE_423_length_27530_cov_0.657103    41.026855 -48.213306
# SuperContig_NODE_2879_length_13488_cov_0.570244   -5.311059  31.441410
# SuperContig_NODE_4804_length_10687_cov_0.404892  -27.327522  30.321516
# SuperContig_NODE_1970_length_16048_cov_2.07963    -6.474091 -17.065952
# SuperContig_NODE_4584_length_10928_cov_2.18626    37.501480   6.486532
# SuperContig_NODE_4438_length_11080_cov_0.635917   39.139915   2.914696
# SuperContig_NODE_4599_length_10911_cov_6.43331   -35.122025   0.370489
# SuperContig_NODE_2454_length_14543_cov_0.914428   15.108349  11.207176
# SuperContig_NODE_2392_length_14699_cov_0.388973    3.465016  23.845634
# SuperContig_NODE_2413_length_14648_cov_0.518592   61.920483  33.976360
# SuperContig_NODE_849_length_22142_cov_0.260445    -5.977458 -36.826023
# SuperContig_NODE_2310_length_14983_cov_0.353332   28.105551 -53.471886
# SuperContig_NODE_601_length_25061_cov_4.23356    -18.301662  41.436447
#
#                                                      x_PC55     y_PC55  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179    41.640961 -35.592979
# SuperContig_NODE_2002_length_15947_cov_0.98025    19.783625  15.841828
# SuperContig_NODE_1248_length_19278_cov_2.04802   -65.427742 -18.290924
# SuperContig_NODE_3562_length_12278_cov_0.503079   37.722759 -34.512691
# SuperContig_NODE_2462_length_14531_cov_2.80592    23.163773  37.086449
# SuperContig_NODE_324_length_29524_cov_1.29003      2.835244   9.457539
# SuperContig_NODE_2872_length_13506_cov_0.220631  -66.342392 -20.023045
# SuperContig_NODE_691_length_23859_cov_3.17386     74.007408  11.878625
# SuperContig_NODE_2172_length_15382_cov_0.531048   52.473465 -32.470745
# SuperContig_NODE_2102_length_15618_cov_0.338359   70.127815  -3.496591
# SuperContig_NODE_5241_length_10240_cov_0.308155   31.520594  -2.232164
# SuperContig_NODE_4882_length_10600_cov_0.369489   56.072330 -17.533346
# SuperContig_NODE_2775_length_13736_cov_1.32595     3.566626 -41.835220
# SuperContig_NODE_2529_length_14344_cov_1.51716    21.513727 -55.862106
# SuperContig_NODE_2408_length_14660_cov_0.0852963   8.765860 -67.678101
# SuperContig_NODE_1498_length_17972_cov_2.74436   -19.483761  24.409567
# SuperContig_NODE_2034_length_15828_cov_0.182974   32.184574   8.441843
# SuperContig_NODE_1414_length_18339_cov_2.79282   -44.627731  40.110016
# SuperContig_NODE_3098_length_13073_cov_0.346077   36.236149 -45.240353
# SuperContig_NODE_3697_length_12059_cov_4.6592      9.101768  44.421951
# SuperContig_NODE_1578_length_17539_cov_0.177867  -20.218203  47.497360
# SuperContig_NODE_4145_length_11432_cov_1.61114    33.810009  74.188126
# SuperContig_NODE_2526_length_14349_cov_0.861754   -4.246809 -25.064095
# SuperContig_NODE_1654_length_17231_cov_1.83849    48.199894  -3.185907
# SuperContig_NODE_4059_length_11557_cov_1.20099    -9.600006   3.869063
# SuperContig_NODE_2404_length_14669_cov_0.105422  -25.313284   5.509642
# SuperContig_NODE_991_length_21052_cov_1.10385    -39.789944 -43.469978
# SuperContig_NODE_628_length_24559_cov_0.203352   -51.661289  20.108921
# SuperContig_NODE_5084_length_10402_cov_2.19383    74.007408  11.878625
# SuperContig_NODE_418_length_27712_cov_0.61366     52.936756   6.515948
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377       0.850763  25.903713
# SuperContig_NODE_102_length_40046_cov_0.322202   -27.660942  56.626171
# SuperContig_NODE_3406_length_12532_cov_1.32928    19.701933 -40.818104
# SuperContig_NODE_3627_length_12179_cov_0.183113  -42.621014  41.385227
# SuperContig_NODE_4486_length_11032_cov_0.242751  -33.450523  13.459975
# SuperContig_NODE_2044_length_15774_cov_0.391005  -43.078922 -40.655930
# SuperContig_NODE_1966_length_16062_cov_0.638226   37.346626 -34.885620
# SuperContig_NODE_436_length_27245_cov_4.30067    -15.404388  30.692789
# SuperContig_NODE_4703_length_10795_cov_0.636593   23.623102 -13.590490
# SuperContig_NODE_3515_length_12354_cov_0.451326   34.360222 -20.791237
# SuperContig_NODE_4938_length_10545_cov_0.650584   50.073448  50.646610
# SuperContig_NODE_1041_length_20745_cov_0.88235    16.041260  22.168686
# SuperContig_NODE_510_length_26197_cov_0.734884   -36.808086  13.880072
# SuperContig_NODE_1438_length_18200_cov_0.36893   -52.588898  18.872421
# SuperContig_NODE_4757_length_10739_cov_0.465414   20.593466   0.317703
# SuperContig_NODE_1765_length_16743_cov_4.69911   -23.960457  24.167599
# SuperContig_NODE_4552_length_10973_cov_1.08295    23.163609  37.104603
# SuperContig_NODE_423_length_27530_cov_0.657103   -28.932953 -68.295242
# SuperContig_NODE_2879_length_13488_cov_0.570244   -4.147430  65.251579
# SuperContig_NODE_4804_length_10687_cov_0.404892   -9.255367  -9.577631
# SuperContig_NODE_1970_length_16048_cov_2.07963    20.637041 -40.560211
# SuperContig_NODE_4584_length_10928_cov_2.18626    34.499447  35.817352
# SuperContig_NODE_4438_length_11080_cov_0.635917   37.949791  35.115646
# SuperContig_NODE_4599_length_10911_cov_6.43331   -42.127411  -5.906279
# SuperContig_NODE_2454_length_14543_cov_0.914428    6.109425  -4.138826
# SuperContig_NODE_2392_length_14699_cov_0.388973   43.982422  19.356365
# SuperContig_NODE_2413_length_14648_cov_0.518592   26.646776  51.142830
# SuperContig_NODE_849_length_22142_cov_0.260445     2.164459 -42.138828
# SuperContig_NODE_2310_length_14983_cov_0.353332    3.404237  49.819153
# SuperContig_NODE_601_length_25061_cov_4.23356     22.542980 -57.483318
#
#                                                      x_PC78     y_PC78  \
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179    20.450151 -10.392942
# SuperContig_NODE_2002_length_15947_cov_0.98025    12.555349 -20.258966
# SuperContig_NODE_1248_length_19278_cov_2.04802   -44.667183  18.984222
# SuperContig_NODE_3562_length_12278_cov_0.503079   22.795389 -15.269758
# SuperContig_NODE_2462_length_14531_cov_2.80592    12.009456  16.536842
# SuperContig_NODE_324_length_29524_cov_1.29003     66.555328  -9.188148
# SuperContig_NODE_2872_length_13506_cov_0.220631  -44.249241  19.199047
# SuperContig_NODE_691_length_23859_cov_3.17386     15.477975   4.171622
# SuperContig_NODE_2172_length_15382_cov_0.531048   40.289154  -1.462828
# SuperContig_NODE_2102_length_15618_cov_0.338359   64.130051 -31.420069
# SuperContig_NODE_5241_length_10240_cov_0.308155  -14.348475  34.582680
# SuperContig_NODE_4882_length_10600_cov_0.369489  -31.617863 -60.666290
# SuperContig_NODE_2775_length_13736_cov_1.32595   -37.018017 -37.947369
# SuperContig_NODE_2529_length_14344_cov_1.51716   -57.313862 -22.154741
# SuperContig_NODE_2408_length_14660_cov_0.0852963   2.640240 -77.574127
# SuperContig_NODE_1498_length_17972_cov_2.74436   -44.728558   2.100045
# SuperContig_NODE_2034_length_15828_cov_0.182974   -8.356261  58.552357
# SuperContig_NODE_1414_length_18339_cov_2.79282    55.652084  20.171688
# SuperContig_NODE_3098_length_13073_cov_0.346077   31.554287 -10.268003
# SuperContig_NODE_3697_length_12059_cov_4.6592     30.563217 -32.698963
# SuperContig_NODE_1578_length_17539_cov_0.177867   19.946177  41.416100
# SuperContig_NODE_4145_length_11432_cov_1.61114    -2.076846  47.176136
# SuperContig_NODE_2526_length_14349_cov_0.861754   -9.495353 -37.945549
# SuperContig_NODE_1654_length_17231_cov_1.83849   -30.814165  24.292795
# SuperContig_NODE_4059_length_11557_cov_1.20099   -15.005506  -2.253950
# SuperContig_NODE_2404_length_14669_cov_0.105422  -39.477180  52.148777
# SuperContig_NODE_991_length_21052_cov_1.10385     17.046728 -37.894867
# SuperContig_NODE_628_length_24559_cov_0.203352    33.398746  51.883095
# SuperContig_NODE_5084_length_10402_cov_2.19383    15.477975   4.171622
# SuperContig_NODE_418_length_27712_cov_0.61366    -22.220154  42.639969
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377     -17.976625 -68.895889
# SuperContig_NODE_102_length_40046_cov_0.322202    18.221304  55.032421
# SuperContig_NODE_3406_length_12532_cov_1.32928   -27.590149 -11.393701
# SuperContig_NODE_3627_length_12179_cov_0.183113   47.811932  27.039967
# SuperContig_NODE_4486_length_11032_cov_0.242751  -43.905052  38.461613
# SuperContig_NODE_2044_length_15774_cov_0.391005   13.030644 -36.786236
# SuperContig_NODE_1966_length_16062_cov_0.638226   22.837971 -14.785021
# SuperContig_NODE_436_length_27245_cov_4.30067    -48.361961 -18.464012
# SuperContig_NODE_4703_length_10795_cov_0.636593    4.676891  25.532047
# SuperContig_NODE_3515_length_12354_cov_0.451326   -5.064322   0.540047
# SuperContig_NODE_4938_length_10545_cov_0.650584  -18.098511 -16.968250
# SuperContig_NODE_1041_length_20745_cov_0.88235     5.716785  -3.898600
# SuperContig_NODE_510_length_26197_cov_0.734884   -40.919403  34.714890
# SuperContig_NODE_1438_length_18200_cov_0.36893    34.548199  52.960194
# SuperContig_NODE_4757_length_10739_cov_0.465414  -17.699661  24.715940
# SuperContig_NODE_1765_length_16743_cov_4.69911   -44.512825   5.721945
# SuperContig_NODE_4552_length_10973_cov_1.08295    12.070056  16.458981
# SuperContig_NODE_423_length_27530_cov_0.657103    24.728178 -69.735611
# SuperContig_NODE_2879_length_13488_cov_0.570244   31.403889  31.457020
# SuperContig_NODE_4804_length_10687_cov_0.404892    2.627242 -29.446682
# SuperContig_NODE_1970_length_16048_cov_2.07963   -26.888210 -12.064564
# SuperContig_NODE_4584_length_10928_cov_2.18626    -5.107790  17.071566
# SuperContig_NODE_4438_length_11080_cov_0.635917   -9.028434  21.412264
# SuperContig_NODE_4599_length_10911_cov_6.43331   -58.441711  -8.752148
# SuperContig_NODE_2454_length_14543_cov_0.914428   -7.165433 -20.820093
# SuperContig_NODE_2392_length_14699_cov_0.388973  -27.765612 -25.473627
# SuperContig_NODE_2413_length_14648_cov_0.518592   -2.422191  35.855679
# SuperContig_NODE_849_length_22142_cov_0.260445   -35.709301 -36.023750
# SuperContig_NODE_2310_length_14983_cov_0.353332   18.650702  -8.022782
# SuperContig_NODE_601_length_25061_cov_4.23356    -58.834824 -22.599129
#
#                                                     x_PC113    y_PC113
# Unnamed: 0
# SuperContig_NODE_1352_length_18628_cov_1.96179    13.219214 -14.143561
# SuperContig_NODE_2002_length_15947_cov_0.98025     9.483404 -42.488495
# SuperContig_NODE_1248_length_19278_cov_2.04802   -52.878380 -29.631920
# SuperContig_NODE_3562_length_12278_cov_0.503079   19.851082 -12.044785
# SuperContig_NODE_2462_length_14531_cov_2.80592    44.526695 -14.477378
# SuperContig_NODE_324_length_29524_cov_1.29003    -36.446411 -34.064594
# SuperContig_NODE_2872_length_13506_cov_0.220631  -50.580170 -27.808689
# SuperContig_NODE_691_length_23859_cov_3.17386     31.553612  23.108351
# SuperContig_NODE_2172_length_15382_cov_0.531048   33.154331 -15.229227
# SuperContig_NODE_2102_length_15618_cov_0.338359   75.356300  14.683330
# SuperContig_NODE_5241_length_10240_cov_0.308155   -8.848772 -30.876961
# SuperContig_NODE_4882_length_10600_cov_0.369489   10.499362 -55.043022
# SuperContig_NODE_2775_length_13736_cov_1.32595    15.845676  59.572796
# SuperContig_NODE_2529_length_14344_cov_1.51716    33.709679  24.022341
# SuperContig_NODE_2408_length_14660_cov_0.0852963 -61.456783 -15.103989
# SuperContig_NODE_1498_length_17972_cov_2.74436    36.610985  10.019903
# SuperContig_NODE_2034_length_15828_cov_0.182974    0.750568 -36.156559
# SuperContig_NODE_1414_length_18339_cov_2.79282   -14.493509   8.770636
# SuperContig_NODE_3098_length_13073_cov_0.346077  -14.422053   8.635979
# SuperContig_NODE_3697_length_12059_cov_4.6592     17.026270 -32.174610
# SuperContig_NODE_1578_length_17539_cov_0.177867   33.617378  24.181824
# SuperContig_NODE_4145_length_11432_cov_1.61114    -4.784343  -2.623200
# SuperContig_NODE_2526_length_14349_cov_0.861754  -29.442448   4.384748
# SuperContig_NODE_1654_length_17231_cov_1.83849    39.172775 -36.400913
# SuperContig_NODE_4059_length_11557_cov_1.20099   -31.818920  -8.925555
# SuperContig_NODE_2404_length_14669_cov_0.105422   11.962744   3.926977
# SuperContig_NODE_991_length_21052_cov_1.10385     -0.293969 -12.015389
# SuperContig_NODE_628_length_24559_cov_0.203352    29.554651  39.962841
# SuperContig_NODE_5084_length_10402_cov_2.19383    60.058895  34.285904
# SuperContig_NODE_418_length_27712_cov_0.61366     56.879261 -16.431450
# ...                                                     ...        ...
# SuperContig_NODE_5129_length_10351_cov_0.377     -28.802097 -56.614918
# SuperContig_NODE_102_length_40046_cov_0.322202    15.016104  40.518715
# SuperContig_NODE_3406_length_12532_cov_1.32928   -12.497351  57.732391
# SuperContig_NODE_3627_length_12179_cov_0.183113  -17.728035  13.852474
# SuperContig_NODE_4486_length_11032_cov_0.242751   59.268791 -34.807411
# SuperContig_NODE_2044_length_15774_cov_0.391005    0.297141  -8.878734
# SuperContig_NODE_1966_length_16062_cov_0.638226   18.656342 -13.277485
# SuperContig_NODE_436_length_27245_cov_4.30067     44.963696   7.281892
# SuperContig_NODE_4703_length_10795_cov_0.636593  -22.392603 -38.473637
# SuperContig_NODE_3515_length_12354_cov_0.451326  -22.771755  -6.006464
# SuperContig_NODE_4938_length_10545_cov_0.650584   24.404112 -62.050446
# SuperContig_NODE_1041_length_20745_cov_0.88235    -5.312083  24.584387
# SuperContig_NODE_510_length_26197_cov_0.734884    53.469013 -38.499538
# SuperContig_NODE_1438_length_18200_cov_0.36893    29.673412  42.476433
# SuperContig_NODE_4757_length_10739_cov_0.465414  -14.563711 -45.279942
# SuperContig_NODE_1765_length_16743_cov_4.69911    34.077049   8.725884
# SuperContig_NODE_4552_length_10973_cov_1.08295    44.462425 -14.487307
# SuperContig_NODE_423_length_27530_cov_0.657103   -43.992435 -61.456154
# SuperContig_NODE_2879_length_13488_cov_0.570244   26.242350  22.320799
# SuperContig_NODE_4804_length_10687_cov_0.404892  -22.107264  44.275105
# SuperContig_NODE_1970_length_16048_cov_2.07963   -12.462366  56.758556
# SuperContig_NODE_4584_length_10928_cov_2.18626    -8.249513 -18.533878
# SuperContig_NODE_4438_length_11080_cov_0.635917    6.177184 -28.235327
# SuperContig_NODE_4599_length_10911_cov_6.43331    41.564877  17.778490
# SuperContig_NODE_2454_length_14543_cov_0.914428  -27.365269   3.393864
# SuperContig_NODE_2392_length_14699_cov_0.388973   19.527250 -33.747993
# SuperContig_NODE_2413_length_14648_cov_0.518592   24.417526  -2.488070
# SuperContig_NODE_849_length_22142_cov_0.260445    14.692562  57.896912
# SuperContig_NODE_2310_length_14983_cov_0.353332   11.025497 -13.335013
# SuperContig_NODE_601_length_25061_cov_4.23356     57.193558  -1.077696
#
# [5039 rows x 26 columns]

# %%
import checkm_out as co

# %%
WDminithres = co.make_checkm_output_df('Permafrost/WestDock/checkm/','WDminiThres')
# Out:
# /home/bojk/Data/minimeta_pyfiles/checkm_out.py:41: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   strhet = pd.read_table(indir+'outputfile.txt')

# %%
WDminithres[(WDminithres['Completeness']>40)&(WDminithres['Contamination']<5)&(WDminithres['Strain heterogeneity']<5)]
# Out:
#                                             marker lineage Completeness  \
# 0
# WestDock_miniPC55_bin_035                      k__Bacteria      56.4263
# WestDock_miniPC26_bin_063                      k__Bacteria       50.125
# WestDock_miniPC38_3kbthres_minCS90_bin_053     k__Bacteria      49.5768
# WestDock_miniPC18_3kbthres_minCS90_bin_069     k__Bacteria      44.8276
# WestDock_miniPC78_5kbthres_minCS70_bin_045     k__Bacteria      44.3574
# WestDock_miniPC13_3kbthres_minCS90_bin_037     k__Bacteria      43.8953
# WestDock_miniPC18_3kbthres_minCS90_bin_025     k__Bacteria        42.82
# WestDock_miniPC113_7kbthres_minCS50_bin_091    k__Bacteria      42.1348
# WestDock_miniPC13_5kbthres_minCS70_bin_007     k__Bacteria      42.1053
# WestDock_miniPC78_7kbthres_minCS50_bin_057     k__Bacteria       41.954
# WestDock_miniPC55_bin_021                      k__Bacteria      40.1116
# WestDock_miniPC38_3kbthres_minCS90_bin_008     k__Bacteria      40.1116
#
#                                             Contamination # contigs  \
# 0
# WestDock_miniPC55_bin_035                         3.44828       219
# WestDock_miniPC26_bin_063                         4.37158       218
# WestDock_miniPC38_3kbthres_minCS90_bin_053        3.44828       224
# WestDock_miniPC18_3kbthres_minCS90_bin_069              0       162
# WestDock_miniPC78_5kbthres_minCS70_bin_045        3.44828       198
# WestDock_miniPC13_3kbthres_minCS90_bin_037        4.30108       126
# WestDock_miniPC18_3kbthres_minCS90_bin_025        4.30108       127
# WestDock_miniPC113_7kbthres_minCS50_bin_091       1.68539       102
# WestDock_miniPC13_5kbthres_minCS70_bin_007        1.75439       147
# WestDock_miniPC78_7kbthres_minCS50_bin_057        3.44828       140
# WestDock_miniPC55_bin_021                               0       104
# WestDock_miniPC38_3kbthres_minCS90_bin_008              0       167
#
#                                             Genome size # genomes  \
# 0
# WestDock_miniPC55_bin_035                       2392153      5449
# WestDock_miniPC26_bin_063                       2434161       433
# WestDock_miniPC38_3kbthres_minCS90_bin_053      2271306      5449
# WestDock_miniPC18_3kbthres_minCS90_bin_069      2074807      5449
# WestDock_miniPC78_5kbthres_minCS70_bin_045      1901286      5449
# WestDock_miniPC13_3kbthres_minCS90_bin_037      1460551      2921
# WestDock_miniPC18_3kbthres_minCS90_bin_025      1441520      2921
# WestDock_miniPC113_7kbthres_minCS50_bin_091     1216973       174
# WestDock_miniPC13_5kbthres_minCS70_bin_007      1320669      5449
# WestDock_miniPC78_7kbthres_minCS50_bin_057      1912708      5449
# WestDock_miniPC55_bin_021                       1035112      5449
# WestDock_miniPC38_3kbthres_minCS90_bin_008      1547918      5449
#
#                                             # marker sets # markers  \
# 0
# WestDock_miniPC55_bin_035                              58       104
# WestDock_miniPC26_bin_063                             183       274
# WestDock_miniPC38_3kbthres_minCS90_bin_053             58       104
# WestDock_miniPC18_3kbthres_minCS90_bin_069             58       104
# WestDock_miniPC78_5kbthres_minCS70_bin_045             58       104
# WestDock_miniPC13_3kbthres_minCS90_bin_037             93       152
# WestDock_miniPC18_3kbthres_minCS90_bin_025             93       152
# WestDock_miniPC113_7kbthres_minCS50_bin_091            89       149
# WestDock_miniPC13_5kbthres_minCS70_bin_007             57       103
# WestDock_miniPC78_7kbthres_minCS50_bin_057             58       104
# WestDock_miniPC55_bin_021                              57       103
# WestDock_miniPC38_3kbthres_minCS90_bin_008             57       103
#
#                                             # predicted genes Coding density  \
# 0
# WestDock_miniPC55_bin_035                                2372       0.897848
# WestDock_miniPC26_bin_063                                2366       0.901981
# WestDock_miniPC38_3kbthres_minCS90_bin_053               2414       0.874176
# WestDock_miniPC18_3kbthres_minCS90_bin_069               1780        0.89889
# WestDock_miniPC78_5kbthres_minCS70_bin_045               1957       0.880029
# WestDock_miniPC13_3kbthres_minCS90_bin_037               1364       0.884606
# WestDock_miniPC18_3kbthres_minCS90_bin_025               1350       0.884106
# WestDock_miniPC113_7kbthres_minCS50_bin_091              1198       0.887788
# WestDock_miniPC13_5kbthres_minCS70_bin_007               1340       0.894572
# WestDock_miniPC78_7kbthres_minCS50_bin_057               1970       0.901637
# WestDock_miniPC55_bin_021                                1072       0.887342
# WestDock_miniPC38_3kbthres_minCS90_bin_008               1635       0.872677
#
#                                                    GC     GC std  \
# 0
# WestDock_miniPC55_bin_035                    0.401672   0.052656
# WestDock_miniPC26_bin_063                    0.383419  0.0480741
# WestDock_miniPC38_3kbthres_minCS90_bin_053   0.459963  0.0613036
# WestDock_miniPC18_3kbthres_minCS90_bin_069   0.392803  0.0291754
# WestDock_miniPC78_5kbthres_minCS70_bin_045   0.406805  0.0576411
# WestDock_miniPC13_3kbthres_minCS90_bin_037   0.408494  0.0534792
# WestDock_miniPC18_3kbthres_minCS90_bin_025    0.40749  0.0538905
# WestDock_miniPC113_7kbthres_minCS50_bin_091  0.368388  0.0748492
# WestDock_miniPC13_5kbthres_minCS70_bin_007   0.415129  0.0613122
# WestDock_miniPC78_7kbthres_minCS50_bin_057   0.414705  0.0491068
# WestDock_miniPC55_bin_021                    0.435128  0.0622048
# WestDock_miniPC38_3kbthres_minCS90_bin_008   0.426667  0.0624296
#
#                                             Longest contig Mean contig length  \
# 0
# WestDock_miniPC55_bin_035                            49729            10923.1
# WestDock_miniPC26_bin_063                            39794            11165.9
# WestDock_miniPC38_3kbthres_minCS90_bin_053           69309            10139.8
# WestDock_miniPC18_3kbthres_minCS90_bin_069           48244            12807.5
# WestDock_miniPC78_5kbthres_minCS70_bin_045           49729            9602.45
# WestDock_miniPC13_3kbthres_minCS90_bin_037           62572            11591.7
# WestDock_miniPC18_3kbthres_minCS90_bin_025           62572            11350.6
# WestDock_miniPC113_7kbthres_minCS50_bin_091          29605            11931.1
# WestDock_miniPC13_5kbthres_minCS70_bin_007           40080            8984.14
# WestDock_miniPC78_7kbthres_minCS50_bin_057           59460            13662.2
# WestDock_miniPC55_bin_021                            41426               9953
# WestDock_miniPC38_3kbthres_minCS90_bin_008           41426            9268.97
#
#                                             N50 (contigs)  \
# 0
# WestDock_miniPC55_bin_035                           12255
# WestDock_miniPC26_bin_063                           12477
# WestDock_miniPC38_3kbthres_minCS90_bin_053          10478
# WestDock_miniPC18_3kbthres_minCS90_bin_069          15624
# WestDock_miniPC78_5kbthres_minCS70_bin_045           9915
# WestDock_miniPC13_3kbthres_minCS90_bin_037          13305
# WestDock_miniPC18_3kbthres_minCS90_bin_025          13098
# WestDock_miniPC113_7kbthres_minCS50_bin_091         12113
# WestDock_miniPC13_5kbthres_minCS70_bin_007           8954
# WestDock_miniPC78_7kbthres_minCS50_bin_057          15322
# WestDock_miniPC55_bin_021                           11024
# WestDock_miniPC38_3kbthres_minCS90_bin_008           9967
#
#                                              Strain heterogeneity
# 0
# WestDock_miniPC55_bin_035                                     0.0
# WestDock_miniPC26_bin_063                                     0.0
# WestDock_miniPC38_3kbthres_minCS90_bin_053                    0.0
# WestDock_miniPC18_3kbthres_minCS90_bin_069                    0.0
# WestDock_miniPC78_5kbthres_minCS70_bin_045                    0.0
# WestDock_miniPC13_3kbthres_minCS90_bin_037                    0.0
# WestDock_miniPC18_3kbthres_minCS90_bin_025                    0.0
# WestDock_miniPC113_7kbthres_minCS50_bin_091                   0.0
# WestDock_miniPC13_5kbthres_minCS70_bin_007                    0.0
# WestDock_miniPC78_7kbthres_minCS50_bin_057                    0.0
# WestDock_miniPC55_bin_021                                     0.0
# WestDock_miniPC38_3kbthres_minCS90_bin_008                    0.0

# %%
WDminithres['marker lineage'].value_counts()
# Out:
# k__Bacteria               2758
# o__Clostridiales           135
# root                       122
# p__Bacteroidetes           111
# c__Deltaproteobacteria      92
# k__Archaea                  73
# p__Euryarchaeota            58
# p__Firmicutes               20
# o__Bacteroidales            12
# c__Clostridia                3
# c__Spirochaetia              3
# Name: marker lineage, dtype: int64

# %%
WDminithres['new_idx'] = [f.split('_')[0]+'_'+f.split('_')[1]+'_'+'0kbthres_minCS100_bin_'+f.split('_')[-1] if len(f.split('_'))==4 else f for f in WDminithres.index]

# %%
WDminithres['PCs'] = [f.split('_')[1].split('C')[1] for f in WDminithres['new_idx']]
WDminithres['Threshold'] = [f.split('_')[2][:-5] for f in WDminithres['new_idx']]
WDminithres['Completeness'] = WDminithres['Completeness'].astype(float)
WDminithres['Contamination'] = WDminithres['Contamination'].astype(float)
WDminithres.groupby(['PCs','Threshold']).mean()
# Out:
#                Completeness  Contamination  Strain heterogeneity
# PCs Threshold
# 113 10kb          21.275725       3.367603             14.095543
#     3kb           35.582103      10.967986             17.208556
#     5kb           33.024624       9.267274             16.444124
#     7kb           28.956575       6.164334             14.838587
# 13  0kb           35.913934      10.469838             18.172911
#     10kb          19.854316       3.201011             11.102105
#     3kb           32.927138      10.226385             15.680000
#     5kb           32.191234       9.764311              9.708723
#     7kb           26.884472       5.878499              9.333011
# 18  0kb           35.639117      10.682469             18.544483
#     10kb          19.370270       2.943323             12.747097
#     3kb           35.629657      10.878327             15.293059
#     5kb           29.874220       7.579772             13.225300
#     7kb           28.260992       6.912744              9.200000
# 26  0kb           36.815711      10.711461             16.839759
#     10kb          21.094357       3.354000             10.947143
#     3kb           37.273721      12.692551             14.744750
#     5kb           30.718421       8.979942             14.034490
#     7kb           28.316766       7.158658              9.969659
# 38  0kb           36.476006      11.669637             19.426988
#     10kb          21.209408       3.576702             11.647444
#     3kb           36.479146      11.569036             15.278415
#     5kb           32.674888      10.314754             11.945955
#     7kb           28.787317       7.617075              9.815568
# 55  0kb           34.679192       9.841693             16.558434
#     10kb          21.965929       3.920586             13.100000
#     3kb           38.478565      11.793959             18.166250
#     5kb           33.952002      10.276271             11.495385
#     7kb           30.112914       7.309837             11.532045
# 78  0kb           34.003507      10.549070             16.644118
#     10kb          22.247549       3.329196             14.245909
#     3kb           38.021316      11.813852             17.722410
#     5kb           33.372098       9.509826             13.480323
#     7kb           30.168175       6.837912             12.361023
# 9   10kb          19.830811       3.254548             11.785000
#     3kb           32.649573       8.647525             12.125111
#     5kb           30.189321       8.366957             12.996900
#     7kb           27.856324       6.834361             10.522247

# %%
pc = '13'
def plot_dens(df,PC):
    f,ax = plt.subplots(3,1,figsize=(6,15))
    temp = df[df['PCs']==PC]
    temp[temp['Threshold']=='0kb']['Completeness'].plot.density(label='0kb',ax=ax[0])
    temp[temp['Threshold']=='3kb']['Completeness'].plot.density(label='3kb',ax=ax[0])
    temp[temp['Threshold']=='5kb']['Completeness'].plot.density(label='5kb',ax=ax[0])
    temp[temp['Threshold']=='7kb']['Completeness'].plot.density(label='7kb',ax=ax[0])
    temp[temp['Threshold']=='10kb']['Completeness'].plot.density(label='10kb',ax=ax[0])
    ax[0].set_title('Completeness')
    ax[0].legend()
    
    temp[temp['Threshold']=='0kb']['Contamination'].plot.density(label='0kb',ax=ax[1])
    temp[temp['Threshold']=='3kb']['Contamination'].plot.density(label='3kb',ax=ax[1])
    temp[temp['Threshold']=='5kb']['Contamination'].plot.density(label='5kb',ax=ax[1])
    temp[temp['Threshold']=='7kb']['Contamination'].plot.density(label='7kb',ax=ax[1])
    temp[temp['Threshold']=='10kb']['Contamination'].plot.density(label='10kb',ax=ax[1])
    ax[1].set_title('Contamination')    
    ax[1].legend()
    temp[temp['Threshold']=='0kb']['Strain heterogeneity'].plot.density(label='0kb',ax=ax[2])
    temp[temp['Threshold']=='3kb']['Strain heterogeneity'].plot.density(label='3kb',ax=ax[2])
    temp[temp['Threshold']=='5kb']['Strain heterogeneity'].plot.density(label='5kb',ax=ax[2])
    temp[temp['Threshold']=='7kb']['Strain heterogeneity'].plot.density(label='7kb',ax=ax[2])
    temp[temp['Threshold']=='10kb']['Strain heterogeneity'].plot.density(label='10kb',ax=ax[2])
    ax[2].set_title('Strain heterogeneity')
    ax[2].legend()
    plt.suptitle('PC number '+PC)
    plt.show()
    

def plot_dens_thres(df,thres):
    pcs = list(df.PCs.unique())
    f,ax = plt.subplots(3,2,figsize=(6,15))
    ax = ax.ravel()
    temp = df[df['Threshold']==thres]
    for p in pcs:
        temp[temp['PCs']==p]['Completeness'].plot.density(label=p+'PCs',ax=ax[0])
        temp[temp['PCs']==p]['Contamination'].plot.density(label=p+'PCs',ax=ax[2])
        temp[temp['PCs']==p]['Strain heterogeneity'].plot.density(label=p+'PCs',ax=ax[4])
        temp[temp['PCs']==p]['Completeness'].boxplot(label=p+'PCs',ax=ax[1])
    
    ax[0].set_title('Completeness')
    ax[0].legend()
    ax[1].set_title('Contamination')    
    ax[1].legend()
    ax[2].set_title('Strain heterogeneity')
    ax[2].legend()
    plt.suptitle('Threshold '+thres)
    plt.show()

# %%
#test.pivot_table(values='Completeness', index=test.index, columns='PCs', aggfunc='first')
test = WDminithres[WDminithres.Threshold=='5kb']
test2 = WDminithres[WDminithres.PCs=='13']
df = test.pivot(index=test.index,columns='PCs')['Contamination']
a = test.PCs.unique()
a = [int(f) for f in a]
a.sort()
a = [str(f) for f in a]
df[a].boxplot()

# %%
sns.violinplot(x='PCs',y='Completeness',data=test)

# %%
sns.violinplot(x='PCs',y='Contamination',data=test)

# %%
sns.violinplot(x='PCs',y='Strain heterogeneity',data=test)

# %%
import sinaplot as sin

# %%
sin.sinaplot(x='PCs',y='Completeness',data=test,point_facealpha=.5,inner='box',linewidth=2)

# %%
order=['0kb', '3kb', '5kb', '7kb', '10kb']
sin.sinaplot(x='Threshold',y='Completeness',data=test2,point_facealpha=.5,order=order,inner='box',linewidth=2)

# %%
sin.sinaplot(x='Threshold',y='Contamination',data=test2,point_facealpha=.5,order=order,inner='box',linewidth=2)

# %%
sin.sinaplot(x='Threshold',y='Strain heterogeneity',data=test2,point_facealpha=.5,order=order,inner='box',linewidth=2)

# %%
plot_dens(WDminithres,pc)

# %%
pc='78'
plot_dens(WDminithres,pc)

# %%
thres = '3kb'
plot_dens_thres(WDminithres,thres)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a0839af47516> in <module>
#       1 thres = '3kb'
# ----> 2 plot_dens_thres(WDminithres,thres)
#
# <ipython-input-22-1605a6c7e9a8> in plot_dens_thres(df, thres)
#      38         temp[temp['PCs']==p]['Contamination'].plot.density(label=p+'PCs',ax=ax[2])
#      39         temp[temp['PCs']==p]['Strain heterogeneity'].plot.density(label=p+'PCs',ax=ax[4])
# ---> 40         temp[temp['PCs']==p]['Completeness'].boxplot(label=p+'PCs',ax=ax[1])
#      41
#      42     ax[0].set_title('Completeness')
#
# ~/miniconda3/envs/py360/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'boxplot'
