# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import os
os.chdir('/home/bojk/Data/') #this is when opened in '/home/bojk/Data/notebooks' on linux Quakelab
#os.chdir('/Users/bojk/Google Drive/QuakeLab/Data/')
import sys
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
sys.path.append('/Users/bojk/Google Drive/QuakeLab/minimeta_pyfiles/')
import imp
import HTSeq
from scipy.stats import powerlaw
#import minimetagenome_analysis as minimeta

import mock_metagenome_creation as mock
imp.reload(mock)
#import reassembly as rea
#import subcluster_bins as sub
#import checkm_out_plot as cop
#import checkm_out as co

import matplotlib as mpl
mpl.rcParams['axes.labelsize'] = 15
mpl.rcParams['xtick.labelsize'] = 15
mpl.rcParams['ytick.labelsize'] = 15
mpl.rcParams['axes.titlesize'] = 15
mpl.rcParams['figure.titlesize'] = 18
mpl.rcParams['legend.fontsize'] = 14

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
metagenome_fasta = '/home/datastorage/ASSEMBLY_DATA/PermafrostFranklinBluffs/Combined_Analysis/super_contigs.PermafrostFranklinBluffs.fasta'
save_dir = 'Permafrost/FranklinBluffs/pickles/'

# %%
imp.reload(mock)
contig7mer,k7mer = mock.make_kmertable_from_fasta_contigs(metagenome_fasta,7,save_dir)
# Out:
# Total number of fasta sequences:16985
# ----------------------------------------------------
# Started collecting kmers, dimensionality = 16384
# Local time: 11:17
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 500 contigs out of 16985 done, took 3035.29 s
# Progress: 2.94 %, local time: 12:7
# Total elapsed time is 50.60 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 1000 contigs out of 16985 done, took 2990.06 s
# Progress: 5.89 %, local time: 12:57
# Total elapsed time is 100.44 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 1500 contigs out of 16985 done, took 2959.87 s
# Progress: 8.83 %, local time: 13:47
# Total elapsed time is 149.77 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 2000 contigs out of 16985 done, took 2978.53 s
# Progress: 11.78 %, local time: 14:36
# Total elapsed time is 199.42 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 2500 contigs out of 16985 done, took 3111.53 s
# Progress: 14.72 %, local time: 15:28
# Total elapsed time is 251.29 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 3000 contigs out of 16985 done, took 3223.08 s
# Progress: 17.66 %, local time: 16:22
# Total elapsed time is 305.02 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 3500 contigs out of 16985 done, took 3265.65 s
# Progress: 20.61 %, local time: 17:16
# Total elapsed time is 359.46 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 4000 contigs out of 16985 done, took 3176.40 s
# Progress: 23.55 %, local time: 18:9
# Total elapsed time is 412.42 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 4500 contigs out of 16985 done, took 2939.50 s
# Progress: 26.49 %, local time: 18:58
# Total elapsed time is 461.43 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 5000 contigs out of 16985 done, took 2955.21 s
# Progress: 29.44 %, local time: 19:47
# Total elapsed time is 510.71 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 5500 contigs out of 16985 done, took 2817.62 s
# Progress: 32.38 %, local time: 20:34
# Total elapsed time is 557.70 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 6000 contigs out of 16985 done, took 2860.76 s
# Progress: 35.33 %, local time: 21:22
# Total elapsed time is 605.41 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 6500 contigs out of 16985 done, took 2833.15 s
# Progress: 38.27 %, local time: 22:9
# Total elapsed time is 652.67 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 7000 contigs out of 16985 done, took 2871.34 s
# Progress: 41.21 %, local time: 22:57
# Total elapsed time is 700.56 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 7500 contigs out of 16985 done, took 2896.88 s
# Progress: 44.16 %, local time: 23:46
# Total elapsed time is 748.89 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 8000 contigs out of 16985 done, took 2898.28 s
# Progress: 47.1 %, local time: 0:34
# Total elapsed time is 797.24 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 8500 contigs out of 16985 done, took 2915.49 s
# Progress: 50.04 %, local time: 1:23
# Total elapsed time is 845.88 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 9000 contigs out of 16985 done, took 2906.44 s
# Progress: 52.99 %, local time: 2:11
# Total elapsed time is 894.37 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 9500 contigs out of 16985 done, took 2911.58 s
# Progress: 55.93 %, local time: 3:0
# Total elapsed time is 942.95 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 10000 contigs out of 16985 done, took 2911.09 s
# Progress: 58.88 %, local time: 3:48
# Total elapsed time is 991.53 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 10500 contigs out of 16985 done, took 2918.71 s
# Progress: 61.82 %, local time: 4:37
# Total elapsed time is 1040.24 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 11000 contigs out of 16985 done, took 2910.50 s
# Progress: 64.76 %, local time: 5:26
# Total elapsed time is 1088.81 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 11500 contigs out of 16985 done, took 2918.66 s
# Progress: 67.71 %, local time: 6:14
# Total elapsed time is 1137.52 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 12000 contigs out of 16985 done, took 2944.01 s
# Progress: 70.65 %, local time: 7:3
# Total elapsed time is 1186.66 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 12500 contigs out of 16985 done, took 2928.87 s
# Progress: 73.59 %, local time: 7:52
# Total elapsed time is 1235.55 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 13000 contigs out of 16985 done, took 2908.85 s
# Progress: 76.54 %, local time: 8:41
# Total elapsed time is 1284.11 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 13500 contigs out of 16985 done, took 2891.57 s
# Progress: 79.48 %, local time: 9:29
# Total elapsed time is 1332.39 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 14000 contigs out of 16985 done, took 2997.33 s
# Progress: 82.43 %, local time: 10:19
# Total elapsed time is 1382.43 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 14500 contigs out of 16985 done, took 3162.75 s
# Progress: 85.37 %, local time: 11:12
# Total elapsed time is 1435.23 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 15000 contigs out of 16985 done, took 3260.41 s
# Progress: 88.31 %, local time: 12:6
# Total elapsed time is 1489.66 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 15500 contigs out of 16985 done, took 3248.35 s
# Progress: 91.26 %, local time: 13:1
# Total elapsed time is 1543.90 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 16000 contigs out of 16985 done, took 3325.41 s
# Progress: 94.2 %, local time: 13:56
# Total elapsed time is 1599.42 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 16500 contigs out of 16985 done, took 3329.57 s
# Progress: 97.14 %, local time: 14:52
# Total elapsed time is 1655.01 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 17000 contigs out of 16985 done, took 3326.71 s
# Progress: 100.09 %, local time: 15:47
# Total elapsed time is 1710.56 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 17500 contigs out of 16985 done, took 3348.37 s
# Progress: 103.03 %, local time: 16:43
# Total elapsed time is 1766.48 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 18000 contigs out of 16985 done, took 3405.69 s
# Progress: 105.98 %, local time: 17:40
# Total elapsed time is 1823.36 minutes
# Saving current contig kmers to pickle...
# relative path = Permafrost/FranklinBluffs/pickles/kmerdf_from_metagenome_fasta_7mer_incomplete.pickle
# ----------------------------------------------------

# %%
k6mer.head()
