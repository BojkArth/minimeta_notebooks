# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import os
os.chdir('/home/bojk/Data/') #this is when opened in '/home/bojk/Data/notebooks' on linux Quakelab
import sys
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
import imp
import HTSeq
from scipy.stats import powerlaw
#import minimetagenome_analysis as minimet
import mock_metagenome_creation as mock

# %%
imp.reload(mock)
maindir = "Mock/Archaea_illuminaHS_low<20contigs/"
meta = pd.read_pickle('Permafrost/FranklinBluffs/pickles/maindf_withDepth')
data = list(meta['Sequence Length'])

stats,contigs,kmers = mock.fragment_genomes_make_kmertable(maindir,data,5,'_feb15')
# Out:
# Collecting kmers for genome 2681812914 took 191.54 s
# Collecting kmers for genome 2778260947 took 197.68 s
# Collecting kmers for genome 2510065051 took 167.06 s
# Collecting kmers for genome 2636416047 took 191.11 s
# Collecting kmers for genome 2642422537 took 105.15 s
# Collecting kmers for genome 2617270917 took 159.93 s
# Collecting kmers for genome 2565956510 took 95.62 s
# Collecting kmers for genome 2619618990 took 208.92 s
# Collecting kmers for genome 2517093008 took 50.45 s
# Collecting kmers for genome 2617270898 took 124.64 s
# Collecting kmers for genome 2816332110 took 182.21 s
# Collecting kmers for genome 2579779151 took 86.80 s
# Collecting kmers for genome 2756170388 took 80.71 s
# Collecting kmers for genome 2619618869 took 178.40 s
# Collecting kmers for genome 2639762563 took 205.63 s
# Collecting kmers for genome 2517287024 took 208.11 s
# Collecting kmers for genome 2786546169 took 80.78 s
# Collecting kmers for genome 2617270902 took 194.65 s
# Collecting kmers for genome 2642422606 took 103.49 s
# Collecting kmers for genome 2619618938 took 186.43 s
# Collecting kmers for genome 2636416021 took 230.89 s
# Collecting kmers for genome 2728369221 took 140.99 s
# Collecting kmers for genome 2757320366 took 71.09 s
# Collecting kmers for genome 2571042922 took 113.25 s
# Collecting kmers for genome 2681812915 took 202.92 s
# Collecting kmers for genome 2617270895 took 158.36 s
# Collecting kmers for genome 2654588138 took 110.72 s
# Collecting kmers for genome 2617270925 took 173.27 s
# Collecting kmers for genome 2698536698 took 230.35 s
# Collecting kmers for genome 646311934 took 250.14 s
# Collecting kmers for genome 2671180170 took 243.58 s
# Collecting kmers for genome 2671180169 took 175.51 s
# Collecting kmers for genome 2642422561 took 145.84 s
# Collecting kmers for genome 2636416066 took 267.02 s
# Collecting kmers for genome 2667527389 took 187.30 s
# Collecting kmers for genome 2654588132 took 108.41 s
# Collecting kmers for genome 2617270920 took 194.79 s
# Collecting kmers for genome 2617270732 took 134.26 s
# Collecting kmers for genome 2582580744 took 172.30 s
# Collecting kmers for genome 2695420988 took 187.16 s
# Collecting kmers for genome 2617270915 took 136.36 s
# Collecting kmers for genome 2642422540 took 154.41 s
# Collecting kmers for genome 2639762573 took 215.90 s
# Constructing mock metagenome from Mock/Archaea_illuminaHS_low<20contigs/
#  with kmer = 5 took 7004.27 s

# %%
imp.reload(mock)
contig6mer,k6mer = mock.make_kmertable_from_fasta_contigs(maindir+'metagenome_from_allgenomes__feb15.fasta',6,maindir+'stats/')
# Out:
# Constructing 6-mer table from metagenome_from_allgenomes__feb15.fasta took 24560.13 s

# 2681812914_contig_001  0.000122911  0.000122911  0.000245821  0.000368732
# 2681812914_contig_002            0            0            0            0
# 2681812914_contig_003  0.000175685   0.00035137   0.00035137            0
# 2681812914_contig_004  0.000325256            0  0.000162628            0
#
#                             GGGGTG       GGGGGA       GGGGGC       GGGGGT  \
# 2681812914_contig_000  8.77886e-05  8.77886e-05            0  0.000175577
# 2681812914_contig_001  0.000122911  0.000122911            0  0.000368732
# 2681812914_contig_002  0.000144571  0.000578285  0.000144571            0
# 2681812914_contig_003   0.00035137  0.000175685            0  0.000175685
# 2681812914_contig_004            0            0            0            0
#
#                             GGGGGG
# 2681812914_contig_000            0
# 2681812914_contig_001  0.000122911
# 2681812914_contig_002            0
# 2681812914_contig_003            0
# 2681812914_contig_004            0
#
# [5 rows x 4096 columns]

# %%
frac0 = (k6mer_norm == 0).sum(axis=0).divide(len(k6mer_norm)).sort_values()

# %%
most_abundant = frac0[frac0<.2].index
len(most_abundant)
# Out:
# 992

# %%
var6 = k6mer_norm.var().sort_values()

# %%
most_variable = var6[-992:].index

# %%
len(set(most_abundant).intersection(most_variable))
# Out:
# 714

# %%
len(set(list(most_abundant)+list(most_variable)))
# Out:
# 1270

# %% [markdown]
# # tSNE most_ab most_var kmers

# %%
clusterlist = list(set(list(most_abundant)+list(most_variable)))

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
x = StandardScaler().fit_transform(k6mer_norm[clusterlist])
# Out:
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype object were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
x_emb = TSNE(n_components=2,perplexity=40,random_state=23944).fit_transform(x)

# %%
tsne = pd.DataFrame(x_emb,index=k6mer_norm.index)
tsne = tsne.join(contig6mer['Sequence length'])
tsne = tsne.join(contig6mer['GC'])
tsne['genome'] = [f.split('_')[0] for f in tsne.index]

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
plt.scatter(tsne[0],tsne[1],s=tsne['Sequence length'].astype(float)/100,alpha=.05,c=tsne['GC'],cmap='RdBu_r')

# %%
keys = tsne['genome'].unique()
values = sns.color_palette('husl',len(tsne['genome'].unique()))
lut = dict(zip(keys,values))
color = tsne.genome.map(lut)

f,ax = plt.subplots(1,1,figsize=(10,10))
plt.scatter(tsne[0],tsne[1],s=tsne['Sequence length'].astype(float)/100,alpha=.05,color=color)

# %% [markdown]
# # tSNE all kmers

# %%
x = StandardScaler().fit_transform(k6mer_norm)
# Out:
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype object were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype object were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
x_emb_all = TSNE(n_components=2,perplexity=40,random_state=23944).fit_transform(x)

# %%
tsne = pd.DataFrame(x_emb_all,index=k6mer_norm.index)
tsne = tsne.join(contig6mer['Sequence length'])
tsne = tsne.join(contig6mer['GC'])
tsne['genome'] = [f.split('_')[0] for f in tsne.index]

# %%
f,ax = plt.subplots(1,1,figsize=(10,10))
plt.scatter(tsne[0],tsne[1],s=tsne['Sequence length'].astype(float)/100,alpha=.05,c=tsne['GC'],cmap='RdBu_r')

# %%
keys = tsne['genome'].unique()
values = sns.color_palette('husl',len(tsne['genome'].unique()))
lut = dict(zip(keys,values))
color = tsne.genome.map(lut)

f,ax = plt.subplots(1,1,figsize=(10,10))
plt.scatter(tsne[0],tsne[1],s=tsne['Sequence length'].astype(float)/100,alpha=.05,color=color)
