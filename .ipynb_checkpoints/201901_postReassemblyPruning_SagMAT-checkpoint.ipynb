# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import os
#os.chdir('../') #this is when opened in '/home/bojk/Data/notebooks' on linux Quakelab
import sys
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
import imp
import minimetagenome_analysis as minimeta
#imp.reload(minimeta)

import reassembly as rea
import subcluster_bins as sub
import checkm_out_plot as cop
import checkm_out as co

# %% [markdown]
# this is a continuation (& cleaned up version of 201810_permafrost_analysis)
# where I continue with post reassembly pruning

# %% [markdown]
# # SagMAT version

# %%
# %pwd
# Out:
# '/home/bojk/Data'

# %%
expt_name = 'SagMAT'

# %%
imp.reload(rea)
#readf = None
SMreadf = rea.make_CS_df_new_index('Permafrost/SagMAT/bins/fasta/reassembly/')#linux
#FBreadf = rea.make_CS_df_new_index('Permafrost/FranklinBluffs/reassembly_files/')#mac
SMreadf5kb = SMreadf[SMreadf['length_linecount']>=5e3]
# Out:
# No numeric data for bin 004, heading on to next.
# Added read count and saved, time elapsed (hh:mm:ss.ms) 0:03:32.285463
# 8052 contigs above 5kb for reassembled SagMAT

# %%
SMreadf5kb.groupby('Bin').sum()['length_from_fasta'].sort_values(ascending=False)
# Out:
# Bin
# 056    3978386.0
# 048    3839433.0
# 065    3224892.0
# 033    3114789.0
# 041    2892102.0
# 023    2850000.0
# 069    2843256.0
# 061    2242012.0
# 049    2145703.0
# 042    2006401.0
# 047    1853013.0
# 043    1841483.0
# 039    1798022.0
# 054    1623784.0
# 011    1577787.0
# 014    1500135.0
# 034    1440309.0
# 058    1413267.0
# 000    1340084.0
# 008    1249740.0
# 059    1215279.0
# 036    1187087.0
# 006    1182034.0
# 045    1181938.0
# 052    1116724.0
# 055    1112401.0
# 062    1056519.0
# 060    1048349.0
# 030    1040655.0
# 068    1020755.0
#          ...
# 021     802688.0
# 038     796018.0
# 015     786561.0
# 026     740253.0
# 040     723545.0
# 050     704056.0
# 029     699003.0
# 037     692117.0
# 025     654525.0
# 031     641736.0
# 053     612132.0
# 064     569007.0
# 035     565134.0
# 022     395841.0
# 016     383910.0
# 007     355330.0
# 046     332241.0
# 018     200050.0
# 010     131443.0
# 009      77688.0
# 013      67916.0
# 012      53431.0
# 005      52310.0
# 020      41821.0
# 003      34345.0
# 017      31168.0
# 028      26694.0
# 027      16472.0
# 002      12394.0
# 019      11824.0
# Name: length_from_fasta, Length: 68, dtype: float64

# %%
len(SMreadf5kb)
# Out:
# 8052

# %%
len(SMreadf[SMreadf['length_from_fasta']>=5e3])
# Out:
# 8401

# %%
SMreadf.columns
# Out:
# Index(['15cm_mean', '15cm_median', '15cm_std', '25cm_mean', '25cm_median',
#        '25cm_std', 'Bin', 'GC', 'absCov_15cm', 'absCov_25cm', 'class_count',
#        'class_mean', 'class_median', 'length', 'length_diff(%)',
#        'length_diff(abs)', 'length_from_fasta', 'length_linecount',
#        'norCov_15cm', 'norCov_25cm', 'expt_name', 'new_index',
#        'depthfrac15cm'],
#       dtype='object')

# %%
#FBreadf5kb = FBreadf[FBreadf['length']>=5000]
f, ax = plt.subplots(4,2, sharex=True,figsize=(12,24))
bin000 = SMreadf5kb[SMreadf5kb['Bin']=='039']
d1 = '15cm'
d2 = '25cm'
ax[0][0].scatter(bin000['GC'],bin000['absCov_'+d1],s=bin000['length']/1e2,alpha=.3)
ax[0][0].set_title('absCov_'+d1)
ax[0][1].scatter(bin000['GC'],bin000['absCov_'+d2],s=bin000['length']/1e2,alpha=.3)
ax[0][1].set_title('absCov_'+d2)
ax[1][0].scatter(bin000['GC'],bin000['norCov_'+d1],s=bin000['length']/1e2,alpha=.3)
ax[1][0].set_title('norCov_'+d1)
ax[1][1].scatter(bin000['GC'],bin000['norCov_'+d2],s=bin000['length']/1e2,alpha=.3)
ax[1][1].set_title('norCov_'+d2)

ax[2][0].scatter(bin000['GC'],bin000[d1+'_mean'],s=bin000['length']/1e2,alpha=.3)
ax[2][0].set_title(d1+'_mean')
ax[2][1].scatter(bin000['GC'],bin000[d2+'_mean'],s=bin000['length']/1e2,alpha=.3)
ax[2][1].set_title(d2+'_mean')
ax[3][0].scatter(bin000['GC'],bin000[d1+'_median'],s=bin000['length']/1e2,alpha=.3)
ax[3][0].set_title(d1+'_median')
ax[3][1].scatter(bin000['GC'],bin000[d2+'_median'],s=bin000['length']/1e2,alpha=.3)
ax[3][1].set_title(d2+'_median')
#plt.xlim(0.3,.5)
plt.show()

# %% [markdown]
# OK, so median and mean are completely different here, let's have a look what's going on.

# %%
bin000.sort_values('absCov_25cm',ascending=False).head()
# Out:
#               15cm_mean  15cm_median   15cm_std  25cm_mean  25cm_median  \
# 039_NODE_002   5.658722          3.0   7.084648  39.500038         39.0
# 039_NODE_001   8.941989          8.0   4.056286  10.937565         10.0
# 039_NODE_025  25.145353         25.0  13.487705  30.728433         26.0
# 039_NODE_036   7.902419          6.0   6.624831  34.354212         33.0
# 039_NODE_022   4.598839          3.0   5.253472  29.105245         29.0
#
#                25cm_std  Bin        GC  absCov_15cm  absCov_25cm  \
# 039_NODE_002   9.727949  039  0.605802       1362.0       9266.0
# 039_NODE_001   4.302443  039  0.636820       3822.0       4656.0
# 039_NODE_025  18.194915  039  0.628551       3030.0       3736.0
# 039_NODE_036  10.596980  039  0.614345        856.0       3664.0
# 039_NODE_022   8.392813  039  0.635218        594.0       3634.0
#
#                   ...         length length_diff(%) length_diff(abs)  \
# 039_NODE_002      ...        26644.0       0.000000              0.0
# 039_NODE_001      ...        48370.0       0.000000              0.0
# 039_NODE_025      ...        13794.0       0.043478              6.0
# 039_NODE_036      ...        11990.0       0.000000              0.0
# 039_NODE_022      ...        14129.0       0.000000              0.0
#
#               length_from_fasta  length_linecount  norCov_15cm  norCov_25cm  \
# 039_NODE_002            26644.0           26644.0     0.051118     0.347771
# 039_NODE_001            48370.0           48370.0     0.079016     0.096258
# 039_NODE_025            13800.0           13794.0     0.219565     0.270725
# 039_NODE_036            11990.0           11990.0     0.071393     0.305588
# 039_NODE_022            14129.0           14129.0     0.042041     0.257202
#
#               expt_name                    new_index  depthfrac15cm
# 039_NODE_002     SagMAT  SagMAT_bin_039_039_NODE_002       0.128152
# 039_NODE_001     SagMAT  SagMAT_bin_039_039_NODE_001       0.450814
# 039_NODE_025     SagMAT  SagMAT_bin_039_039_NODE_025       0.447827
# 039_NODE_036     SagMAT  SagMAT_bin_039_039_NODE_036       0.189381
# 039_NODE_022     SagMAT  SagMAT_bin_039_039_NODE_022       0.140492
#
# [5 rows x 23 columns]

# %%
#pd.read_table('Permafrost/FranklinBluffs/bins/fasta/reassembly/shotgunReads_absoluteRealignmentReadCount.000.txt')
binn = '039'
env='linux'
colname = 'SegMat'
expt_name = 'SagMAT'
if env=='linux':
    bin_000 = pd.read_table('Permafrost/'+expt_name+'/bins/fasta/reassembly/shotgunReads_realignmentDepthProfile.'+binn+'.txt')#linux_quake
elif env=='mac':
    bin_000 = pd.read_table('Permafrost/'+expt_name+'/reassembly_files/shotgunReads_realignmentDepthProfile.'+binn+'.txt')#mac
f,ax = plt.subplots() 
plt.style.use(['bmh'])
#'NODE_16_length_9207_cov_5.81697'
#plt.rcParams.update(plt.rcParamsDefault)
num = '2'
bin_000[bin_000['ContigName'].str.contains('NODE_'+num+'_le')].reset_index()[[colname+'_'+d1+'_Bulk',colname+'_'+d2+'_Bulk']].plot(ax=ax,figsize=(7,5))
plt.ylabel('Coverage')
plt.xlabel('Position along contig')
plt.title(expt_name+' bin '+binn+' contig '+num)
#plt.gcf().subplots_adjust(left=0.25,right=0.99,bottom=0.43,top=0.99)
if env=='linux':
    f.savefig('Permafrost/'+expt_name+'/bins/fasta/reassembly/coverage_bin_'+binn+'_contig'+num+'.png')
    f.savefig('Permafrost/'+expt_name+'/bins/fasta/reassembly/coverage_bin_'+binn+'_contig'+num+'.pdf')
elif env=='mac':
    f.savefig('Permafrost/'+expt_name+'/reassembly_plots/coverage_bin_'+binn+'_contig'+num+'.png')
    f.savefig('Permafrost/'+expt_name+'/reassembly_plots/coverage_bin_'+binn+'_contig'+num+'.pdf')

# %%
SMreadf5kb.columns[SMreadf5kb.columns.str.contains('cm_mean')]
# Out:
# Index(['15cm_mean', '25cm_mean'], dtype='object')

# %%
SMreadf5kb.columns
# Out:
# Index(['15cm_mean', '15cm_median', '15cm_std', '25cm_mean', '25cm_median',
#        '25cm_std', 'Bin', 'GC', 'absCov_15cm', 'absCov_25cm', 'class_count',
#        'class_mean', 'class_median', 'length', 'length_diff(%)',
#        'length_diff(abs)', 'length_from_fasta', 'length_linecount',
#        'norCov_15cm', 'norCov_25cm', 'expt_name', 'new_index',
#        'depthfrac15cm'],
#       dtype='object')

# %% [markdown]
# # compare pre-post reassembly

# %%
imp.reload(cop)
indir_reassembly = 'Permafrost/'+expt_name+'/bins/fasta/reassembly/genomes_5kbfilter/CheckM/'
indir_originals = 'Permafrost/'+expt_name+'/bins/fasta/originals/checkm_SM/'
chkm_orig = co.make_checkm_output_df(indir_originals,'tempcheckmdf')
chkm_orig['dataset'] = 'original'
chkm_reas = co.make_checkm_output_df(indir_reassembly,'tempcheckmdf')
chkm_reas['dataset'] = 'reassembled'
cop.compare_two_checkmdfs(chkm_orig,chkm_reas,'dataset',indir_reassembly,expt_name+'_comparison_pre-post_reassembly')

# %% [markdown]
# The completeness of these datasets really sucks.

# %% [markdown]
# ## 1. bins that are ok before reassembly

# %%
okbefore = chkm_orig[(chkm_orig['Contamination']<=5)&(chkm_orig['Strain heterogeneity']<=5)].index
chkm_orig[(chkm_orig['Contamination']<=5)&(chkm_orig['Strain heterogeneity']<=5)][['Completeness','Contamination','Strain heterogeneity','Genome size']]
# Out:
#                Completeness Contamination  Strain heterogeneity Genome size
# 0
# SagMAT_bin_034       36.442       3.44828                   0.0     1658009
# SagMAT_bin_049      32.0533       3.44828                   0.0     2606911
# SagMAT_bin_002      29.3718      0.294118                   0.0     2472213
# SagMAT_bin_040      23.4326             0                   0.0      847440
# SagMAT_bin_007      22.6489             0                   0.0     1206273
# SagMAT_bin_010      19.8276       1.72414                   0.0     1328834
# SagMAT_bin_058      14.6486        1.7094                   0.0     1968010
# SagMAT_bin_016      8.33333       4.16667                   0.0     1582884
# SagMAT_bin_059      6.89655             0                   0.0     1839759
# SagMAT_bin_066      4.16667             0                   0.0      980311
# SagMAT_bin_020      4.16667             0                   0.0     1421594
# SagMAT_bin_064      3.44828             0                   0.0      664035
# SagMAT_bin_037            0             0                   0.0      925367
# SagMAT_bin_053            0             0                   0.0      775700
# SagMAT_bin_046            0             0                   0.0      899960

# %%
okbefidx = ['genome_contigs_withBulk.'+f[-3:]+'.5000bp_filter' for f in okbefore]
chkm_reas[chkm_reas.index.isin(okbefidx)][['Completeness','Contamination','Strain heterogeneity','Genome size']]
# Out:
#                                           Completeness Contamination  \
# 0
# genome_contigs_withBulk.034.5000bp_filter       36.442       3.44828
# genome_contigs_withBulk.049.5000bp_filter      28.4483       1.72414
# genome_contigs_withBulk.040.5000bp_filter      19.9843             0
# genome_contigs_withBulk.058.5000bp_filter      14.4587        1.7094
# genome_contigs_withBulk.002.5000bp_filter      4.31034             0
# genome_contigs_withBulk.007.5000bp_filter      4.16667             0
# genome_contigs_withBulk.066.5000bp_filter      4.16667             0
# genome_contigs_withBulk.059.5000bp_filter      3.44828             0
# genome_contigs_withBulk.064.5000bp_filter      3.44828             0
# genome_contigs_withBulk.016.5000bp_filter            0             0
# genome_contigs_withBulk.053.5000bp_filter            0             0
# genome_contigs_withBulk.020.5000bp_filter            0             0
# genome_contigs_withBulk.037.5000bp_filter            0             0
# genome_contigs_withBulk.010.5000bp_filter            0             0
# genome_contigs_withBulk.046.5000bp_filter            0             0
#
#                                            Strain heterogeneity Genome size
# 0
# genome_contigs_withBulk.034.5000bp_filter                   0.0     1440309
# genome_contigs_withBulk.049.5000bp_filter                   0.0     2145338
# genome_contigs_withBulk.040.5000bp_filter                   0.0      723545
# genome_contigs_withBulk.058.5000bp_filter                   0.0     1413267
# genome_contigs_withBulk.002.5000bp_filter                   0.0      572891
# genome_contigs_withBulk.007.5000bp_filter                   0.0      353731
# genome_contigs_withBulk.066.5000bp_filter                   0.0      838997
# genome_contigs_withBulk.059.5000bp_filter                   0.0     1215279
# genome_contigs_withBulk.064.5000bp_filter                   0.0      569007
# genome_contigs_withBulk.016.5000bp_filter                   0.0      383568
# genome_contigs_withBulk.053.5000bp_filter                   0.0      612132
# genome_contigs_withBulk.020.5000bp_filter                   0.0       36490
# genome_contigs_withBulk.037.5000bp_filter                   0.0      692117
# genome_contigs_withBulk.010.5000bp_filter                   0.0      137506
# genome_contigs_withBulk.046.5000bp_filter                   0.0      332241

# %% [markdown]
# ## 2. bins that needed reassembly, and pass now

# %%
#chkm_orig[(chkm_orig['Contamination']>=5)|(chkm_orig['Strain heterogeneity']>=5)]

# %%
bins_for_reass = chkm_orig[(chkm_orig['Contamination']>=5)|(chkm_orig['Strain heterogeneity']>=5)].index.str[-3:]
indices = ['genome_contigs_withBulk.'+f+'.5000bp_filter' for f in bins_for_reass]
chkm_reas[chkm_reas.index.isin(indices)&(chkm_reas['Contamination']<=5)&(chkm_reas['Strain heterogeneity']<=5)]
#chkm_reas.sort_index()[['Completeness','Contamination','Strain heterogeneity','Genome size']][30:]
#chkm_orig.sort_index()[['Completeness','Contamination','Strain heterogeneity','Genome size']]
# Out:
#                                                    marker lineage  \
# 0
# genome_contigs_withBulk.033.5000bp_filter        p__Bacteroidetes
# genome_contigs_withBulk.006.5000bp_filter   c__Betaproteobacteria
# genome_contigs_withBulk.048.5000bp_filter  c__Deltaproteobacteria
# genome_contigs_withBulk.029.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.055.5000bp_filter          o__Rhizobiales
# genome_contigs_withBulk.060.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.057.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.047.5000bp_filter  c__Deltaproteobacteria
# genome_contigs_withBulk.000.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.061.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.008.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.013.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.043.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.063.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.035.5000bp_filter                    root
# genome_contigs_withBulk.065.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.038.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.067.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.054.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.021.5000bp_filter        p__Bacteroidetes
# genome_contigs_withBulk.026.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.032.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.031.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.044.5000bp_filter  c__Deltaproteobacteria
# genome_contigs_withBulk.028.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.025.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.045.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.012.5000bp_filter                    root
# genome_contigs_withBulk.003.5000bp_filter     f__Paenibacillaceae
# genome_contigs_withBulk.051.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.027.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.017.5000bp_filter                    root
# genome_contigs_withBulk.050.5000bp_filter                    root
# genome_contigs_withBulk.004.5000bp_filter                    root
# genome_contigs_withBulk.005.5000bp_filter                    root
# genome_contigs_withBulk.018.5000bp_filter                    root
# genome_contigs_withBulk.001.5000bp_filter                    root
# genome_contigs_withBulk.009.5000bp_filter                    root
# genome_contigs_withBulk.019.5000bp_filter                    root
#
#                                           Completeness Contamination  \
# 0
# genome_contigs_withBulk.033.5000bp_filter      79.1133      0.738916
# genome_contigs_withBulk.006.5000bp_filter      65.0399             0
# genome_contigs_withBulk.048.5000bp_filter      50.9892       2.58065
# genome_contigs_withBulk.029.5000bp_filter      34.3887       1.72414
# genome_contigs_withBulk.055.5000bp_filter      33.3516       1.72612
# genome_contigs_withBulk.060.5000bp_filter      32.4561             0
# genome_contigs_withBulk.057.5000bp_filter      31.5789             0
# genome_contigs_withBulk.047.5000bp_filter      28.3492             0
# genome_contigs_withBulk.000.5000bp_filter      28.0702             0
# genome_contigs_withBulk.061.5000bp_filter      27.5862             0
# genome_contigs_withBulk.008.5000bp_filter      26.8809             0
# genome_contigs_withBulk.013.5000bp_filter      24.7492             0
# genome_contigs_withBulk.043.5000bp_filter      24.5614             0
# genome_contigs_withBulk.063.5000bp_filter      21.9136        3.7037
# genome_contigs_withBulk.035.5000bp_filter      20.8333             0
# genome_contigs_withBulk.065.5000bp_filter      20.6897       3.44828
# genome_contigs_withBulk.038.5000bp_filter      20.6897       4.31034
# genome_contigs_withBulk.067.5000bp_filter      20.6897             0
# genome_contigs_withBulk.054.5000bp_filter      20.6583       3.44828
# genome_contigs_withBulk.021.5000bp_filter      17.4384      0.492611
# genome_contigs_withBulk.026.5000bp_filter      17.3981             0
# genome_contigs_withBulk.032.5000bp_filter      15.3292             0
# genome_contigs_withBulk.031.5000bp_filter       15.047             0
# genome_contigs_withBulk.044.5000bp_filter      13.4393       0.16129
# genome_contigs_withBulk.028.5000bp_filter      12.2257             0
# genome_contigs_withBulk.025.5000bp_filter       12.069       1.72414
# genome_contigs_withBulk.045.5000bp_filter      10.5263             0
# genome_contigs_withBulk.012.5000bp_filter      4.16667             0
# genome_contigs_withBulk.003.5000bp_filter      4.14925      0.134409
# genome_contigs_withBulk.051.5000bp_filter       3.1348             0
# genome_contigs_withBulk.027.5000bp_filter     0.862069             0
# genome_contigs_withBulk.017.5000bp_filter            0             0
# genome_contigs_withBulk.050.5000bp_filter            0             0
# genome_contigs_withBulk.004.5000bp_filter            0             0
# genome_contigs_withBulk.005.5000bp_filter            0             0
# genome_contigs_withBulk.018.5000bp_filter            0             0
# genome_contigs_withBulk.001.5000bp_filter            0             0
# genome_contigs_withBulk.009.5000bp_filter            0             0
# genome_contigs_withBulk.019.5000bp_filter            0             0
#
#                                           # contigs Genome size # genomes  \
# 0
# genome_contigs_withBulk.033.5000bp_filter        98     3114789       364
# genome_contigs_withBulk.006.5000bp_filter       114     1182034       323
# genome_contigs_withBulk.048.5000bp_filter       110     3839433        83
# genome_contigs_withBulk.029.5000bp_filter        92      699003      5449
# genome_contigs_withBulk.055.5000bp_filter       132     1112401       107
# genome_contigs_withBulk.060.5000bp_filter       103     1048349      5449
# genome_contigs_withBulk.057.5000bp_filter        72      822501      5449
# genome_contigs_withBulk.047.5000bp_filter       100     1858024        83
# genome_contigs_withBulk.000.5000bp_filter       175     1340084      5449
# genome_contigs_withBulk.061.5000bp_filter       212     2242012      5449
# genome_contigs_withBulk.008.5000bp_filter       131     1263862      5449
# genome_contigs_withBulk.013.5000bp_filter        37      338562      5449
# genome_contigs_withBulk.043.5000bp_filter       178     1841483      5449
# genome_contigs_withBulk.063.5000bp_filter       141      909631      2258
# genome_contigs_withBulk.035.5000bp_filter        90      565134      5656
# genome_contigs_withBulk.065.5000bp_filter       276     3224892      5449
# genome_contigs_withBulk.038.5000bp_filter       112      796018      5449
# genome_contigs_withBulk.067.5000bp_filter        91      906226      5449
# genome_contigs_withBulk.054.5000bp_filter       227     1623784      5449
# genome_contigs_withBulk.021.5000bp_filter       108      807966       364
# genome_contigs_withBulk.026.5000bp_filter        89      740253      5449
# genome_contigs_withBulk.032.5000bp_filter        63      831462      5449
# genome_contigs_withBulk.031.5000bp_filter       102      641736      5449
# genome_contigs_withBulk.044.5000bp_filter       155     1020489        83
# genome_contigs_withBulk.028.5000bp_filter        38      414346      5449
# genome_contigs_withBulk.025.5000bp_filter       103      654525      5449
# genome_contigs_withBulk.045.5000bp_filter       120     1181938      5449
# genome_contigs_withBulk.012.5000bp_filter         8       58506      5656
# genome_contigs_withBulk.003.5000bp_filter        65      764528        46
# genome_contigs_withBulk.051.5000bp_filter        98      843712      5449
# genome_contigs_withBulk.027.5000bp_filter         3       16472      5449
# genome_contigs_withBulk.017.5000bp_filter         5       31168      5656
# genome_contigs_withBulk.050.5000bp_filter        55      709452      5656
# genome_contigs_withBulk.004.5000bp_filter        11       87395      5656
# genome_contigs_withBulk.005.5000bp_filter       124     1561188      5656
# genome_contigs_withBulk.018.5000bp_filter        28      200050      5656
# genome_contigs_withBulk.001.5000bp_filter        29      253471      5656
# genome_contigs_withBulk.009.5000bp_filter        11       85139      5656
# genome_contigs_withBulk.019.5000bp_filter         2       11824      5656
#
#                                           # marker sets # markers  \
# 0
# genome_contigs_withBulk.033.5000bp_filter           203       302
# genome_contigs_withBulk.006.5000bp_filter           234       387
# genome_contigs_withBulk.048.5000bp_filter           155       247
# genome_contigs_withBulk.029.5000bp_filter            58       104
# genome_contigs_withBulk.055.5000bp_filter           316       485
# genome_contigs_withBulk.060.5000bp_filter            57       103
# genome_contigs_withBulk.057.5000bp_filter            57       103
# genome_contigs_withBulk.047.5000bp_filter           155       247
# genome_contigs_withBulk.000.5000bp_filter            57       102
# genome_contigs_withBulk.061.5000bp_filter            58       104
# genome_contigs_withBulk.008.5000bp_filter            58       104
# genome_contigs_withBulk.013.5000bp_filter            58       104
# genome_contigs_withBulk.043.5000bp_filter            57       103
# genome_contigs_withBulk.063.5000bp_filter           117       188
# genome_contigs_withBulk.035.5000bp_filter            24        56
# genome_contigs_withBulk.065.5000bp_filter            58       104
# genome_contigs_withBulk.038.5000bp_filter            58       104
# genome_contigs_withBulk.067.5000bp_filter            58       104
# genome_contigs_withBulk.054.5000bp_filter            58       104
# genome_contigs_withBulk.021.5000bp_filter           203       303
# genome_contigs_withBulk.026.5000bp_filter            58       104
# genome_contigs_withBulk.032.5000bp_filter            58       104
# genome_contigs_withBulk.031.5000bp_filter            58       104
# genome_contigs_withBulk.044.5000bp_filter           155       247
# genome_contigs_withBulk.028.5000bp_filter            58       104
# genome_contigs_withBulk.025.5000bp_filter            58       104
# genome_contigs_withBulk.045.5000bp_filter            57       103
# genome_contigs_withBulk.012.5000bp_filter            24        56
# genome_contigs_withBulk.003.5000bp_filter           186       481
# genome_contigs_withBulk.051.5000bp_filter            58       104
# genome_contigs_withBulk.027.5000bp_filter            58       103
# genome_contigs_withBulk.017.5000bp_filter            24        56
# genome_contigs_withBulk.050.5000bp_filter            24        56
# genome_contigs_withBulk.004.5000bp_filter            24        56
# genome_contigs_withBulk.005.5000bp_filter            24        56
# genome_contigs_withBulk.018.5000bp_filter            24        56
# genome_contigs_withBulk.001.5000bp_filter            24        56
# genome_contigs_withBulk.009.5000bp_filter            24        56
# genome_contigs_withBulk.019.5000bp_filter            24        56
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.033.5000bp_filter              2738       0.910484
# genome_contigs_withBulk.006.5000bp_filter              1280       0.915964
# genome_contigs_withBulk.048.5000bp_filter              3530       0.906641
# genome_contigs_withBulk.029.5000bp_filter               746       0.928218
# genome_contigs_withBulk.055.5000bp_filter              1127       0.904928
# genome_contigs_withBulk.060.5000bp_filter              1135       0.853083
# genome_contigs_withBulk.057.5000bp_filter               912       0.836277
# genome_contigs_withBulk.047.5000bp_filter              1691       0.913347
# genome_contigs_withBulk.000.5000bp_filter              1304       0.925929
# genome_contigs_withBulk.061.5000bp_filter              2044       0.875922
# genome_contigs_withBulk.008.5000bp_filter              1202        0.89717
# genome_contigs_withBulk.013.5000bp_filter               370       0.901282
# genome_contigs_withBulk.043.5000bp_filter              1768       0.914955
# genome_contigs_withBulk.063.5000bp_filter               830        0.90955
# genome_contigs_withBulk.035.5000bp_filter               532        0.95368
# genome_contigs_withBulk.065.5000bp_filter              3147       0.877822
# genome_contigs_withBulk.038.5000bp_filter               789       0.929659
# genome_contigs_withBulk.067.5000bp_filter               879       0.879838
# genome_contigs_withBulk.054.5000bp_filter              1751       0.889222
# genome_contigs_withBulk.021.5000bp_filter               808       0.895747
# genome_contigs_withBulk.026.5000bp_filter               648       0.933042
# genome_contigs_withBulk.032.5000bp_filter               754       0.914149
# genome_contigs_withBulk.031.5000bp_filter               650       0.925108
# genome_contigs_withBulk.044.5000bp_filter               960       0.938717
# genome_contigs_withBulk.028.5000bp_filter               362       0.854185
# genome_contigs_withBulk.025.5000bp_filter               701       0.921444
# genome_contigs_withBulk.045.5000bp_filter              1094       0.915822
# genome_contigs_withBulk.012.5000bp_filter                55       0.900711
# genome_contigs_withBulk.003.5000bp_filter               736       0.851698
# genome_contigs_withBulk.051.5000bp_filter               825       0.900843
# genome_contigs_withBulk.027.5000bp_filter                16       0.658451
# genome_contigs_withBulk.017.5000bp_filter                34       0.839322
# genome_contigs_withBulk.050.5000bp_filter               676       0.855872
# genome_contigs_withBulk.004.5000bp_filter                97        0.83562
# genome_contigs_withBulk.005.5000bp_filter              1533       0.868511
# genome_contigs_withBulk.018.5000bp_filter               200       0.847853
# genome_contigs_withBulk.001.5000bp_filter               239       0.873398
# genome_contigs_withBulk.009.5000bp_filter                84       0.826073
# genome_contigs_withBulk.019.5000bp_filter                11       0.779432
#
#                                                  GC      GC std  \
# 0
# genome_contigs_withBulk.033.5000bp_filter  0.443493  0.00996389
# genome_contigs_withBulk.006.5000bp_filter  0.478558   0.0133113
# genome_contigs_withBulk.048.5000bp_filter  0.647309   0.0118705
# genome_contigs_withBulk.029.5000bp_filter  0.561824   0.0109062
# genome_contigs_withBulk.055.5000bp_filter  0.617894   0.0134953
# genome_contigs_withBulk.060.5000bp_filter  0.571797  0.00981141
# genome_contigs_withBulk.057.5000bp_filter  0.566364   0.0148531
# genome_contigs_withBulk.047.5000bp_filter  0.649401   0.0111835
# genome_contigs_withBulk.000.5000bp_filter  0.674793   0.0170125
# genome_contigs_withBulk.061.5000bp_filter  0.582851    0.014103
# genome_contigs_withBulk.008.5000bp_filter  0.414811   0.0112862
# genome_contigs_withBulk.013.5000bp_filter   0.30761   0.0247987
# genome_contigs_withBulk.043.5000bp_filter   0.64789  0.00971711
# genome_contigs_withBulk.063.5000bp_filter  0.565271    0.011229
# genome_contigs_withBulk.035.5000bp_filter  0.656074   0.0168417
# genome_contigs_withBulk.065.5000bp_filter  0.544902   0.0112049
# genome_contigs_withBulk.038.5000bp_filter  0.624569    0.010872
# genome_contigs_withBulk.067.5000bp_filter  0.550938  0.00979479
# genome_contigs_withBulk.054.5000bp_filter  0.623903   0.0134795
# genome_contigs_withBulk.021.5000bp_filter  0.354193   0.0180071
# genome_contigs_withBulk.026.5000bp_filter  0.450273   0.0115654
# genome_contigs_withBulk.032.5000bp_filter    0.4455    0.010641
# genome_contigs_withBulk.031.5000bp_filter  0.591726   0.0118825
# genome_contigs_withBulk.044.5000bp_filter  0.650927   0.0107427
# genome_contigs_withBulk.028.5000bp_filter  0.414668    0.014982
# genome_contigs_withBulk.025.5000bp_filter   0.67415  0.00898082
# genome_contigs_withBulk.045.5000bp_filter  0.646966   0.0098015
# genome_contigs_withBulk.012.5000bp_filter  0.404916   0.0139609
# genome_contigs_withBulk.003.5000bp_filter  0.427775    0.028482
# genome_contigs_withBulk.051.5000bp_filter  0.622615   0.0162114
# genome_contigs_withBulk.027.5000bp_filter  0.389206   0.0161275
# genome_contigs_withBulk.017.5000bp_filter  0.395341   0.0144444
# genome_contigs_withBulk.050.5000bp_filter   0.50696   0.0131063
# genome_contigs_withBulk.004.5000bp_filter  0.426455   0.0262717
# genome_contigs_withBulk.005.5000bp_filter  0.437021   0.0263466
# genome_contigs_withBulk.018.5000bp_filter  0.403689   0.0171853
# genome_contigs_withBulk.001.5000bp_filter  0.451993   0.0275155
# genome_contigs_withBulk.009.5000bp_filter   0.42938   0.0116235
# genome_contigs_withBulk.019.5000bp_filter  0.404009   0.0059649
#
#                                           Longest contig Mean contig length  \
# 0
# genome_contigs_withBulk.033.5000bp_filter         148420            31783.6
# genome_contigs_withBulk.006.5000bp_filter          36648            10368.7
# genome_contigs_withBulk.048.5000bp_filter         150732            34903.9
# genome_contigs_withBulk.029.5000bp_filter          17783            7597.86
# genome_contigs_withBulk.055.5000bp_filter          34689            8427.27
# genome_contigs_withBulk.060.5000bp_filter          28552            10178.1
# genome_contigs_withBulk.057.5000bp_filter          35369            11423.6
# genome_contigs_withBulk.047.5000bp_filter          61357            18580.2
# genome_contigs_withBulk.000.5000bp_filter          22945            7657.62
# genome_contigs_withBulk.061.5000bp_filter          34967            10575.5
# genome_contigs_withBulk.008.5000bp_filter          25913            9647.78
# genome_contigs_withBulk.013.5000bp_filter          19652            9150.32
# genome_contigs_withBulk.043.5000bp_filter          37900            10345.4
# genome_contigs_withBulk.063.5000bp_filter          10986            6451.28
# genome_contigs_withBulk.035.5000bp_filter          10909            6279.27
# genome_contigs_withBulk.065.5000bp_filter          42302            11684.4
# genome_contigs_withBulk.038.5000bp_filter          16365             7107.3
# genome_contigs_withBulk.067.5000bp_filter          25378            9958.49
# genome_contigs_withBulk.054.5000bp_filter          27538            7153.23
# genome_contigs_withBulk.021.5000bp_filter          17438            7481.15
# genome_contigs_withBulk.026.5000bp_filter          18852            8317.45
# genome_contigs_withBulk.032.5000bp_filter          43554            13197.8
# genome_contigs_withBulk.031.5000bp_filter          13801            6291.52
# genome_contigs_withBulk.044.5000bp_filter          16553             6583.8
# genome_contigs_withBulk.028.5000bp_filter          23642            10903.8
# genome_contigs_withBulk.025.5000bp_filter          17986            6354.61
# genome_contigs_withBulk.045.5000bp_filter          24103            9849.48
# genome_contigs_withBulk.012.5000bp_filter          10111            7313.25
# genome_contigs_withBulk.003.5000bp_filter          47640              11762
# genome_contigs_withBulk.051.5000bp_filter          19533            8609.31
# genome_contigs_withBulk.027.5000bp_filter           6104            5490.67
# genome_contigs_withBulk.017.5000bp_filter           7550             6233.6
# genome_contigs_withBulk.050.5000bp_filter          65752            12899.1
# genome_contigs_withBulk.004.5000bp_filter          17317               7945
# genome_contigs_withBulk.005.5000bp_filter          42668            12590.2
# genome_contigs_withBulk.018.5000bp_filter          10519            7144.64
# genome_contigs_withBulk.001.5000bp_filter          17976            8740.38
# genome_contigs_withBulk.009.5000bp_filter          13608            7739.91
# genome_contigs_withBulk.019.5000bp_filter           6134               5912
#
#                                           N50 (contigs)  Strain heterogeneity  \
# 0
# genome_contigs_withBulk.033.5000bp_filter         44806                   0.0
# genome_contigs_withBulk.006.5000bp_filter         11133                   0.0
# genome_contigs_withBulk.048.5000bp_filter         45767                   0.0
# genome_contigs_withBulk.029.5000bp_filter          7968                   0.0
# genome_contigs_withBulk.055.5000bp_filter          8474                   0.0
# genome_contigs_withBulk.060.5000bp_filter         10616                   0.0
# genome_contigs_withBulk.057.5000bp_filter         12331                   0.0
# genome_contigs_withBulk.047.5000bp_filter         20965                   0.0
# genome_contigs_withBulk.000.5000bp_filter          7300                   0.0
# genome_contigs_withBulk.061.5000bp_filter         11526                   0.0
# genome_contigs_withBulk.008.5000bp_filter         10254                   0.0
# genome_contigs_withBulk.013.5000bp_filter          9134                   0.0
# genome_contigs_withBulk.043.5000bp_filter         10685                   0.0
# genome_contigs_withBulk.063.5000bp_filter          6181                   0.0
# genome_contigs_withBulk.035.5000bp_filter          5989                   0.0
# genome_contigs_withBulk.065.5000bp_filter         13245                   0.0
# genome_contigs_withBulk.038.5000bp_filter          7129                   0.0
# genome_contigs_withBulk.067.5000bp_filter         10554                   0.0
# genome_contigs_withBulk.054.5000bp_filter          6917                   0.0
# genome_contigs_withBulk.021.5000bp_filter          7424                   0.0
# genome_contigs_withBulk.026.5000bp_filter          8591                   0.0
# genome_contigs_withBulk.032.5000bp_filter         14233                   0.0
# genome_contigs_withBulk.031.5000bp_filter          5954                   0.0
# genome_contigs_withBulk.044.5000bp_filter          6395                   0.0
# genome_contigs_withBulk.028.5000bp_filter         12164                   0.0
# genome_contigs_withBulk.025.5000bp_filter          6202                   0.0
# genome_contigs_withBulk.045.5000bp_filter         10942                   0.0
# genome_contigs_withBulk.012.5000bp_filter          7077                   0.0
# genome_contigs_withBulk.003.5000bp_filter         13993                   0.0
# genome_contigs_withBulk.051.5000bp_filter          9040                   0.0
# genome_contigs_withBulk.027.5000bp_filter          5195                   0.0
# genome_contigs_withBulk.017.5000bp_filter          5936                   0.0
# genome_contigs_withBulk.050.5000bp_filter         17401                   0.0
# genome_contigs_withBulk.004.5000bp_filter          7686                   0.0
# genome_contigs_withBulk.005.5000bp_filter         14111                   0.0
# genome_contigs_withBulk.018.5000bp_filter          7309                   0.0
# genome_contigs_withBulk.001.5000bp_filter          9200                   0.0
# genome_contigs_withBulk.009.5000bp_filter          7451                   0.0
# genome_contigs_withBulk.019.5000bp_filter          6134                   0.0
#
#                                                dataset
# 0
# genome_contigs_withBulk.033.5000bp_filter  reassembled
# genome_contigs_withBulk.006.5000bp_filter  reassembled
# genome_contigs_withBulk.048.5000bp_filter  reassembled
# genome_contigs_withBulk.029.5000bp_filter  reassembled
# genome_contigs_withBulk.055.5000bp_filter  reassembled
# genome_contigs_withBulk.060.5000bp_filter  reassembled
# genome_contigs_withBulk.057.5000bp_filter  reassembled
# genome_contigs_withBulk.047.5000bp_filter  reassembled
# genome_contigs_withBulk.000.5000bp_filter  reassembled
# genome_contigs_withBulk.061.5000bp_filter  reassembled
# genome_contigs_withBulk.008.5000bp_filter  reassembled
# genome_contigs_withBulk.013.5000bp_filter  reassembled
# genome_contigs_withBulk.043.5000bp_filter  reassembled
# genome_contigs_withBulk.063.5000bp_filter  reassembled
# genome_contigs_withBulk.035.5000bp_filter  reassembled
# genome_contigs_withBulk.065.5000bp_filter  reassembled
# genome_contigs_withBulk.038.5000bp_filter  reassembled
# genome_contigs_withBulk.067.5000bp_filter  reassembled
# genome_contigs_withBulk.054.5000bp_filter  reassembled
# genome_contigs_withBulk.021.5000bp_filter  reassembled
# genome_contigs_withBulk.026.5000bp_filter  reassembled
# genome_contigs_withBulk.032.5000bp_filter  reassembled
# genome_contigs_withBulk.031.5000bp_filter  reassembled
# genome_contigs_withBulk.044.5000bp_filter  reassembled
# genome_contigs_withBulk.028.5000bp_filter  reassembled
# genome_contigs_withBulk.025.5000bp_filter  reassembled
# genome_contigs_withBulk.045.5000bp_filter  reassembled
# genome_contigs_withBulk.012.5000bp_filter  reassembled
# genome_contigs_withBulk.003.5000bp_filter  reassembled
# genome_contigs_withBulk.051.5000bp_filter  reassembled
# genome_contigs_withBulk.027.5000bp_filter  reassembled
# genome_contigs_withBulk.017.5000bp_filter  reassembled
# genome_contigs_withBulk.050.5000bp_filter  reassembled
# genome_contigs_withBulk.004.5000bp_filter  reassembled
# genome_contigs_withBulk.005.5000bp_filter  reassembled
# genome_contigs_withBulk.018.5000bp_filter  reassembled
# genome_contigs_withBulk.001.5000bp_filter  reassembled
# genome_contigs_withBulk.009.5000bp_filter  reassembled
# genome_contigs_withBulk.019.5000bp_filter  reassembled

# %% [markdown]
# ## 3. bins that did not pass reassembly and need pruning

# %%
bins_for_pruning = chkm_reas[chkm_reas.index.isin(indices)&((chkm_reas['Contamination']>5)|(chkm_reas['Strain heterogeneity']>5))].index
chkm_reas[chkm_reas.index.isin(indices)&((chkm_reas['Contamination']>5)|(chkm_reas['Strain heterogeneity']>5))]
# Out:
#                                                    marker lineage  \
# 0
# genome_contigs_withBulk.011.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.056.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.014.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.041.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.023.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.042.5000bp_filter  c__Deltaproteobacteria
# genome_contigs_withBulk.068.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.030.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.024.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.015.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.022.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.039.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.036.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.069.5000bp_filter                    root
# genome_contigs_withBulk.062.5000bp_filter             k__Bacteria
# genome_contigs_withBulk.052.5000bp_filter             k__Bacteria
#
#                                           Completeness Contamination  \
# 0
# genome_contigs_withBulk.011.5000bp_filter       70.766       30.9671
# genome_contigs_withBulk.056.5000bp_filter      60.3448       8.62069
# genome_contigs_withBulk.014.5000bp_filter      55.3498       9.21811
# genome_contigs_withBulk.041.5000bp_filter      51.0972       21.1599
# genome_contigs_withBulk.023.5000bp_filter      39.9687        22.884
# genome_contigs_withBulk.042.5000bp_filter      34.9631             2
# genome_contigs_withBulk.068.5000bp_filter      30.4075      0.940439
# genome_contigs_withBulk.030.5000bp_filter      28.7083       3.64865
# genome_contigs_withBulk.024.5000bp_filter      25.8621       5.17241
# genome_contigs_withBulk.015.5000bp_filter      25.4232       5.51724
# genome_contigs_withBulk.022.5000bp_filter      24.1379       1.72414
# genome_contigs_withBulk.039.5000bp_filter      23.2532        4.3956
# genome_contigs_withBulk.036.5000bp_filter      20.6897       3.44828
# genome_contigs_withBulk.069.5000bp_filter      16.6667       8.33333
# genome_contigs_withBulk.062.5000bp_filter      15.7526       4.93827
# genome_contigs_withBulk.052.5000bp_filter      10.3448       1.72414
#
#                                           # contigs Genome size # genomes  \
# 0
# genome_contigs_withBulk.011.5000bp_filter       232     1577787       924
# genome_contigs_withBulk.056.5000bp_filter       337     3978388      5449
# genome_contigs_withBulk.014.5000bp_filter       217     1505143       924
# genome_contigs_withBulk.041.5000bp_filter       417     2890306      5449
# genome_contigs_withBulk.023.5000bp_filter       278     2850000      5449
# genome_contigs_withBulk.042.5000bp_filter       260     2006401        83
# genome_contigs_withBulk.068.5000bp_filter       129     1020755      5449
# genome_contigs_withBulk.030.5000bp_filter       163     1051071        88
# genome_contigs_withBulk.024.5000bp_filter       127     1000581      5449
# genome_contigs_withBulk.015.5000bp_filter       120      786561      5449
# genome_contigs_withBulk.022.5000bp_filter        64      401237      5449
# genome_contigs_withBulk.039.5000bp_filter       180     1795758      2993
# genome_contigs_withBulk.036.5000bp_filter       159     1186701      5449
# genome_contigs_withBulk.069.5000bp_filter       285     2843256      5656
# genome_contigs_withBulk.062.5000bp_filter       160     1056519      2258
# genome_contigs_withBulk.052.5000bp_filter       137     1121727      5449
#
#                                           # marker sets # markers  \
# 0
# genome_contigs_withBulk.011.5000bp_filter           108       161
# genome_contigs_withBulk.056.5000bp_filter            58       104
# genome_contigs_withBulk.014.5000bp_filter           108       161
# genome_contigs_withBulk.041.5000bp_filter            58       104
# genome_contigs_withBulk.023.5000bp_filter            58       103
# genome_contigs_withBulk.042.5000bp_filter           155       247
# genome_contigs_withBulk.068.5000bp_filter            58       104
# genome_contigs_withBulk.030.5000bp_filter           148       230
# genome_contigs_withBulk.024.5000bp_filter            58       103
# genome_contigs_withBulk.015.5000bp_filter            58       104
# genome_contigs_withBulk.022.5000bp_filter            58       104
# genome_contigs_withBulk.039.5000bp_filter            91       147
# genome_contigs_withBulk.036.5000bp_filter            58       104
# genome_contigs_withBulk.069.5000bp_filter            24        56
# genome_contigs_withBulk.062.5000bp_filter           117       188
# genome_contigs_withBulk.052.5000bp_filter            58       104
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.011.5000bp_filter              1666       0.944434
# genome_contigs_withBulk.056.5000bp_filter              4129        0.86192
# genome_contigs_withBulk.014.5000bp_filter              1623       0.944477
# genome_contigs_withBulk.041.5000bp_filter              2910       0.926935
# genome_contigs_withBulk.023.5000bp_filter              3036       0.889766
# genome_contigs_withBulk.042.5000bp_filter              1910       0.932765
# genome_contigs_withBulk.068.5000bp_filter              1017       0.883537
# genome_contigs_withBulk.030.5000bp_filter              1029       0.927089
# genome_contigs_withBulk.024.5000bp_filter              1025       0.908068
# genome_contigs_withBulk.015.5000bp_filter               795       0.931363
# genome_contigs_withBulk.022.5000bp_filter               399       0.910881
# genome_contigs_withBulk.039.5000bp_filter              1791        0.91649
# genome_contigs_withBulk.036.5000bp_filter              1177       0.950046
# genome_contigs_withBulk.069.5000bp_filter              2758       0.875152
# genome_contigs_withBulk.062.5000bp_filter               934        0.90288
# genome_contigs_withBulk.052.5000bp_filter              1155       0.892869
#
#                                                  GC     GC std Longest contig  \
# 0
# genome_contigs_withBulk.011.5000bp_filter   0.68775  0.0131365          16369
# genome_contigs_withBulk.056.5000bp_filter  0.604887  0.0176328          77675
# genome_contigs_withBulk.014.5000bp_filter  0.689725  0.0125698          21274
# genome_contigs_withBulk.041.5000bp_filter  0.633962   0.015531          24149
# genome_contigs_withBulk.023.5000bp_filter  0.664321  0.0160687          42573
# genome_contigs_withBulk.042.5000bp_filter   0.65137  0.0106348          24924
# genome_contigs_withBulk.068.5000bp_filter  0.554708  0.0108711          17768
# genome_contigs_withBulk.030.5000bp_filter   0.59197  0.0142665          18435
# genome_contigs_withBulk.024.5000bp_filter  0.667115  0.0093067          18048
# genome_contigs_withBulk.015.5000bp_filter   0.67209  0.0118959          11990
# genome_contigs_withBulk.022.5000bp_filter  0.339881  0.0194295          12286
# genome_contigs_withBulk.039.5000bp_filter  0.613536  0.0154234          48370
# genome_contigs_withBulk.036.5000bp_filter  0.656122  0.0120199          22425
# genome_contigs_withBulk.069.5000bp_filter  0.552715  0.0108154          31114
# genome_contigs_withBulk.062.5000bp_filter  0.562795  0.0106658          15740
# genome_contigs_withBulk.052.5000bp_filter  0.620911  0.0146003          24815
#
#                                           Mean contig length N50 (contigs)  \
# 0
# genome_contigs_withBulk.011.5000bp_filter             6800.8          6258
# genome_contigs_withBulk.056.5000bp_filter            11805.3         13529
# genome_contigs_withBulk.014.5000bp_filter            6936.14          6779
# genome_contigs_withBulk.041.5000bp_filter            6931.18          6499
# genome_contigs_withBulk.023.5000bp_filter            10251.8         10745
# genome_contigs_withBulk.042.5000bp_filter            7716.92          7506
# genome_contigs_withBulk.068.5000bp_filter            7912.81          7909
# genome_contigs_withBulk.030.5000bp_filter            6448.27          6100
# genome_contigs_withBulk.024.5000bp_filter            7878.57          7924
# genome_contigs_withBulk.015.5000bp_filter            6554.68          6522
# genome_contigs_withBulk.022.5000bp_filter            6269.33          6113
# genome_contigs_withBulk.039.5000bp_filter            9976.43         10108
# genome_contigs_withBulk.036.5000bp_filter            7463.53          7385
# genome_contigs_withBulk.069.5000bp_filter            9976.32         10846
# genome_contigs_withBulk.062.5000bp_filter            6603.24          6393
# genome_contigs_withBulk.052.5000bp_filter            8187.78          7982
#
#                                            Strain heterogeneity      dataset
# 0
# genome_contigs_withBulk.011.5000bp_filter                  0.00  reassembled
# genome_contigs_withBulk.056.5000bp_filter                  0.00  reassembled
# genome_contigs_withBulk.014.5000bp_filter                  4.17  reassembled
# genome_contigs_withBulk.041.5000bp_filter                 42.31  reassembled
# genome_contigs_withBulk.023.5000bp_filter                  0.00  reassembled
# genome_contigs_withBulk.042.5000bp_filter                 50.00  reassembled
# genome_contigs_withBulk.068.5000bp_filter                 66.67  reassembled
# genome_contigs_withBulk.030.5000bp_filter                 57.14  reassembled
# genome_contigs_withBulk.024.5000bp_filter                 50.00  reassembled
# genome_contigs_withBulk.015.5000bp_filter                 33.33  reassembled
# genome_contigs_withBulk.022.5000bp_filter                100.00  reassembled
# genome_contigs_withBulk.039.5000bp_filter                 20.00  reassembled
# genome_contigs_withBulk.036.5000bp_filter                 66.67  reassembled
# genome_contigs_withBulk.069.5000bp_filter                  0.00  reassembled
# genome_contigs_withBulk.062.5000bp_filter                 26.67  reassembled
# genome_contigs_withBulk.052.5000bp_filter                100.00  reassembled

# %%
import HTSeq

# %%
binn = '039'
file = '/home/bojk/Data/Permafrost/SagMAT/bins/fasta/originals/genome_cluster.'+binn+'.fasta'
file2 = '/home/bojk/Data/Permafrost/SagMAT/bins/fasta/reassembly/genome_contigs_withBulk.'+binn+'.fasta'
len_orig = [];len_reas=[]
for s in HTSeq.FastaReader(file):
    len_orig.append(len(s.seq))
for s in HTSeq.FastaReader(file2):
    len_reas.append(len(s.seq))

# %%
#old = plt.hist(len_orig,np.linspace(100,1e5,40))
f = plt.figure()
oldlog = plt.hist(len_orig,np.logspace(2,5,40))
newlog = plt.hist(len_reas,np.logspace(2,5,40))
plt.legend(['original','reassembled'])
plt.xlabel('Contig length (bp)')
plt.ylabel('Count')
plt.title('SagMAT bin '+binn+' reassembly')
plt.xscale('log')
f.savefig(indir_reassembly+'SM_bin_'+binn+'_reassembly.png')

# %%
sherlock_subsamples = pd.read_table('Permafrost/SagMAT/bins/fasta/reassembly/sherlock_subsamples.txt')
newpath = '/scratch/users/berghuis/PermafrostSagMAT/'
sherlock_subsamples['biosample'] = newpath
sherlock_subsamples.to_csv('Permafrost/SagMAT/bins/fasta/reassembly/sherlock_subsamples_new.txt','\t',index=False)

# %%
#pd.read_table('Permafrost/SagMAT/bins/fasta/reassembly/sherlock_subsamples_new.txt')

# %% [markdown]
# # Pruning reassembled bins

# %%
len(bins_for_pruning)
# Out:
# 16

# %%
# won't be using this for SagMAT since there are only 16 reassembled bins that need pruning.
"""imp.reload(sub)
fastadir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/'
pickle = fastadir+'FranklinBluffs_reassembly_contig_stats.pickle'
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster',
       'expt_name','write_fasta']
values = [30,1,'eom',True,'FranklinBluffs','YES']
kwargs = dict(zip(keys,values))
sub.subcluster_bin_post_reassembly(pickle,fastadir,**kwargs)"""
# Out:
# "imp.reload(sub)\nfastadir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/'\npickle = fastadir+'FranklinBluffs_reassembly_contig_stats.pickle'\nkeys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster',\n       'expt_name','write_fasta']\nvalues = [30,1,'eom',True,'FranklinBluffs','YES']\nkwargs = dict(zip(keys,values))\nsub.subcluster_bin_post_reassembly(pickle,fastadir,**kwargs)"

# %% [markdown]
# # bin-specific parameter selection

# %%
import checkm_out as co

# %%
bins_for_pruning.sort_values()
# Out:
# Index(['genome_contigs_withBulk.011.5000bp_filter',
#        'genome_contigs_withBulk.014.5000bp_filter',
#        'genome_contigs_withBulk.015.5000bp_filter',
#        'genome_contigs_withBulk.022.5000bp_filter',
#        'genome_contigs_withBulk.023.5000bp_filter',
#        'genome_contigs_withBulk.024.5000bp_filter',
#        'genome_contigs_withBulk.030.5000bp_filter',
#        'genome_contigs_withBulk.036.5000bp_filter',
#        'genome_contigs_withBulk.039.5000bp_filter',
#        'genome_contigs_withBulk.041.5000bp_filter',
#        'genome_contigs_withBulk.042.5000bp_filter',
#        'genome_contigs_withBulk.052.5000bp_filter',
#        'genome_contigs_withBulk.056.5000bp_filter',
#        'genome_contigs_withBulk.062.5000bp_filter',
#        'genome_contigs_withBulk.068.5000bp_filter',
#        'genome_contigs_withBulk.069.5000bp_filter'],
#       dtype='object', name=0)

# %%
binn = '069'

# %%
chkm_orig[chkm_orig.index.str.contains('_'+binn)][['Completeness','Contamination','Strain heterogeneity','Genome size']]
# Out:
#                Completeness Contamination  Strain heterogeneity Genome size
# 0
# SagMAT_bin_069      16.6667       8.33333                   0.0     3382122

# %%
chkm_reas[chkm_reas.index.str.contains('.'+binn+'.')][['Completeness','Contamination','Strain heterogeneity','Genome size']].sort_values(0)
# Out:
#                                           Completeness Contamination  \
# 0
# genome_contigs_withBulk.069.5000bp_filter      16.6667       8.33333
#
#                                            Strain heterogeneity Genome size
# 0
# genome_contigs_withBulk.069.5000bp_filter                   0.0     2843256

# %%
imp.reload(sub)
fastadir = 'Permafrost/'+expt_name+'/bins/fasta/reassembly/genomes_5kbfilter/'
pickle = fastadir+expt_name+'_reassembly_contig_stats.pickle'
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster',
       'expt_name','write_fasta','Bin','GC_sensitive']#,'GCmin','GCmax']
values = [45,1,'eom',False,expt_name,'NO',binn,'YES']#,.65,.79]
kwargs = dict(zip(keys,values))
sub.subcluster_bin_post_reassembly(pickle,fastadir,**kwargs)
# Out:
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df

# %% [markdown]
# #  now rewrite all fastas

# %%
imp.reload(sub)
sub.write_subfasta_from_jsonparams(pickle,fastadir+'pruning/json/',fastadir)
# Out:
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(100)
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/Data/minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df

# %% [markdown]
# # make final collection of bins FB

# %%
indir = fastadir+'pruning/fastas/checkm/'
checkm_pruned2 = co.make_checkm_output_df(indir,'FB_prune2')

# %%
checkm_pruned2[(checkm_pruned2['Contamination']<=5)&(checkm_pruned2['Strain heterogeneity']<=5)].head()
# Out:
#                                         marker lineage Completeness  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000    k__Bacteria      65.4545
# FranklinBluffs_bin_019_40cm_sub_bin_000    k__Bacteria      60.9091
# FranklinBluffs_bin_066_55cm_sub_bin_000    k__Bacteria      59.8291
# FranklinBluffs_bin_001_55cm_sub_bin_000    k__Bacteria      57.1676
# FranklinBluffs_bin_001_40cm_sub_bin_000    k__Bacteria      57.1676
#
#                                         Contamination # contigs Genome size  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000      0.909091        67     1449635
# FranklinBluffs_bin_019_40cm_sub_bin_000      0.909091        65     1428051
# FranklinBluffs_bin_066_55cm_sub_bin_000      0.854701        78     1953938
# FranklinBluffs_bin_001_55cm_sub_bin_000      0.819672       153     1794647
# FranklinBluffs_bin_001_40cm_sub_bin_000      0.546448       162     1853981
#
#                                         # genomes # marker sets # markers  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000       924           110       163
# FranklinBluffs_bin_019_40cm_sub_bin_000       924           110       163
# FranklinBluffs_bin_066_55cm_sub_bin_000      2258           117       188
# FranklinBluffs_bin_001_55cm_sub_bin_000       433           183       273
# FranklinBluffs_bin_001_40cm_sub_bin_000       433           183       273
#
#                                         # predicted genes Coding density  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000              1472       0.922567
# FranklinBluffs_bin_019_40cm_sub_bin_000              1445       0.923695
# FranklinBluffs_bin_066_55cm_sub_bin_000              1763       0.881901
# FranklinBluffs_bin_001_55cm_sub_bin_000              1754       0.888318
# FranklinBluffs_bin_001_40cm_sub_bin_000              1811       0.886722
#
#                                                GC     GC std Longest contig  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000  0.562303   0.010454         104433
# FranklinBluffs_bin_019_40cm_sub_bin_000  0.562468  0.0107087         104433
# FranklinBluffs_bin_066_55cm_sub_bin_000  0.605441  0.0065294         100680
# FranklinBluffs_bin_001_55cm_sub_bin_000  0.354487    0.01294          46643
# FranklinBluffs_bin_001_40cm_sub_bin_000  0.354461  0.0131308          46643
#
#                                         Mean contig length N50 (contigs)  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000            21636.3         31960
# FranklinBluffs_bin_019_40cm_sub_bin_000              21970         31960
# FranklinBluffs_bin_066_55cm_sub_bin_000            25050.5         33845
# FranklinBluffs_bin_001_55cm_sub_bin_000            11729.7         12986
# FranklinBluffs_bin_001_40cm_sub_bin_000            11444.3         12840
#
#                                          Strain heterogeneity
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_019_40cm_sub_bin_000                   0.0
# FranklinBluffs_bin_066_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_001_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_001_40cm_sub_bin_000                   0.0

# %%
# make original reassembled checkmdf again
indir = fastadir+'CheckM/'
FBcheckm_reassembled = co.make_checkm_output_df(indir,'bla')

# %%
FBcheckm_reassembled[(FBcheckm_reassembled['Contamination']<=5)&(FBcheckm_reassembled['Strain heterogeneity']<=5)].head()
# Out:
#                                              marker lineage Completeness  \
# 0
# genome_contigs_withBulk.056.5000bp_filter       k__Bacteria      64.1162
# genome_contigs_withBulk.005.5000bp_filter  p__Bacteroidetes      58.3856
# genome_contigs_withBulk.015.5000bp_filter       k__Bacteria      49.0383
# genome_contigs_withBulk.014.5000bp_filter       k__Bacteria      48.9262
# genome_contigs_withBulk.003.5000bp_filter  p__Bacteroidetes       44.802
#
#                                           Contamination # contigs Genome size  \
# 0
# genome_contigs_withBulk.056.5000bp_filter      0.909091       115     1994896
# genome_contigs_withBulk.005.5000bp_filter             0       214     2143843
# genome_contigs_withBulk.015.5000bp_filter             0        76      746174
# genome_contigs_withBulk.014.5000bp_filter       1.68067        83      783768
# genome_contigs_withBulk.003.5000bp_filter             0       225     2096528
#
#                                           # genomes # marker sets # markers  \
# 0
# genome_contigs_withBulk.056.5000bp_filter      2258           110       181
# genome_contigs_withBulk.005.5000bp_filter       364           202       302
# genome_contigs_withBulk.015.5000bp_filter      2258           119       190
# genome_contigs_withBulk.014.5000bp_filter      2258           119       190
# genome_contigs_withBulk.003.5000bp_filter       364           202       302
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.056.5000bp_filter              2149       0.858638
# genome_contigs_withBulk.005.5000bp_filter              1980       0.858635
# genome_contigs_withBulk.015.5000bp_filter               734       0.949722
# genome_contigs_withBulk.014.5000bp_filter               770       0.953588
# genome_contigs_withBulk.003.5000bp_filter              1926       0.894564
#
#                                                  GC     GC std Longest contig  \
# 0
# genome_contigs_withBulk.056.5000bp_filter  0.572637  0.0117451          92468
# genome_contigs_withBulk.005.5000bp_filter  0.413879  0.0200715          27363
# genome_contigs_withBulk.015.5000bp_filter  0.673958  0.0146131          25576
# genome_contigs_withBulk.014.5000bp_filter  0.673773  0.0154173          36057
# genome_contigs_withBulk.003.5000bp_filter  0.414389  0.0128904          31993
#
#                                           Mean contig length N50 (contigs)  \
# 0
# genome_contigs_withBulk.056.5000bp_filter            17346.9         24421
# genome_contigs_withBulk.005.5000bp_filter            10017.9         11184
# genome_contigs_withBulk.015.5000bp_filter            9818.08         11116
# genome_contigs_withBulk.014.5000bp_filter            9442.99         10115
# genome_contigs_withBulk.003.5000bp_filter            9317.88          9659
#
#                                            Strain heterogeneity
# 0
# genome_contigs_withBulk.056.5000bp_filter                   0.0
# genome_contigs_withBulk.005.5000bp_filter                   0.0
# genome_contigs_withBulk.015.5000bp_filter                   0.0
# genome_contigs_withBulk.014.5000bp_filter                   0.0
# genome_contigs_withBulk.003.5000bp_filter                   0.0

# %%
# these are the bins I went through individually and marked as 'no pruning needed'
ok_manual_selection = pd.read_csv(indir+'list_FB_reassembled_noPruningNeeded.csv',header=None)

# %%
oklist = ["{0:0=3d}".format(int(f)) for f in ok_manual_selection[0]]
ok_from_checkm = [f.split('.')[1] for f in FBcheckm_reassembled[(FBcheckm_reassembled['Contamination']<=5)&(FBcheckm_reassembled['Strain heterogeneity']<=5)].index]

# %%
# passes criteria in checkmdf, but did not make it to my manual 'OK'
missing = list(set(ok_from_checkm).difference(set(oklist)))
# on my ok list but not in checkm ok region (none)
list(set(oklist).difference(set(ok_from_checkm)))
missing
# Out:
# ['032', '006', '123', '012', '011', '017', '009', '162']

# %%
indices = ['genome_contigs_withBulk.'+f+'.5000bp_filter' for f in missing]
FBcheckm_reassembled[FBcheckm_reassembled.index.isin(indices)]
# Out:
#                                           marker lineage Completeness  \
# 0
# genome_contigs_withBulk.012.5000bp_filter           root      8.33333
# genome_contigs_withBulk.017.5000bp_filter    k__Bacteria      5.17241
# genome_contigs_withBulk.006.5000bp_filter    k__Bacteria      5.17241
# genome_contigs_withBulk.011.5000bp_filter           root      4.16667
# genome_contigs_withBulk.032.5000bp_filter           root      4.16667
# genome_contigs_withBulk.162.5000bp_filter           root            0
# genome_contigs_withBulk.009.5000bp_filter           root            0
# genome_contigs_withBulk.123.5000bp_filter           root            0
#
#                                           Contamination # contigs Genome size  \
# 0
# genome_contigs_withBulk.012.5000bp_filter             0        79      499015
# genome_contigs_withBulk.017.5000bp_filter             0        88      738338
# genome_contigs_withBulk.006.5000bp_filter             0        66      591299
# genome_contigs_withBulk.011.5000bp_filter             0        25      189791
# genome_contigs_withBulk.032.5000bp_filter             0        89      921367
# genome_contigs_withBulk.162.5000bp_filter             0       105     1085543
# genome_contigs_withBulk.009.5000bp_filter             0        13       84619
# genome_contigs_withBulk.123.5000bp_filter             0       145     1014113
#
#                                           # genomes # marker sets # markers  \
# 0
# genome_contigs_withBulk.012.5000bp_filter      5656            24        56
# genome_contigs_withBulk.017.5000bp_filter      5449            58       104
# genome_contigs_withBulk.006.5000bp_filter      5449            58       104
# genome_contigs_withBulk.011.5000bp_filter      5656            24        56
# genome_contigs_withBulk.032.5000bp_filter      5656            24        56
# genome_contigs_withBulk.162.5000bp_filter      5656            24        56
# genome_contigs_withBulk.009.5000bp_filter      5656            24        56
# genome_contigs_withBulk.123.5000bp_filter      5656            24        56
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.012.5000bp_filter               478       0.897867
# genome_contigs_withBulk.017.5000bp_filter               704       0.899286
# genome_contigs_withBulk.006.5000bp_filter               591       0.890891
# genome_contigs_withBulk.011.5000bp_filter               190       0.905759
# genome_contigs_withBulk.032.5000bp_filter               868       0.911231
# genome_contigs_withBulk.162.5000bp_filter              1141       0.907639
# genome_contigs_withBulk.009.5000bp_filter                82       0.889044
# genome_contigs_withBulk.123.5000bp_filter              1137       0.947691
#
#                                                  GC     GC std Longest contig  \
# 0
# genome_contigs_withBulk.012.5000bp_filter  0.394355  0.0105792          14804
# genome_contigs_withBulk.017.5000bp_filter  0.399853  0.0121572          17021
# genome_contigs_withBulk.006.5000bp_filter  0.402594  0.0256219          30489
# genome_contigs_withBulk.011.5000bp_filter   0.42747  0.0230886          14872
# genome_contigs_withBulk.032.5000bp_filter  0.623087  0.0160368          38937
# genome_contigs_withBulk.162.5000bp_filter   0.68821  0.0146675          39077
# genome_contigs_withBulk.009.5000bp_filter  0.425744  0.0126747          11183
# genome_contigs_withBulk.123.5000bp_filter  0.708813  0.0114128          13273
#
#                                           Mean contig length N50 (contigs)  \
# 0
# genome_contigs_withBulk.012.5000bp_filter            6316.65          6053
# genome_contigs_withBulk.017.5000bp_filter             8390.2          8563
# genome_contigs_withBulk.006.5000bp_filter            8959.06          8935
# genome_contigs_withBulk.011.5000bp_filter            7591.64          9195
# genome_contigs_withBulk.032.5000bp_filter            10352.4         11313
# genome_contigs_withBulk.162.5000bp_filter            10338.5         10379
# genome_contigs_withBulk.009.5000bp_filter            6509.15          6224
# genome_contigs_withBulk.123.5000bp_filter            6993.88          6777
#
#                                            Strain heterogeneity
# 0
# genome_contigs_withBulk.012.5000bp_filter                   0.0
# genome_contigs_withBulk.017.5000bp_filter                   0.0
# genome_contigs_withBulk.006.5000bp_filter                   0.0
# genome_contigs_withBulk.011.5000bp_filter                   0.0
# genome_contigs_withBulk.032.5000bp_filter                   0.0
# genome_contigs_withBulk.162.5000bp_filter                   0.0
# genome_contigs_withBulk.009.5000bp_filter                   0.0
# genome_contigs_withBulk.123.5000bp_filter                   0.0

# %%
indices_oklist = ['genome_contigs_withBulk.'+f+'.5000bp_filter' for f in oklist]
FBcheckm_reassembled[FBcheckm_reassembled.index.isin(indices_oklist)]
fastanames_oklist = ['genome_contigs_withBulk.'+f+'.5000bp_filter.fasta' for f in oklist]
fastadir_old = [fastadir+f for f in fastanames_oklist]
fastadir_new = [fastadir+'ok_as_is/'+f for f in fastanames_oklist]
# move the reassembled fastas that are ok as is:
for i in range(len(fastadir_old)):
    os.rename(fastadir_old[i],fastadir_new[i])

# %%
finalpass = checkm_pruned2[(checkm_pruned2['Contamination']<=5)&(checkm_pruned2['Strain heterogeneity']<=5)].index
# move the pruned fastas that pass:
prunedir = [fastadir+'pruning/fastas/'+f+'.fasta' for f in finalpass]
finalpassdir = [fastadir+'pruning/fastas/final_pass/'+f+'.fasta' for f in finalpass]
for i in range(len(prunedir)):
    os.rename(prunedir[i],finalpassdir[i])
len(finalpassdir)
# Out:
# 64

# %% [markdown]
# now repeat for SagMAT and WestDock

# %%
bid  = 123
profit = []
for box in np.random.randint(0,1000,10000):
    if box<=bid:
        profit.append(2*box-bid)
print(np.sum(profit))
# Out:
# 3213

# %%
np.random.random_integers(0,1000,10)
# Out:
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(0, 1000 + 1) instead
#   """Entry point for launching an IPython kernel.
# array([411, 651, 545, 265, 436, 949,   2, 246, 275, 951])

# %%
np.random.randint(0,1000,10)
# Out:
# array([146, 990, 943, 665, 864, 613, 466,  47, 811, 653])

# %%
profit

plt.plot(np.random.randint(0,1000,10000),'o')
