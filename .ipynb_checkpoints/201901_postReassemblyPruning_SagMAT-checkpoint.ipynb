# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import sys
sys.path.append('minimeta_pyfiles/')
import imp
import minimetagenome_analysis as minimeta
#imp.reload(minimeta)
import os
import reassembly as rea
import subcluster_bins as sub

# %% [markdown]
# this is a continuation (& cleaned up version of 201810_permafrost_analysis)
# where I continue with post reassembly pruning

# %%
# %pwd
# Out:
# '/home/bojk/Data'

# %%
os.chdir('../')

# %%
imp.reload(rea)
#readf = None
FBreadf = rea.make_CS_df_new_index('Permafrost/FranklinBluffs/bins/fasta/reassembly/')#linux
#FBreadf = rea.make_CS_df_new_index('Permafrost/FranklinBluffs/reassembly_files/')#mac
FBreadf5kb = FBreadf[FBreadf['length_linecount']>=5e3]
# Out:
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Added read count and saved, time elapsed (hh:mm:ss.ms) 0:09:12.442897
# 25157 contigs above 5kb for reassembled FranklinBluffs

# %%
len(FBreadf5kb)
# Out:
# 25157

# %%
len(FBreadf[FBreadf['length_from_fasta']>=5e3])
# Out:
# 25172

# %%
#FBreadf5kb = FBreadf[FBreadf['length']>=5000]
f, ax = plt.subplots(4,2, sharex=True,figsize=(12,24))
bin000 = FBreadf5kb[FBreadf5kb['Bin']=='005']
ax[0][0].scatter(bin000['GC'],bin000['absCov_55cm'],s=bin000['length']/1e2,alpha=.3)
ax[0][0].set_title('absCov_55cm')
ax[0][1].scatter(bin000['GC'],bin000['absCov_40cm'],s=bin000['length']/1e2,alpha=.3)
ax[0][1].set_title('absCov_40cm')
ax[1][0].scatter(bin000['GC'],bin000['norCov_55cm'],s=bin000['length']/1e2,alpha=.3)
ax[1][0].set_title('norCov_55cm')
ax[1][1].scatter(bin000['GC'],bin000['norCov_40cm'],s=bin000['length']/1e2,alpha=.3)
ax[1][1].set_title('norCov_40cm')

ax[2][0].scatter(bin000['GC'],bin000['55cm_mean'],s=bin000['length']/1e2,alpha=.3)
ax[2][0].set_title('55cm_mean')
ax[2][1].scatter(bin000['GC'],bin000['40cm_mean'],s=bin000['length']/1e2,alpha=.3)
ax[2][1].set_title('40cm_mean')
ax[3][0].scatter(bin000['GC'],bin000['55cm_median'],s=bin000['length']/1e2,alpha=.3)
ax[3][0].set_title('55cm_median')
ax[3][1].scatter(bin000['GC'],bin000['40cm_median'],s=bin000['length']/1e2,alpha=.3)
ax[3][1].set_title('40cm_median')
#plt.xlim(0.3,.5)
plt.show()

# %%
FBreadf5kb.columns[FBreadf5kb.columns.str.contains('cm_mean')]
# Out:
# Index(['40cm_mean', '55cm_mean'], dtype='object')

# %%
FBreadf5kb.columns
# Out:
# Index(['40cm_mean', '40cm_median', '40cm_std', '55cm_mean', '55cm_median',
#        '55cm_std', 'Bin', 'GC', 'absCov_40cm', 'absCov_55cm', 'class_count',
#        'class_mean', 'class_median', 'length', 'length_diff(%)',
#        'length_diff(abs)', 'length_from_fasta', 'length_linecount',
#        'norCov_40cm', 'norCov_55cm', 'expt_name', 'new_index',
#        'depthfrac55cm'],
#       dtype='object')

# %% [markdown]
# # subcluster reassembled bins (same params for all)

# %%
imp.reload(sub)
fastadir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/'
pickle = fastadir+'FranklinBluffs_reassembly_contig_stats.pickle'
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster',
       'expt_name','write_fasta']
values = [30,1,'eom',True,'FranklinBluffs','YES']
kwargs = dict(zip(keys,values))
sub.subcluster_bin_post_reassembly(pickle,fastadir,**kwargs)
# Out:
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df

# %% [markdown]
# performed checkm on pruned bins

# %%
import checkm_out as co

# %%
indir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/pruning/fastas/checkm/'
savename = 'FB_ReA_pruned_checkm'
FB_pruned = co.make_checkm_output_df(indir,savename)
indir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/CheckM/'
FB_pre_pruned = co.make_checkm_output_df(indir,'FB_reassembled_checkmdf')

# %%
FB_pruned[(FB_pruned['Contamination']<=5) & (FB_pruned['Strain heterogeneity']<=5)].head()
# Out:
#                                         marker lineage Completeness  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001    k__Bacteria       77.037
# FranklinBluffs_bin_059_40cm_sub_bin_001    k__Bacteria      76.3613
# FranklinBluffs_bin_075_40cm_sub_bin_000    k__Bacteria      63.7931
# FranklinBluffs_bin_056_55cm_sub_bin_000    k__Bacteria      62.2807
# FranklinBluffs_bin_093_40cm_sub_bin_000    k__Bacteria      53.4483
#
#                                         Contamination # contigs Genome size  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001             0        98     3126894
# FranklinBluffs_bin_059_40cm_sub_bin_001      0.675676        85     2970568
# FranklinBluffs_bin_075_40cm_sub_bin_000             0        99     1799398
# FranklinBluffs_bin_056_55cm_sub_bin_000             0        61     1358450
# FranklinBluffs_bin_093_40cm_sub_bin_000       3.44828        98     1606352
#
#                                         # genomes # marker sets # markers  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001        88           148       230
# FranklinBluffs_bin_059_40cm_sub_bin_001        88           148       230
# FranklinBluffs_bin_075_40cm_sub_bin_000      5449            58       104
# FranklinBluffs_bin_056_55cm_sub_bin_000      5449            57       103
# FranklinBluffs_bin_093_40cm_sub_bin_000      5449            58       104
#
#                                         # predicted genes Coding density  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001              3060       0.887668
# FranklinBluffs_bin_059_40cm_sub_bin_001              2905       0.888549
# FranklinBluffs_bin_075_40cm_sub_bin_000              1868       0.882769
# FranklinBluffs_bin_056_55cm_sub_bin_000              1437       0.864821
# FranklinBluffs_bin_093_40cm_sub_bin_000              1735       0.948816
#
#                                                GC     GC std Longest contig  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001  0.595814  0.0129365         140849
# FranklinBluffs_bin_059_40cm_sub_bin_001  0.596433  0.0132537         140849
# FranklinBluffs_bin_075_40cm_sub_bin_000  0.624319  0.0143225          67983
# FranklinBluffs_bin_056_55cm_sub_bin_000  0.573662  0.0110335          92468
# FranklinBluffs_bin_093_40cm_sub_bin_000  0.660766  0.0160805          72386
#
#                                         Mean contig length N50 (contigs)  \
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001            31907.1         49663
# FranklinBluffs_bin_059_40cm_sub_bin_001            34947.8         52757
# FranklinBluffs_bin_075_40cm_sub_bin_000            18175.7         20454
# FranklinBluffs_bin_056_55cm_sub_bin_000            22269.7         28331
# FranklinBluffs_bin_093_40cm_sub_bin_000            16391.3         19347
#
#                                          Strain heterogeneity
# 0
# FranklinBluffs_bin_059_55cm_sub_bin_001                   0.0
# FranklinBluffs_bin_059_40cm_sub_bin_001                   0.0
# FranklinBluffs_bin_075_40cm_sub_bin_000                   0.0
# FranklinBluffs_bin_056_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_093_40cm_sub_bin_000                   0.0

# %% [markdown]
# OK, so the conclusion is that from the 300+ bins formed (which are redundant, so let's say 150 bins) there are only a handful (~20) that are reasonably complete (>50%) and clean enough. This is too little. I will need to resort to pruning them one by one.

# %%
binn = '165'

# %%
FB_pre_pruned[FB_pre_pruned.index.str.contains('k.'+binn+'.')][['Completeness','Contamination','Strain heterogeneity','Genome size']]
# Out:
# Empty DataFrame
# Columns: [Completeness, Contamination, Strain heterogeneity, Genome size]
# Index: []

# %%
FB_pruned[FB_pruned.index.str.contains('bin_'+binn+'_')][['Completeness','Contamination','Strain heterogeneity','Genome size']].sort_values(0)
# Out:
# Empty DataFrame
# Columns: [Completeness, Contamination, Strain heterogeneity, Genome size]
# Index: []

# %% [markdown]
# # bin-specific parameter selection

# %%
imp.reload(sub)
fastadir = 'Permafrost/FranklinBluffs/bins/fasta/reassembly/'
pickle = fastadir+'FranklinBluffs_reassembly_contig_stats.pickle'
keys = ['min_cluster_size','min_samples','cluster_selection_method','allow_single_cluster',
       'expt_name','write_fasta','Bin','GC_sensitive']#,'GCmin','GCmax']
values = [145,1,'eom',True,'FranklinBluffs','YES',binn,'YES']#,.65,.79]
kwargs = dict(zip(keys,values))
sub.subcluster_bin_post_reassembly(pickle,fastadir,**kwargs)
# Out:
# minimeta_pyfiles/subcluster_bins.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in['GC_sensitive'] = df_in['GC'].multiply(10)
# minimeta_pyfiles/subcluster_bins.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df
# minimeta_pyfiles/subcluster_bins.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_in[subclunum] = ["{0:0=3d}".format(f) if f>=0 else f for f in labels] #add cluster numbers to main df

# %% [markdown]
# #  now rewrite all fastas

# %%
imp.reload(sub)
sub.write_subfasta_from_jsonparams(pickle,fastadir+'pruning/json/',fastadir)
# Out:
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# /home/bojk/miniconda3/envs/py360/lib/python3.6/site-packages/matplotlib/collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   xcol = 'GC_sensitive'
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for
# minimeta_pyfiles/subcluster_bins.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   stats2 = df_in.groupby(subclunum).count()['length_from_fasta'] # contigs for

# %% [markdown]
# # make final collection of bins FB

# %%
indir = fastadir+'pruning/fastas/checkm/'
checkm_pruned2 = co.make_checkm_output_df(indir,'FB_prune2')

# %%
checkm_pruned2[(checkm_pruned2['Contamination']<=5)&(checkm_pruned2['Strain heterogeneity']<=5)].head()
# Out:
#                                         marker lineage Completeness  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000    k__Bacteria      65.4545
# FranklinBluffs_bin_019_40cm_sub_bin_000    k__Bacteria      60.9091
# FranklinBluffs_bin_066_55cm_sub_bin_000    k__Bacteria      59.8291
# FranklinBluffs_bin_001_55cm_sub_bin_000    k__Bacteria      57.1676
# FranklinBluffs_bin_001_40cm_sub_bin_000    k__Bacteria      57.1676
#
#                                         Contamination # contigs Genome size  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000      0.909091        67     1449635
# FranklinBluffs_bin_019_40cm_sub_bin_000      0.909091        65     1428051
# FranklinBluffs_bin_066_55cm_sub_bin_000      0.854701        78     1953938
# FranklinBluffs_bin_001_55cm_sub_bin_000      0.819672       153     1794647
# FranklinBluffs_bin_001_40cm_sub_bin_000      0.546448       162     1853981
#
#                                         # genomes # marker sets # markers  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000       924           110       163
# FranklinBluffs_bin_019_40cm_sub_bin_000       924           110       163
# FranklinBluffs_bin_066_55cm_sub_bin_000      2258           117       188
# FranklinBluffs_bin_001_55cm_sub_bin_000       433           183       273
# FranklinBluffs_bin_001_40cm_sub_bin_000       433           183       273
#
#                                         # predicted genes Coding density  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000              1472       0.922567
# FranklinBluffs_bin_019_40cm_sub_bin_000              1445       0.923695
# FranklinBluffs_bin_066_55cm_sub_bin_000              1763       0.881901
# FranklinBluffs_bin_001_55cm_sub_bin_000              1754       0.888318
# FranklinBluffs_bin_001_40cm_sub_bin_000              1811       0.886722
#
#                                                GC     GC std Longest contig  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000  0.562303   0.010454         104433
# FranklinBluffs_bin_019_40cm_sub_bin_000  0.562468  0.0107087         104433
# FranklinBluffs_bin_066_55cm_sub_bin_000  0.605441  0.0065294         100680
# FranklinBluffs_bin_001_55cm_sub_bin_000  0.354487    0.01294          46643
# FranklinBluffs_bin_001_40cm_sub_bin_000  0.354461  0.0131308          46643
#
#                                         Mean contig length N50 (contigs)  \
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000            21636.3         31960
# FranklinBluffs_bin_019_40cm_sub_bin_000              21970         31960
# FranklinBluffs_bin_066_55cm_sub_bin_000            25050.5         33845
# FranklinBluffs_bin_001_55cm_sub_bin_000            11729.7         12986
# FranklinBluffs_bin_001_40cm_sub_bin_000            11444.3         12840
#
#                                          Strain heterogeneity
# 0
# FranklinBluffs_bin_019_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_019_40cm_sub_bin_000                   0.0
# FranklinBluffs_bin_066_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_001_55cm_sub_bin_000                   0.0
# FranklinBluffs_bin_001_40cm_sub_bin_000                   0.0

# %%
# make original reassembled checkmdf again
indir = fastadir+'CheckM/'
FBcheckm_reassembled = co.make_checkm_output_df(indir,'bla')

# %%
FBcheckm_reassembled[(FBcheckm_reassembled['Contamination']<=5)&(FBcheckm_reassembled['Strain heterogeneity']<=5)].head()
# Out:
#                                              marker lineage Completeness  \
# 0
# genome_contigs_withBulk.056.5000bp_filter       k__Bacteria      64.1162
# genome_contigs_withBulk.005.5000bp_filter  p__Bacteroidetes      58.3856
# genome_contigs_withBulk.015.5000bp_filter       k__Bacteria      49.0383
# genome_contigs_withBulk.014.5000bp_filter       k__Bacteria      48.9262
# genome_contigs_withBulk.003.5000bp_filter  p__Bacteroidetes       44.802
#
#                                           Contamination # contigs Genome size  \
# 0
# genome_contigs_withBulk.056.5000bp_filter      0.909091       115     1994896
# genome_contigs_withBulk.005.5000bp_filter             0       214     2143843
# genome_contigs_withBulk.015.5000bp_filter             0        76      746174
# genome_contigs_withBulk.014.5000bp_filter       1.68067        83      783768
# genome_contigs_withBulk.003.5000bp_filter             0       225     2096528
#
#                                           # genomes # marker sets # markers  \
# 0
# genome_contigs_withBulk.056.5000bp_filter      2258           110       181
# genome_contigs_withBulk.005.5000bp_filter       364           202       302
# genome_contigs_withBulk.015.5000bp_filter      2258           119       190
# genome_contigs_withBulk.014.5000bp_filter      2258           119       190
# genome_contigs_withBulk.003.5000bp_filter       364           202       302
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.056.5000bp_filter              2149       0.858638
# genome_contigs_withBulk.005.5000bp_filter              1980       0.858635
# genome_contigs_withBulk.015.5000bp_filter               734       0.949722
# genome_contigs_withBulk.014.5000bp_filter               770       0.953588
# genome_contigs_withBulk.003.5000bp_filter              1926       0.894564
#
#                                                  GC     GC std Longest contig  \
# 0
# genome_contigs_withBulk.056.5000bp_filter  0.572637  0.0117451          92468
# genome_contigs_withBulk.005.5000bp_filter  0.413879  0.0200715          27363
# genome_contigs_withBulk.015.5000bp_filter  0.673958  0.0146131          25576
# genome_contigs_withBulk.014.5000bp_filter  0.673773  0.0154173          36057
# genome_contigs_withBulk.003.5000bp_filter  0.414389  0.0128904          31993
#
#                                           Mean contig length N50 (contigs)  \
# 0
# genome_contigs_withBulk.056.5000bp_filter            17346.9         24421
# genome_contigs_withBulk.005.5000bp_filter            10017.9         11184
# genome_contigs_withBulk.015.5000bp_filter            9818.08         11116
# genome_contigs_withBulk.014.5000bp_filter            9442.99         10115
# genome_contigs_withBulk.003.5000bp_filter            9317.88          9659
#
#                                            Strain heterogeneity
# 0
# genome_contigs_withBulk.056.5000bp_filter                   0.0
# genome_contigs_withBulk.005.5000bp_filter                   0.0
# genome_contigs_withBulk.015.5000bp_filter                   0.0
# genome_contigs_withBulk.014.5000bp_filter                   0.0
# genome_contigs_withBulk.003.5000bp_filter                   0.0

# %%
# these are the bins I went through individually and marked as 'no pruning needed'
ok_manual_selection = pd.read_csv(indir+'list_FB_reassembled_noPruningNeeded.csv',header=None)

# %%
oklist = ["{0:0=3d}".format(int(f)) for f in ok_manual_selection[0]]
ok_from_checkm = [f.split('.')[1] for f in FBcheckm_reassembled[(FBcheckm_reassembled['Contamination']<=5)&(FBcheckm_reassembled['Strain heterogeneity']<=5)].index]

# %%
# passes criteria in checkmdf, but did not make it to my manual 'OK'
missing = list(set(ok_from_checkm).difference(set(oklist)))
# on my ok list but not in checkm ok region (none)
list(set(oklist).difference(set(ok_from_checkm)))
missing
# Out:
# ['032', '006', '123', '012', '011', '017', '009', '162']

# %%
indices = ['genome_contigs_withBulk.'+f+'.5000bp_filter' for f in missing]
FBcheckm_reassembled[FBcheckm_reassembled.index.isin(indices)]
# Out:
#                                           marker lineage Completeness  \
# 0
# genome_contigs_withBulk.012.5000bp_filter           root      8.33333
# genome_contigs_withBulk.017.5000bp_filter    k__Bacteria      5.17241
# genome_contigs_withBulk.006.5000bp_filter    k__Bacteria      5.17241
# genome_contigs_withBulk.011.5000bp_filter           root      4.16667
# genome_contigs_withBulk.032.5000bp_filter           root      4.16667
# genome_contigs_withBulk.162.5000bp_filter           root            0
# genome_contigs_withBulk.009.5000bp_filter           root            0
# genome_contigs_withBulk.123.5000bp_filter           root            0
#
#                                           Contamination # contigs Genome size  \
# 0
# genome_contigs_withBulk.012.5000bp_filter             0        79      499015
# genome_contigs_withBulk.017.5000bp_filter             0        88      738338
# genome_contigs_withBulk.006.5000bp_filter             0        66      591299
# genome_contigs_withBulk.011.5000bp_filter             0        25      189791
# genome_contigs_withBulk.032.5000bp_filter             0        89      921367
# genome_contigs_withBulk.162.5000bp_filter             0       105     1085543
# genome_contigs_withBulk.009.5000bp_filter             0        13       84619
# genome_contigs_withBulk.123.5000bp_filter             0       145     1014113
#
#                                           # genomes # marker sets # markers  \
# 0
# genome_contigs_withBulk.012.5000bp_filter      5656            24        56
# genome_contigs_withBulk.017.5000bp_filter      5449            58       104
# genome_contigs_withBulk.006.5000bp_filter      5449            58       104
# genome_contigs_withBulk.011.5000bp_filter      5656            24        56
# genome_contigs_withBulk.032.5000bp_filter      5656            24        56
# genome_contigs_withBulk.162.5000bp_filter      5656            24        56
# genome_contigs_withBulk.009.5000bp_filter      5656            24        56
# genome_contigs_withBulk.123.5000bp_filter      5656            24        56
#
#                                           # predicted genes Coding density  \
# 0
# genome_contigs_withBulk.012.5000bp_filter               478       0.897867
# genome_contigs_withBulk.017.5000bp_filter               704       0.899286
# genome_contigs_withBulk.006.5000bp_filter               591       0.890891
# genome_contigs_withBulk.011.5000bp_filter               190       0.905759
# genome_contigs_withBulk.032.5000bp_filter               868       0.911231
# genome_contigs_withBulk.162.5000bp_filter              1141       0.907639
# genome_contigs_withBulk.009.5000bp_filter                82       0.889044
# genome_contigs_withBulk.123.5000bp_filter              1137       0.947691
#
#                                                  GC     GC std Longest contig  \
# 0
# genome_contigs_withBulk.012.5000bp_filter  0.394355  0.0105792          14804
# genome_contigs_withBulk.017.5000bp_filter  0.399853  0.0121572          17021
# genome_contigs_withBulk.006.5000bp_filter  0.402594  0.0256219          30489
# genome_contigs_withBulk.011.5000bp_filter   0.42747  0.0230886          14872
# genome_contigs_withBulk.032.5000bp_filter  0.623087  0.0160368          38937
# genome_contigs_withBulk.162.5000bp_filter   0.68821  0.0146675          39077
# genome_contigs_withBulk.009.5000bp_filter  0.425744  0.0126747          11183
# genome_contigs_withBulk.123.5000bp_filter  0.708813  0.0114128          13273
#
#                                           Mean contig length N50 (contigs)  \
# 0
# genome_contigs_withBulk.012.5000bp_filter            6316.65          6053
# genome_contigs_withBulk.017.5000bp_filter             8390.2          8563
# genome_contigs_withBulk.006.5000bp_filter            8959.06          8935
# genome_contigs_withBulk.011.5000bp_filter            7591.64          9195
# genome_contigs_withBulk.032.5000bp_filter            10352.4         11313
# genome_contigs_withBulk.162.5000bp_filter            10338.5         10379
# genome_contigs_withBulk.009.5000bp_filter            6509.15          6224
# genome_contigs_withBulk.123.5000bp_filter            6993.88          6777
#
#                                            Strain heterogeneity
# 0
# genome_contigs_withBulk.012.5000bp_filter                   0.0
# genome_contigs_withBulk.017.5000bp_filter                   0.0
# genome_contigs_withBulk.006.5000bp_filter                   0.0
# genome_contigs_withBulk.011.5000bp_filter                   0.0
# genome_contigs_withBulk.032.5000bp_filter                   0.0
# genome_contigs_withBulk.162.5000bp_filter                   0.0
# genome_contigs_withBulk.009.5000bp_filter                   0.0
# genome_contigs_withBulk.123.5000bp_filter                   0.0

# %%
indices_oklist = ['genome_contigs_withBulk.'+f+'.5000bp_filter' for f in oklist]
FBcheckm_reassembled[FBcheckm_reassembled.index.isin(indices_oklist)]
fastanames_oklist = ['genome_contigs_withBulk.'+f+'.5000bp_filter.fasta' for f in oklist]
fastadir_old = [fastadir+f for f in fastanames_oklist]
fastadir_new = [fastadir+'ok_as_is/'+f for f in fastanames_oklist]
# move the reassembled fastas that are ok as is:
for i in range(len(fastadir_old)):
    os.rename(fastadir_old[i],fastadir_new[i])

# %%
finalpass = checkm_pruned2[(checkm_pruned2['Contamination']<=5)&(checkm_pruned2['Strain heterogeneity']<=5)].index
# move the pruned fastas that pass:
prunedir = [fastadir+'pruning/fastas/'+f+'.fasta' for f in finalpass]
finalpassdir = [fastadir+'pruning/fastas/final_pass/'+f+'.fasta' for f in finalpass]
for i in range(len(prunedir)):
    os.rename(prunedir[i],finalpassdir[i])
len(finalpassdir)
# Out:
# 64

# %% [markdown]
# now repeat for SagMAT and WestDock
