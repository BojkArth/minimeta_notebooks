# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import gridspec
import ast
import os
os.chdir('/home/bojk/Data/') #this is when opened in '/home/bojk/Data/notebooks' on linux Quakelab
#os.chdir('/Users/bojk/Google Drive/QuakeLab/Data/')
import sys
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
sys.path.append('/Users/bojk/Google Drive/QuakeLab/minimeta_pyfiles/')
import imp
import HTSeq
from scipy.stats import powerlaw
#import minimetagenome_analysis as minimeta

import mock_metagenome_creation as mock
imp.reload(mock)
#import reassembly as rea
#import subcluster_bins as sub
#import checkm_out_plot as cop
#import checkm_out as co

import matplotlib as mpl
mpl.rcParams['axes.labelsize'] = 15
mpl.rcParams['xtick.labelsize'] = 15
mpl.rcParams['ytick.labelsize'] = 15
mpl.rcParams['axes.titlesize'] = 15
mpl.rcParams['figure.titlesize'] = 18
mpl.rcParams['legend.fontsize'] = 14

from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
metagenome_fasta = '/home/datastorage/ASSEMBLY_DATA/PermafrostFranklinBluffs/Combined_Analysis/super_contigs.PermafrostFranklinBluffs.fasta'
save_dir = 'Permafrost/FranklinBluffs/pickles/'

# %%
imp.reload(mock)
contig5mer,k5mer = mock.make_kmertable_from_fasta_contigs(metagenome_fasta,5,save_dir)
# Out:
# Total number of fasta sequences:16985
# ----------------------------------------------------
# Started collecting kmers, dimensionality = 1024
# Local time: 16:42
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 500 contigs out of 16985 done, took 171.37 s
# Progress: 2.94 %, local time: 16:45
# Total elapsed time is 2.86 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 1000 contigs out of 16985 done, took 171.11 s
# Progress: 5.89 %, local time: 16:48
# Total elapsed time is 5.71 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 1500 contigs out of 16985 done, took 167.36 s
# Progress: 8.83 %, local time: 16:51
# Total elapsed time is 8.50 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 2000 contigs out of 16985 done, took 170.50 s
# Progress: 11.78 %, local time: 16:53
# Total elapsed time is 11.34 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 2500 contigs out of 16985 done, took 173.25 s
# Progress: 14.72 %, local time: 16:56
# Total elapsed time is 14.23 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 3000 contigs out of 16985 done, took 172.61 s
# Progress: 17.66 %, local time: 16:59
# Total elapsed time is 17.10 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 3500 contigs out of 16985 done, took 169.52 s
# Progress: 20.61 %, local time: 17:2
# Total elapsed time is 19.93 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 4000 contigs out of 16985 done, took 167.53 s
# Progress: 23.55 %, local time: 17:5
# Total elapsed time is 22.72 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 4500 contigs out of 16985 done, took 170.51 s
# Progress: 26.49 %, local time: 17:8
# Total elapsed time is 25.56 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 5000 contigs out of 16985 done, took 170.07 s
# Progress: 29.44 %, local time: 17:10
# Total elapsed time is 28.40 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 5500 contigs out of 16985 done, took 170.58 s
# Progress: 32.38 %, local time: 17:13
# Total elapsed time is 31.24 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 6000 contigs out of 16985 done, took 170.82 s
# Progress: 35.33 %, local time: 17:16
# Total elapsed time is 34.09 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 6500 contigs out of 16985 done, took 170.02 s
# Progress: 38.27 %, local time: 17:19
# Total elapsed time is 36.92 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 7000 contigs out of 16985 done, took 170.40 s
# Progress: 41.21 %, local time: 17:22
# Total elapsed time is 39.76 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 7500 contigs out of 16985 done, took 170.89 s
# Progress: 44.16 %, local time: 17:25
# Total elapsed time is 42.61 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 8000 contigs out of 16985 done, took 169.88 s
# Progress: 47.1 %, local time: 17:28
# Total elapsed time is 45.44 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 8500 contigs out of 16985 done, took 167.94 s
# Progress: 50.04 %, local time: 17:30
# Total elapsed time is 48.24 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 9000 contigs out of 16985 done, took 168.92 s
# Progress: 52.99 %, local time: 17:33
# Total elapsed time is 51.06 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 9500 contigs out of 16985 done, took 169.58 s
# Progress: 55.93 %, local time: 17:36
# Total elapsed time is 53.88 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 10000 contigs out of 16985 done, took 170.74 s
# Progress: 58.88 %, local time: 17:39
# Total elapsed time is 56.73 minutes
# ----------------------------------------------------
# ----------------------------------------------------
# Collecting kmers for 10500 contigs out of 16985 done, took 170.41 s
# Progress: 61.82 %, local time: 17:42
# Total elapsed time is 59.57 minutes
# ----------------------------------------------------
