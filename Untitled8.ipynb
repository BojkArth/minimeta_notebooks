# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import imp
sys.path.append('/home/bojk/Data/minimeta_pyfiles/')
import fromasciitodf as fad

# %%
# %pwd
# Out:
# '/home/bojk/Data/notebooks'

# %%
os.chdir('..')

# %%
imp.reload(fad)
kmer6 = fad.fromasciitodf('Permafrost/SagMAT/kmer6occurrence_bhtsne_locations_20.SagMAT.txt',20)

# %%
kmer6.plot.scatter('x_20n','y_20n',alpha=.05,figsize=(10,10))

# %%
pd.read_pickle('../Downloads/Demo_topgrenzen/SHAPE/topgrenzen_demo.dbf')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# ~/miniconda3/envs/py360/lib/python3.6/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ~/miniconda3/envs/py360/lib/python3.6/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     148         try:
# --> 149             return func(f)
#     150         finally:
#
# ~/miniconda3/envs/py360/lib/python3.6/site-packages/pandas/io/pickle.py in <lambda>(f)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# UnpicklingError: invalid load key, '\x03'.
#
# ...
